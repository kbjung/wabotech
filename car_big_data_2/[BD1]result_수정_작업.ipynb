# %% [markdown]
# # 라이브러리

# %%
import pandas as pd
import os
import tqdm
import numpy as np
from glob import glob

# %%
# import modin.pandas as pd
# import ray
# ray.init()

# %%
# 소수점 옵션
pd.options.display.float_format = '{:.2f}'.format
# pd.reset_option('display.float_format')

# %% [markdown]
# # fold path

# %%
result_fold = 'D:/data/big2/BD1/raw/result수정'
raw_fold = 'D:/data/big2/BD1/raw/result수정/raw'
sample_fold = 'D:/data/big2/BD1/raw/result수정/sample'
ods_fold = 'D:/data/big2/ODS'

# %% [markdown]
# # Load

# %% [markdown]
# ## 2개 result 파일 병합

# %%
glob(os.path.join(raw_fold, '*.csv'))
# Out:
# ['D:/data/big2/result/raw\\4등급 차량 리스트 양식 result 최종1_수정-작업.csv',
#  'D:/data/big2/result/raw\\4등급 차량 리스트 양식 result 최종2_수정-작업.csv',
#  'D:/data/big2/result/raw\\4등급 차량 리스트 양식 result 최종_수정-작업.csv',
#  'D:/data/big2/result/raw\\샘플_result_비고.csv']

# %%
# about 9.3s
# modin about 3.7s
df = pd.DataFrame()
for add in glob(os.path.join(raw_fold, '*.csv')):
    temp = pd.read_csv(add, encoding='cp949', low_memory=False)
    df = pd.concat([df, temp], ignore_index=False)
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153813 entries, 0 to 1153812
# Data columns (total 36 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   차대번호        1153813 non-null  object
#  1   차량번호        1153813 non-null  object
#  2   제원관리번호      1153813 non-null  object
#  3   차종_원본       1153813 non-null  object
#  4   용도          1153813 non-null  object
#  5   최초등록일       1153813 non-null  int64
#  6   연식          1153813 non-null  int64
#  7   제작일자        1153809 non-null  float64
#  8   검사유효일       1153810 non-null  float64
#  9   배출가스인증번호    1146663 non-null  object
#  10  등급          1153813 non-null  int64
#  11  차명          1153813 non-null  object
#  12  차종분류        1153813 non-null  object
#  13  차종유형        1153813 non-null  object
#  14  자동차형식       1153812 non-null  object
#  15  제작사명        1153795 non-null  object
#  16  연료          1153813 non-null  object
#  17  엔진형식        1153813 non-null  object
#  18  총중량         1153813 non-null  int64
#  19  적재중량        1153589 non-null  float64
#  20  엔진출력        1153811 non-null  float64
#  21  배기량         1153813 non-null  int64
#  22  법정동코드       1153813 non-null  int64
#  23  시도명         1153813 non-null  object
#  24  시군구명        1153813 non-null  object
#  25  소유자구분       1153813 non-null  object
#  26  말소여부        1153813 non-null  object
#  27  일치유무        1153813 non-null  object
#  28  인증번호 수정 유무  1153813 non-null  object
#  29  배인번호_수정     1153813 non-null  object
#  30  등급_수정       1153813 non-null  int64
#  31  DPF유무_수정    1153813 non-null  object
#  32  배출가스        1153813 non-null  object
#  33  등급2         1153813 non-null  object
#  34  DPF         1146987 non-null  object
#  35  비고          46458 non-null    object
# dtypes: float64(4), int64(7), object(25)
# memory usage: 316.9+ MB

# %% [markdown]
# ### [출력] df

# %%
# about 17s
df.to_csv(os.path.join(raw_fold, '4등급 차량 리스트 양식 result 최종_수정-작업.csv'), encoding='cp949', index=False)

# %% [markdown]
# ## result 수정

# %%
# about 10.3s
df = pd.read_csv(os.path.join(raw_fold, '4등급 차량 리스트 양식 result 최종_수정-작업.csv'), encoding='cp949', low_memory=False)

# %%
df['비고'].unique()
# Out:
# array([nan, '현재 5등급으로 반영되어 있음(2/23)',
#        '등급변경 5등급 확인 4MY-DB-04 인증번호 5등급 차량, DPF 확인불가->무 로 변경',
#        'BX210, BX120 혼재 및 5등급(BX212)에 동일 차종 있어 등급 검토, 전체 06, 07년식 차량',
#        '말소', 'DPF 장착 확인 필요', '4MY-DB-03 동일차량 5등급',
#        '동일 인증번호 3등급에도 있음. 확인 필요',
#        'DPF 무, 동일차종 5등급 차량 및 저감사업으로 DPF장착지원 되고 있는 차량 J3엔진 123마력 2902cc 형식 WFK12F8',
#        '푸조 307모델 DPF 장착 확인', '푸조407 607모델 혼제 DPF 장착 확인', 'DPF장착 확인 필요',
#        'DPF 장착 확인(미장착) 검토 필요',
#        '동일인정번호 차량 중 17대 보조금 지급으로 DPF장착. 실제 출고시 DPF장착 유무 확인 필요',
#        '동일인증번호 차량 중 배출가스 저감창치 장착된 차량 있음. 확인 필요', 'DPF 장착 확인(무, 확인불가)',
#        'PDF 확인불가', 'TDV6 DPF장착 확인 무, 확인불가',
#        '짚 그랜드 체로키 8MY-DK-14-01 배출가스 인증번호 현재 3등급으로 분류 중',
#        '짚 그랜드 체로키 동일 제원관리번호 차량 4,5등급 혼재, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중',
#        '짚 그랜드 체로키 동일 제원관리번호 차량 5등급, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중',
#        '짚 그랜드 체로키 동일 배출가스인증번로, 동일제원관리번호 3등급으로 분류 되어있음.',
#        '제원관리번호 확인 04220000400031308', '제원관리번호 확인 04220000400041309',
#        '제원관리번호 확인 04220000800021308', '제원관리번호 확인 04220000800031308',
#        '봉고3 8MY-KM-13-19 동일 배출가스 인증번호 3, 4등급 혼재 위 차량은 4등급 DPF장착 차량이며 저공해 인증차량 09,10년식 등급제 반영되어있음',
#        '(23.2.15)볼보차량 2,003대 4등급 -> 3등급 조정'], dtype=object)

# %% [markdown]
# ## 3등급 등록&제원정보

# %%
# about 2m 47s
name = '[ODS][G3]등록정보&제원정보(2022.12.28)'
file_name = f'{name}.csv'
g3 = pd.read_csv(os.path.join(ods_fold, file_name), low_memory=False, encoding='cp949')
g3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10027407 entries, 0 to 10027406
# Data columns (total 49 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   차량관리번호        object
#  1   차량등록번호        object
#  2   본거지법정동코드      int64
#  3   소유자구분         object
#  4   차종_등록정보       object
#  5   용도            object
#  6   현재회원번호        object
#  7   차대번호          object
#  8   최초등록일자        int64
#  9   차량연식          int64
#  10  차량제작일자        float64
#  11  배출가스검사유효일자    float64
#  12  제원관리번호        object
#  13  배출가스인증번호      object
#  14  배출가스등급        object
#  15  저공해조치YN(미사용)  object
#  16  저공해조치종류       float64
#  17  저공해조치구조변경YN   object
#  18  차량등록번호숫자정보    int64
#  19  차량말소YN        object
#  20  최초회원번호        object
#  21  취득일자          float64
#  22  취득금액          float64
#  23  생성일시_등록정보     object
#  24  수정일시_등록정보     object
#  25  차명            object
#  26  차종_제원정보       object
#  27  차종분류          object
#  28  차종유형(소분류)     object
#  29  자동차형식         object
#  30  제작사명          object
#  31  연료            object
#  32  엔진형식          object
#  33  공차중량          float64
#  34  총중량           float64
#  35  적재중량          float64
#  36  엔진출력          float64
#  37  배기량           float64
#  38  승차인원          float64
#  39  차량길이          float64
#  40  차량너비          float64
#  41  차량높이          float64
#  42  원산지명          object
#  43  삭제YN          object
#  44  승인일자          float64
#  45  구동형식          float64
#  46  변속기종류         object
#  47  생성일시_제원정보     object
#  48  수정일시_제원정보     object
# dtypes: float64(16), int64(4), object(29)
# memory usage: 3.7+ GB

# %% [markdown]
# ## 5등급 등록&제원정보

# %%
# about 37.7s
name = '[ODS][G5]등록정보&제원정보(2022.12.28)'
file_name = f'{name}.csv'
g5 = pd.read_csv(os.path.join(ods_fold, file_name), low_memory=False, encoding='cp949')
g5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2378648 entries, 0 to 2378647
# Data columns (total 49 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   차량관리번호        object
#  1   차량등록번호        object
#  2   본거지법정동코드      int64
#  3   소유자구분         object
#  4   차종_등록정보       object
#  5   용도            object
#  6   현재회원번호        object
#  7   차대번호          object
#  8   최초등록일자        int64
#  9   차량연식          int64
#  10  차량제작일자        float64
#  11  배출가스검사유효일자    float64
#  12  제원관리번호        object
#  13  배출가스인증번호      object
#  14  배출가스등급        object
#  15  저공해조치YN(미사용)  object
#  16  저공해조치종류       float64
#  17  저공해조치구조변경YN   object
#  18  차량등록번호숫자정보    int64
#  19  차량말소YN        object
#  20  최초회원번호        object
#  21  취득일자          float64
#  22  취득금액          float64
#  23  생성일시_등록정보     object
#  24  수정일시_등록정보     object
#  25  차명            object
#  26  차종_제원정보       object
#  27  차종분류          object
#  28  차종유형(소분류)     object
#  29  자동차형식         object
#  30  제작사명          object
#  31  연료            object
#  32  엔진형식          object
#  33  공차중량          float64
#  34  총중량           float64
#  35  적재중량          float64
#  36  엔진출력          float64
#  37  배기량           float64
#  38  승차인원          float64
#  39  차량길이          float64
#  40  차량너비          float64
#  41  차량높이          float64
#  42  원산지명          object
#  43  삭제YN          object
#  44  승인일자          object
#  45  구동형식          float64
#  46  변속기종류         object
#  47  생성일시_제원정보     object
#  48  수정일시_제원정보     object
# dtypes: float64(15), int64(4), object(30)
# memory usage: 889.2+ MB

# %% [markdown]
# # 확인

# %% [markdown]
# ## 비고 해당 샘플 수 확인

# %%
for one in df['비고'].unique():
    print(f'{one}')
    print(df.loc[df['비고'] == one].shape)
    print()
# Out:
# nan
# (0, 36)
#
# 현재 5등급으로 반영되어 있음(2/23)
# (7, 36)
#
# 등급변경 5등급 확인 4MY-DB-04 인증번호 5등급 차량, DPF 확인불가->무 로 변경
# (24, 36)
#
# BX210, BX120 혼재 및 5등급(BX212)에 동일 차종 있어 등급 검토, 전체 06, 07년식 차량
# (48, 36)
#
# 말소
# (2, 36)
#
# DPF 장착 확인 필요
# (4088, 36)
#
# 4MY-DB-03 동일차량 5등급
# (9, 36)
#
# 동일 인증번호 3등급에도 있음. 확인 필요
# (1690, 36)
#
# DPF 무, 동일차종 5등급 차량 및 저감사업으로 DPF장착지원 되고 있는 차량 J3엔진 123마력 2902cc 형식 WFK12F8
# (79, 36)
#
# 푸조 307모델 DPF 장착 확인
# (1677, 36)
#
# 푸조407 607모델 혼제 DPF 장착 확인
# (127, 36)
#
# DPF장착 확인 필요
# (1, 36)
#
# DPF 장착 확인(미장착) 검토 필요
# (2, 36)
#
# 동일인정번호 차량 중 17대 보조금 지급으로 DPF장착. 실제 출고시 DPF장착 유무 확인 필요
# (24415, 36)
#
# 동일인증번호 차량 중 배출가스 저감창치 장착된 차량 있음. 확인 필요
# (10751, 36)
#
# DPF 장착 확인(무, 확인불가)
# (1, 36)
#
# PDF 확인불가
# (1, 36)
#
# TDV6 DPF장착 확인 무, 확인불가
# (162, 36)
#
# 짚 그랜드 체로키 8MY-DK-14-01 배출가스 인증번호 현재 3등급으로 분류 중
# (137, 36)
#
# 짚 그랜드 체로키 동일 제원관리번호 차량 4,5등급 혼재, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중
# (107, 36)
#
# 짚 그랜드 체로키 동일 제원관리번호 차량 5등급, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중
# (4, 36)
#
# 짚 그랜드 체로키 동일 배출가스인증번로, 동일제원관리번호 3등급으로 분류 되어있음.
# (1, 36)
#
# 제원관리번호 확인 04220000400031308
# (34, 36)
#
# 제원관리번호 확인 04220000400041309
# (15, 36)
#
# 제원관리번호 확인 04220000800021308
# (120, 36)
#
# 제원관리번호 확인 04220000800031308
# (17, 36)
#
# 봉고3 8MY-KM-13-19 동일 배출가스 인증번호 3, 4등급 혼재 위 차량은 4등급 DPF장착 차량이며 저공해 인증차량 09,10년식 등급제 반영되어있음
# (934, 36)
#
# (23.2.15)볼보차량 2,003대 4등급 -> 3등급 조정
# (2005, 36)

# %% [markdown]
# ## 비고 하나씩 확인 함수, 준비

# %%
col = ['차대번호', '제원관리번호', '배인번호_수정', '등급_수정', 'DPF유무_수정', '차명', '제작사명', '자동차형식', '엔진형식', '연식']
dup_col = ['제원관리번호', '배인번호_수정', '등급_수정', 'DPF유무_수정', '차명', '제작사명', '자동차형식', '엔진형식', '연식']
check_col = ['제원관리번호', '배출가스인증번호', '배출가스등급', '차명', '제작사명', '자동차형식', '엔진형식', '차량연식']

# %%
def func(text):
    print(df.loc[df['비고'] == text, col].shape)
    # display(df.loc[df['비고'] == text, col].drop_duplicates(col))
    return df.loc[df['비고'] == text, col].drop_duplicates(dup_col)

# %% [markdown]
# ## [⭕] 현재 5등급으로 반영되어 있음(2/23)
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '현재 5등급으로 반영되어 있음(2/23)'
func(text)
# Out:
# (7, 10)
#                  차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 29  KL3K9ARF57K000001  A0310006701423306  6MY-DC-23-17      5        유
#
#                     차명        제작사명   자동차형식  엔진형식    연식
# 29  대우11.5톤장축카고트럭(DPF)  타타대우상용차(주)  K9ARF5  DV11  2007

# %% [markdown]
# ## [⭕] 등급변경 5등급 확인 4MY-DB-04 인증번호 5등급 차량, DPF 확인불가->무 로 변경
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '등급변경 5등급 확인 4MY-DB-04 인증번호 5등급 차량, DPF 확인불가->무 로 변경'
func(text)
# Out:
# (24, 10)
#                      차대번호             제원관리번호    배인번호_수정  등급_수정 DPF유무_수정  \
# 40548   KL5UM52PD7P027968  A0210001400792306  4MY-DB-04      4        무
# 40549   KL5UM52PD7P027530  A0210001400812306  4MY-DB-04      4        무
# 40552   KL5UK42PD7P003493  A0210001200872206  4MY-DB-04      4        무
# 40553   KL5UK42PD8U001076  A0210001201352207  4MY-DB-04      4        무
# 40555   KL5UK42PD8U001119  A0210001201402207  4MY-DB-04      4        무
# 40556   KL5UK42PD7P003227  A0210001200672206  4MY-DB-04      4        무
# 40558   KL5UK42PD7U000790  A0210001200762206  4MY-DB-04      4        무
# 40560   KL5UK42PD8U001103  A0210001201392307  4MY-DB-04      4        무
# 40561   KL5UK42PD7P003637  A0210001200802206  4MY-DB-04      4        무
# 229160  KL5UM52PD8U001480  A0210001401282307  4MY-DB-04      4        무
# 229189  KL5UA54MD8P000349  A0210002400232307  4MY-DB-04      4        무
#
#              차명          제작사명               자동차형식  엔진형식    연식
# 40548     BS106  자일대우상용차 주식회사    BS106-HM7P3T291S  DL08  2007
# 40549     BS106  자일대우상용차 주식회사    BS106-PR7P3T331S  DL08  2007
# 40552     BS090  자일대우상용차 주식회사    BS090-SC7P1T313P  DL08  2007
# 40553     BS090  자일대우상용차 주식회사    BS090-GP8P1T331P  DL08  2008
# 40555     BS090  자일대우상용차 주식회사    BS090-GP8P1T291P  DL08  2008
# 40556     BS090  자일대우상용차 주식회사    BS090-CS7P1T291S  DL08  2007
# 40558     BS090  자일대우상용차 주식회사    BS090-CS7P1T241S  DL08  2007
# 40560     BS090  자일대우상용차 주식회사    BS090-SC8P1T643P  DL08  2008
# 40561     BS090  자일대우상용차 주식회사    BS090-CS7P1T291S  DL08  2007
# 229160    BS106  자일대우상용차 주식회사    BS106-GP8P3T451S  DL08  2008
# 229189  BS110CN  자일대우상용차 주식회사  BS110CN-GP8P3A281F  DL08  2008

# %% [markdown]
# ## [⭕] BX210, BX120 혼재 및 5등급(BX212)에 동일 차종 있어 등급 검토, 전체 06, 07년식 차량
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = 'BX210, BX120 혼재 및 5등급(BX212)에 동일 차종 있어 등급 검토, 전체 06, 07년식 차량'
check = func(text)
check
# Out:
# (48, 10)
#                      차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 40570   KL5UY61YD6P000496  A0210002100412306  6MY-DB-24-24      4        무
# 40571   KL5UY61YD7P000682  A0210002100732306  6MY-DB-24-24      4        무
# 40572   KL5US65YD7P006118  A0210002001752307  6MY-DB-24-24      4        무
# 40573   KL5UY61YD7P000591  A0210002100772306  6MY-DB-24-24      4        무
# 40574   KL5UY61YD6P000533  A0210002100402306  6MY-DB-24-24      4        무
# 40575   KL5US65YD7P005889  A0210002001542307  6MY-DB-24-24      4        무
# 40576   KL5US65YD7P005789  A0210002001682307  6MY-DB-24-24      4        무
# 40578   KL5UY61YD7P000942  A0210002100742306  6MY-DB-24-24      4        무
# 40579   KL5US65YD7P005814  A0210002001552307  6MY-DB-24-24      4        무
# 40584   KL5UY61YD7P000894  A0210002100802307  6MY-DB-24-24      4        무
# 40589   KL5US65YD7P006365  A0210002001512307  6MY-DB-24-24      4        무
# 40594   KL5UY61YD7P000797  A0210002100812307  6MY-DB-24-24      4        무
# 40598   KL5UY61YD7P000864  A0210002100822307  6MY-DB-24-24      4        무
# 229356  KL5UY61YD8P001193  A0210002101092307  6MY-DB-24-24      4        무
#
#            차명          제작사명             자동차형식 엔진형식    연식
# 40570   BX212  자일대우상용차 주식회사  BX212-GP6Y1S401S  ISM  2006
# 40571   BX212  자일대우상용차 주식회사  BX212-GP7Y1S401S  ISM  2007
# 40572   BH120  자일대우상용차 주식회사  BH120-GP7Y2T452S  ISM  2007
# 40573   BX212  자일대우상용차 주식회사  BX212-GP7Y1S281S  ISM  2007
# 40574   BX212  자일대우상용차 주식회사  BX212-GP6Y1S441S  ISM  2006
# 40575   BH120  자일대우상용차 주식회사  BH120-GP7Y2S451S  ISM  2007
# 40576   BH120  자일대우상용차 주식회사  BH120-GP7Y2T401S  ISM  2007
# 40578   BX212  자일대우상용차 주식회사  BX212-GP7Y1S361S  ISM  2007
# 40579   BH120  자일대우상용차 주식회사  BH120-GP7Y2S452S  ISM  2007
# 40584   BX212  자일대우상용차 주식회사  BX212-GP7Y1S241S  ISM  2007
# 40589   BH120  자일대우상용차 주식회사  BH120-GP7Y2S412S  ISM  2007
# 40594   BX212  자일대우상용차 주식회사  BX212-GP7Y1S271T  ISM  2007
# 40598   BX212  자일대우상용차 주식회사  BX212-GP7Y1S251T  ISM  2007
# 229356  BX212  자일대우상용차 주식회사  BX212-GP8Y1S441S  ISM  2008

# %%
# 5등급에서 차량 찾기
# 1. 제번
# 2. 배인번호_수정
# 3. 차명

# %%
g5.columns
# Out:
# Index(['차량관리번호', '차량등록번호', '본거지법정동코드', '소유자구분', '차종_등록정보', '용도', '현재회원번호',
#        '차대번호', '최초등록일자', '차량연식', '차량제작일자', '배출가스검사유효일자', '제원관리번호', '배출가스인증번호',
#        '배출가스등급', '저공해조치YN(미사용)', '저공해조치종류', '저공해조치구조변경YN', '차량등록번호숫자정보',
#        '차량말소YN', '최초회원번호', '취득일자', '취득금액', '생성일시_등록정보', '수정일시_등록정보', '차명',
#        '차종_제원정보', '차종분류', '차종유형(소분류)', '자동차형식', '제작사명', '연료', '엔진형식', '공차중량',
#        '총중량', '적재중량', '엔진출력', '배기량', '승차인원', '차량길이', '차량너비', '차량높이', '원산지명',
#        '삭제YN', '승인일자', '구동형식', '변속기종류', '생성일시_제원정보', '수정일시_제원정보'],
#       dtype='object')

# %%
pick_col = '제원관리번호'
for one in check[pick_col]:
    temp = g5.loc[g5[pick_col] == one, check_col]
    if temp.shape[0] != 0:
        display(temp)
# Out:
#                     제원관리번호      배출가스인증번호 배출가스등급     차명          제작사명  \
# 2196148  A0210002100732306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
# 2289467  A0210002100732306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
# 2291175  A0210002100732306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
# 2310564  A0210002100732306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
# 2340558  A0210002100732306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
#
#                     자동차형식 엔진형식  차량연식
# 2196148  BX212-GP7Y1S401S  ISM  2007
# 2289467  BX212-GP7Y1S401S  ISM  2007
# 2291175  BX212-GP7Y1S401S  ISM  2007
# 2310564  BX212-GP7Y1S401S  ISM  2007
# 2340558  BX212-GP7Y1S401S  ISM  2007
#                     제원관리번호      배출가스인증번호 배출가스등급     차명          제작사명  \
# 2370420  A0210002001752307  6MY-DB-24-24      5  BH120  자일대우상용차 주식회사
#
#                     자동차형식 엔진형식  차량연식
# 2370420  BH120-GP7Y2T452S  ISM  2007
#                     제원관리번호      배출가스인증번호 배출가스등급     차명          제작사명  \
# 2291995  A0210002100772306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
#
#                     자동차형식 엔진형식  차량연식
# 2291995  BX212-GP7Y1S281S  ISM  2007
#                     제원관리번호      배출가스인증번호 배출가스등급     차명          제작사명  \
# 2086112  A0210002100402306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
# 2119019  A0210002100402306  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
#
#                     자동차형식 엔진형식  차량연식
# 2086112  BX212-GP6Y1S441S  ISM  2006
# 2119019  BX212-GP6Y1S441S  ISM  2006
#                     제원관리번호      배출가스인증번호 배출가스등급     차명          제작사명  \
# 2283850  A0210002001552307  6MY-DB-24-24      5  BH120  자일대우상용차 주식회사
# 2285568  A0210002001552307  6MY-DB-24-24      5  BH120  자일대우상용차 주식회사
#
#                     자동차형식 엔진형식  차량연식
# 2283850  BH120-GP7Y2S452S  ISM  2007
# 2285568  BH120-GP7Y2S452S  ISM  2007
#                     제원관리번호      배출가스인증번호 배출가스등급     차명          제작사명  \
# 2373548  A0210002101092307  6MY-DB-24-24      5  BX212  자일대우상용차 주식회사
#
#                     자동차형식 엔진형식  차량연식
# 2373548  BX212-GP8Y1S441S  ISM  2008

# %% [markdown]
# ## [⭕] 말소
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '말소'
func(text)
# Out:
# (2, 10)
#                       차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 44618    YSCFD41W382300083   420001000000000           확인불가      4     확인불가
# 1150271  KNGGBK8J18K000114  A0110004101422307  7MY-KM-24-33      4     확인불가
#
#                           차명               제작사명            자동차형식    엔진형식    연식
# 44618          캐딜락(Cadillac)  지엠아시아퍼시픽지역본부 주식회사              BLS  Z19DTH  2008
# 1150271  뉴그랜버드(NEW GRANBIRD)           기아자동차(주)  SD1-47-8HbZ-BET    D6HA  2008

# %% [markdown]
# ## [🔺] DPF 장착 확인 필요
# - '유' 로 변경 예정

# %%
text = 'DPF 장착 확인 필요'
check = func(text)
check
# Out:
# (4088, 10)
#                     차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 72176  KMHEU41VP9A524249    31112000000000   6MY-HD-14-64      4     확인불가
# 72177  KMHEU41VP7A364665    34113000000000   6MY-HD-14-64      4     확인불가
# 72178  KMHEU41VP7A415824    31113000000000   6MY-HD-14-64      4     확인불가
# 72179  KMHEU41VP6A209873    31121000000000   6MY-HD-14-64      4     확인불가
# 72180  KMHEU41VP7A408115    33002000000000   6MY-HD-14-64      4     확인불가
# 72181  KMHEU41VP9A565962    31119000000000   6MY-HD-14-64      4     확인불가
# 72182  KMHEU41VP7A310234    31123000000000   6MY-HD-14-64      4     확인불가
# 72183  KMHEU41VP7A338628    31126000000000   6MY-HD-14-64      4     확인불가
# 72184  KMHEU41VP9A552239    31123000000000   6MY-HD-14-64      4     확인불가
# 72185  KMHEU41VP7A290406    31123000000000   6MY-HD-14-64      4     확인불가
# 72186  KMHET41VP7A351447  A0810006400731206  6MY-HD-14-64      4     확인불가
# 72187  KMHET41VP8A578733  A0810006401631207  6MY-HD-14-64      4     확인불가
# 72188  KMHET41VP8A550458  A0810006401611207  6MY-HD-14-64      4     확인불가
# 72190  KMHET41VP6A213952  A0810006400581205  6MY-HD-14-64      4     확인불가
# 72197  KMHET41VP8A444680  A0810006401391207  6MY-HD-14-64      4     확인불가
# 72207  KMHET41VP8A504219  A0810006401571207  6MY-HD-14-64      4     확인불가
# 72213  KMHET41VP7A413432  A0810006401171207  6MY-HD-14-64      4     확인불가
# 72252  KMHET41VP7A383901  A0810006400721206  6MY-HD-14-64      4     확인불가
# 72268  KMHET41VBAA731683  A0810006402131209  6MY-HD-14-64      4     확인불가
# 72273  KMHET41VP9A710249  A0810006402031208  6MY-HD-14-64      4     확인불가
# 72279  KMHET41VP9A622649  A0810006401901208  6MY-HD-14-64      4     확인불가
# 72316  KMHET41VP8A475313  A0810006401381207  6MY-HD-14-64      4     확인불가
# 72326  KMHET41VP9A672797  A0810006402021208  6MY-HD-14-64      4     확인불가
# 72333  KMHET41VP7A405310  A0810006401151207  6MY-HD-14-64      4     확인불가
# 72357  KMHET41VP8A530297  A0810006401591207  6MY-HD-14-64      4     확인불가
# 72397  KMHET41VAAA734462  A0810006402121209  6MY-HD-14-64      4     확인불가
# 72423  KMHET41VP8A467825  A0810006401371207  6MY-HD-14-64      4     확인불가
# 72762  KMHET41VP9A622116  A0810006401881208  6MY-HD-14-64      4     확인불가
# 72962  KMHET41VP9A612382  A0810006401841208  6MY-HD-14-64      4     확인불가
# 74601  KMHET41VP9A607782  A0810006401861208  6MY-HD-14-64      4     확인불가
#
#                    차명      제작사명           자동차형식  엔진형식    연식
# 72176             쏘나타  자기인증면제차량    NF-D20B28-A2  D4EA  2009
# 72177     쏘나타(SONATA)  자기인증면제차량    NF-D20B28-A2  D4EA  2007
# 72178     쑈나타(SONATA)  자기인증면제차량    NF-D20B28-A2  D4EA  2007
# 72179             쏘나타  자기인증면제차량     NF-20DSL-4A  D4EA  2006
# 72180  HYUNDAI SONATA  자기인증면제차량    NF-D20B28-A2  D4EA  2007
# 72181          SONATA  자기인증면제차량           EU41V  D4EA  2009
# 72182          SONATA  자기인증면제차량           EU41V  D4EA  2007
# 72183          SONATA  자기인증면제차량           EU41V  D4EA  2007
# 72184          SONATA  자기인증면제차량  NF2-D20B222-A1  D4EA  2009
# 72185     쏘나타(SONATA)  자기인증면제차량     NF-20DSL-A1  D4EA  2007
# 72186     쏘나타(SONATA)  현대자동차(주)     NF-D20B2-A2  D4EA  2007
# 72187    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B221-A1  D4EA  2008
# 72188    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B222-A1  D4EA  2008
# 72190     쏘나타(SONATA)  현대자동차(주)     NF-20DSL-A1  D4EA  2006
# 72197     쏘나타(SONATA)  현대자동차(주)    NF-D20B29-A2  D4EA  2008
# 72207    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B222-M1  D4EA  2008
# 72213     쏘나타(SONATA)  현대자동차(주)    NF-D20B29-A1  D4EA  2007
# 72252     쏘나타(SONATA)  현대자동차(주)     NF-D20B2-M2  D4EA  2007
# 72268    쏘나타 (SONATA)  현대자동차(주)  NF2-D20GA-0901  D4EA  2010
# 72273    쏘나타 (SONATA)  현대자동차(주)  NF2-D20GA-0804  D4EA  2009
# 72279    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B221-A2  D4EA  2009
# 72316     쏘나타(SONATA)  현대자동차(주)    NF-D20B28-A2  D4EA  2008
# 72326    쏘나타 (SONATA)  현대자동차(주)  NF2-D20GM-0804  D4EA  2009
# 72333     쏘나타(SONATA)  현대자동차(주)    NF-D20B29-M1  D4EA  2007
# 72357    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B221-M1  D4EA  2008
# 72397    쏘나타 (SONATA)  현대자동차(주)  NF2-D20GM-0901  D4EA  2010
# 72423     쏘나타(SONATA)  현대자동차(주)    NF-D20B29-M2  D4EA  2008
# 72762    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B222-A2  D4EA  2009
# 72962    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B222-M2  D4EA  2009
# 74601    쏘나타 (SONATA)  현대자동차(주)  NF2-D20B221-M2  D4EA  2009

# %%
check['연식'].unique()
# Out:
# array([2009, 2007, 2006, 2008, 2010], dtype=int64)

# %%
# 현대 GSW로 확인 가능성 있는 소나타의 차대번호 확인
check['차대번호'].str[:6].unique()
# Out:
# array(['KMHEU4', 'KMHET4'], dtype=object)

# %% [markdown]
# ## [❓] 4MY-DB-03 동일차량 5등급
# - 5등급 샘플 추출(⭕)

# %%
text = '4MY-DB-03 동일차량 5등급'
func(text)
# Out:
# (9, 10)
#                      차대번호             제원관리번호    배인번호_수정  등급_수정 DPF유무_수정  \
# 229265  KL5UY61RD8P001220  A0210002101122307  4MY-DB-03      4        무
# 229287  KL5UY61RD8P001232  A0210002101112307  4MY-DB-03      4        무
# 229299  KL5UY61RD7P001084  A0210002100842307  4MY-DB-03      4        무
#
#            차명          제작사명             자동차형식  엔진형식    연식
# 229265  BX212  자일대우상용차 주식회사  BX212-GP8R5S441S  DV11  2008
# 229287  BX212  자일대우상용차 주식회사  BX212-GP8R5C401S  DV11  2008
# 229299  BX212  자일대우상용차 주식회사  BX212-GP7R5C441S  DV11  2007

# %%
g5.loc[g5['배출가스인증번호'] == '4MY-DB-03', check_col]
# Out:
#                     제원관리번호   배출가스인증번호 배출가스등급     차명          제작사명  \
# 1542876  A0210002000172304  4MY-DB-03      5  BH120  자일대우상용차 주식회사
# 1543296  A0210001600042304  4MY-DB-03      5  BH116  자일대우상용차 주식회사
# 1547264  A0210001700012304  4MY-DB-03      5  BH117  자일대우상용차 주식회사
# 1549663  A0210001900152304  4MY-DB-03      5  BH119  자일대우상용차 주식회사
# 1551260  A0210002000192304  4MY-DB-03      5  BH120  자일대우상용차 주식회사
# ...                    ...        ...    ...    ...           ...
# 2375266  A0210002001212306  4MY-DB-03      5  BH120  자일대우상용차 주식회사
# 2376862  A0210001901042307  4MY-DB-03      5  BH119  자일대우상용차 주식회사
# 2377669  A0210002000782305  4MY-DB-03      5  BH120  자일대우상용차 주식회사
# 2378075  A0210002001212306  4MY-DB-03      5  BH120  자일대우상용차 주식회사
# 2378591  00034427000012319  4MY-DB-03      5  BX212      자기인증면제차량
#
#                     자동차형식  엔진형식  차량연식
# 1542876  BH120-GP5R3S452S  DV11  2005
# 1543296  BH116-GP5R1T452S  DV11  2005
# 1547264  BH117-GP5R2S451S  DV11  2005
# 1549663  BH119-GP5R3S411S  DV11  2005
# 1551260  BH120-GP5R3S412S  DV11  2005
# ...                   ...   ...   ...
# 2375266  BH120-GP7R3S452S  DV11  2007
# 2376862  BH119-GP7R4S451S  DV11  2007
# 2377669  BH120-GP6R3S451S  DV11  2009
# 2378075  BH120-GP7R3S452S  DV11  2007
# 2378591  BX212-GP5R4A441S  DV11  2006
#
# [783 rows x 8 columns]

# %%
g5.loc[g5['배출가스인증번호'] == '4MY-DB-03', '차명'].unique()
# Out:
# array(['BH120', 'BH116', 'BH117', 'BH119', 'BX212', 'BH212', 'BH115E'],
#       dtype=object)

# %% [markdown]
# ### [샘플] 5등급 동일 배번

# %%
g5.loc[g5['배출가스인증번호'] == '4MY-DB-03'].to_csv(os.path.join(sample_fold, '샘플 5등급 등록&제원 4MY-DB-03.csv'), encoding='cp949', index=False)

# %% [markdown]
# ## [❓] 동일 인증번호 3등급에도 있음. 확인 필요
# - 동일 배번 3등급 샘플 추출(⭕)

# %%
text = '동일 인증번호 3등급에도 있음. 확인 필요'
check = func(text)
check
# Out:
# (1690, 10)
#                      차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 229379  KLTBL8AW19K000032  A0310007502323308  7MY-DC-23-69      4        유
# 229380  KLTBP9CN3AK000049  A0310007601503308  7MY-DC-23-69      4        유
# 229381  KLTBP9CN39K000015  A0310007600683308  7MY-DC-23-69      4        유
# 229382  KLTBT9CM2BK000968  A0310007700313310  7MY-DC-23-69      4        유
# 229383  KLTBT9CM29K000211  A0310007700213308  7MY-DC-23-69      4        유
# ...                   ...                ...           ...    ...      ...
# 230392  KLTET9CMEBK000001  A0310008400343310  7MY-DC-23-69      4        유
# 230527  KLUBK3TM1BK000063  A0310007800754310  7MY-DC-23-69      4        유
# 230568  KLTBP7CN4BK000004  A0310007602093310  7MY-DC-23-69      4        유
# 230706  KLTBL7CW1AK000005  A0310007503213308  7MY-DC-23-69      4        유
# 230900  KLUBK3TM1AK000033  A0310007800574308  7MY-DC-23-69      4        유
#
#                        차명        제작사명   자동차형식 엔진형식    연식
# 229379      대우11.5톤장축카고트럭  타타대우상용차(주)  BL8AW1  ISM  2009
# 229380  대우22.5톤후삼축초장축카고트럭  타타대우상용차(주)  BP9CN3  ISM  2010
# 229381  대우22.5톤후삼축초장축카고트럭  타타대우상용차(주)  BP9CN3  ISM  2009
# 229382          대우25톤카고트럭  타타대우상용차(주)  BT9CM2  ISM  2011
# 229383          대우25톤카고트럭  타타대우상용차(주)  BT9CM2  ISM  2009
# ...                   ...         ...     ...  ...   ...
# 230392          대우25톤카고트럭  타타대우상용차(주)  ET9CME  ISM  2011
# 230527              대우트랙터  타타대우상용차(주)  BK3TM1  ISM  2011
# 230568     대우24톤후삼축단축카고트럭  타타대우상용차(주)  BP7CN4  ISM  2011
# 230706        대우16톤표준카고트럭  타타대우상용차(주)  BL7CW1  ISM  2010
# 230900              대우트랙터  타타대우상용차(주)  BK3TM1  ISM  2010
#
# [68 rows x 10 columns]

# %%
check['차명'].unique()
# Out:
# array(['대우11.5톤장축카고트럭', '대우22.5톤후삼축초장축카고트럭', '대우25톤카고트럭', '대우트랙터',
#        '대우14톤장축카고트럭', '대우풀카고트럭', '대우19.5톤단축카고트럭', '대우15.5톤표준카고트럭',
#        '대우22.5톤후삼축카고트럭', '대우24톤후삼축단축카고트럭', '대우14톤초장축카고트럭', '대우24톤후삼축카고트럭',
#        '대우16톤표준카고트럭'], dtype=object)

# %%
g3.loc[g3['배출가스인증번호'] == '7MY-DC-23-69', check_col]
# Out:
#                     제원관리번호      배출가스인증번호 배출가스등급         차명        제작사명  \
# 2003443  A0310007700123308  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2003796  A0310007700123308  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2004198  A0310007700123308  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2004978  A0310007700123308  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2005123  A0310007700123308  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# ...                    ...           ...    ...        ...         ...
# 2379956  A0310008400603310  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2386614  A0310008400603310  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2393752  A0310008400603310  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2404949  A0310007700303310  7MY-DC-23-69      3  대우25톤카고트럭  타타대우상용차(주)
# 2423307  A0310008500294310  7MY-DC-23-69      3      대우트랙터  타타대우상용차(주)
#
#           자동차형식 엔진형식  차량연식
# 2003443  BT9CM1  ISM  2009
# 2003796  BT9CM1  ISM  2009
# 2004198  BT9CM1  ISM  2009
# 2004978  BT9CM1  ISM  2009
# 2005123  BT9CM1  ISM  2009
# ...         ...  ...   ...
# 2379956  ET9CM2  ISM  2011
# 2386614  ET9CM2  ISM  2011
# 2393752  ET9CM2  ISM  2011
# 2404949  BT9CM1  ISM  2011
# 2423307  EK3TM8  ISM  2011
#
# [557 rows x 8 columns]

# %%
g3.loc[g3['배출가스인증번호'] == '7MY-DC-23-69', '차명'].unique()
# Out:
# array(['대우25톤카고트럭', '대우24톤후삼축단축카고트럭', '대우17톤표준카고트럭', '대우21톤후삼축초장축카고트럭',
#        '대우19톤장축카고트럭', '대우19.5톤단축카고트럭', '대우풀카고트럭', '대우14톤장축카고트럭', '대우트랙터',
#        '대우16톤단축카고트럭'], dtype=object)

# %%
set(check['차명'].unique()) & set(g3.loc[g3['배출가스인증번호'] == '7MY-DC-23-69', '차명'].unique())
# Out:
# {'대우14톤장축카고트럭',
#  '대우19.5톤단축카고트럭',
#  '대우24톤후삼축단축카고트럭',
#  '대우25톤카고트럭',
#  '대우트랙터',
#  '대우풀카고트럭'}

# %% [markdown]
# ### [샘플] 3등급 동일 배번

# %%
g3.loc[g3['배출가스인증번호'] == '7MY-DC-23-69'].to_csv(os.path.join(sample_fold, '샘플 3등급 등록&제원 7MY-DC-23-69.csv'), encoding='cp949', index=False)

# %% [markdown]
# ## [🔺] DPF 무, 동일차종 5등급 차량 및 저감사업으로 DPF장착지원 되고 있는 차량 J3엔진 123마력 2902cc 형식 WFK12F8
# - '무' 확인

# %%
text = 'DPF 무, 동일차종 5등급 차량 및 저감사업으로 DPF장착지원 되고 있는 차량 J3엔진 123마력 2902cc 형식 WFK12F8'
check = func(text)
check
# Out:
# (79, 10)
#                      차대번호             제원관리번호    배인번호_수정  등급_수정 DPF유무_수정  \
# 500099  KN4HAW8NR8K284550  A0110003301173207  4MY-KM-08      4     확인불가
# 500100  KN4HAW8NK8K289037  A0110003301243207  4MY-KM-08      4     확인불가
# 500102  KN90J4MDD8HZ00045  A0110003301253207  4MY-KM-08      4     확인불가
# 500108  KN4HAT8NX8K287223  A0110003301273207  4MY-KM-08      4     확인불가
# 500110  KN4HAT8NH8K288487  A0110003301263207  4MY-KM-08      4     확인불가
# 500113  KN4HAW8NV8K288356  A0110003301213207  4MY-KM-08      4     확인불가
# 500116  KN4HAW8NM8K288629  A0110003301193207  4MY-KM-08      4     확인불가
# 500120  KN4HAW8NU8K284407  A0110003301203207  4MY-KM-08      4     확인불가
# 500122  KN4HAW8NP8K285021  A0110003301163207  4MY-KM-08      4     확인불가
#
#                    차명      제작사명         자동차형식 엔진형식    연식
# 500099    봉고Ⅲ 1.4톤냉동차  기아자동차(주)   WFK12F8-RTS   J3  2008
# 500100     봉고Ⅲ1.4톤윙바디  기아자동차(주)    WFK12F8-WB   J3  2008
# 500102   봉고Ⅲ1.4톤활어수송차  기아자동차(주)   WFK12F8-LFT   J3  2008
# 500108        봉고Ⅲ 홈로리  기아자동차(주)    WFK12F8-HL   J3  2008
# 500110   봉고Ⅲ1.4톤파워게이트  기아자동차(주)   WFK12F8-PGT   J3  2008
# 500113  봉고Ⅲ1.4톤플러스내장차  기아자동차(주)  WFK12F8-PDVS   J3  2008
# 500116     봉고Ⅲ1.4톤내장차  기아자동차(주)   WFK12F8-DVS   J3  2008
# 500120  봉고Ⅲ1.4톤플러스내장차  기아자동차(주)  WFS12F8-PDVS   J3  2008
# 500122    봉고Ⅲ 1.4톤냉동차  기아자동차(주)   WFS12F8-RTS   J3  2008

# %%
check.shape
# Out:
# (9, 10)

# %%
pick_col = '제원관리번호'
for one in check[pick_col]:
    temp = g5.loc[g5[pick_col] == one, check_col]
    if temp.shape[0] != 0:
        display(temp.shape)
# Out:
# (57, 8)
# (74, 8)
# (34, 8)
# (45, 8)
# (23, 8)
# (31, 8)
# (7, 8)
# (23, 8)
# (34, 8)

# %%
g5.loc[g5['제원관리번호'] == 'A0110003301173207', check_col].head()
# Out:
#                     제원관리번호 배출가스인증번호 배출가스등급           차명      제작사명  \
# 2303600  A0110003301173207      NaN      5  봉고Ⅲ 1.4톤냉동차  기아자동차(주)
# 2304553  A0110003301173207      NaN      5  봉고Ⅲ 1.4톤냉동차  기아자동차(주)
# 2305506  A0110003301173207      NaN      5  봉고Ⅲ 1.4톤냉동차  기아자동차(주)
# 2306394  A0110003301173207      NaN      5  봉고Ⅲ 1.4톤냉동차  기아자동차(주)
# 2307382  A0110003301173207      NaN      5  봉고Ⅲ 1.4톤냉동차  기아자동차(주)
#
#                자동차형식 엔진형식  차량연식
# 2303600  WFK12F8-RTS   J3  2008
# 2304553  WFK12F8-RTS   J3  2008
# 2305506  WFK12F8-RTS   J3  2008
# 2306394  WFK12F8-RTS   J3  2008
# 2307382  WFK12F8-RTS   J3  2008

# %% [markdown]
# ## [🔺] 푸조 307모델 DPF 장착 확인
# - 한불모터스에 확인 요청 예정

# %%
text = '푸조 307모델 DPF 장착 확인'
func(text)
# Out:
# (1677, 10)
#                      차대번호            제원관리번호      배인번호_수정  등급_수정 DPF유무_수정  \
# 500187  KL90E3ABD6H006050  620001000000000   5MY-HB-14-1      4     확인불가
# 500195  VF34HRHRJ9S003103  620001000000000   5MY-HB-14-1      4     확인불가
# 500197  KL90B3ABD7UZ00001  620000000000000   5MY-HB-14-1      4     확인불가
# 500199  VF33HRHRJ7S013876  620000000000000   5MY-HB-14-1      4     확인불가
# 500200  VF34BRHRJBS004574  620001000000000   5MY-HB-14-1      4     확인불가
# 500201  VF36DRHRJ8L002028  620001000000000   5MY-HB-14-1      4     확인불가
# 500202  VF33CRHRJ8S002050  620000000000000   5MY-HB-14-1      4     확인불가
# 500203  VF36DRHRJ7L003304  620001000000000   5MY-HB-14-1      4     확인불가
# 500204  VF36DRHRJ9L001441  620001000000000   5MY-HB-14-1      4     확인불가
# 500205  VF33HRHRJ7S016430  620000000000000   5MY-HB-14-1      4     확인불가
# 500208  VF34BRHRJAS001255  620001000000000   5MY-HB-14-1      4     확인불가
# 500211  VF33HRHRJ8S002074  620000000000000   5MY-HB-14-1      4     확인불가
# 500217  VF33HRHRJ8S009571  620000000000000   5MY-HB-14-1      4     확인불가
# 500222  VF33HRHRJ9S000339  620000000000000   5MY-HB-14-1      4     확인불가
# 500225  VF34CRHRJ9S002527  620001000000000   5MY-HB-14-1      4     확인불가
# 500229  VF34HRHRJBS003965  620001000000000   5MY-HB-14-1      4     확인불가
# 500239  VF36ERHRJ7L005560  620001000000000   5MY-HB-14-1      4     확인불가
# 500251  VF33HRHRJ9S000046  620000000000000   5MY-HB-14-1      4     확인불가
# 500255  VF36ERHRJ9L001774  620001000000000   5MY-HB-14-1      4     확인불가
# 500315  VF34HRHRJAS056248  620001000000000   5MY-HB-14-1      4     확인불가
# 500459  KL90E3ABD8SZ00001  620001000000000   5MY-HB-14-1      4     확인불가
# 500674  VF36DRHRJ6L016663  620001000000000   5MY-HB-14-1      4     확인불가
# 501391  VF34BRHRJ9S009668  620001000000000   5MY-HB-14-1      4     확인불가
# 501690  VF34BRHHACS057952  620001000000000   5MY-HB-14-1      4     확인불가
# 501862  VF33HRHRJ85103759   33002000000000   5MY-HB-14-1      4     확인불가
# 501863  VF33H9HZC83642855   31113000000000   5MY-HB-14-1      4     확인불가
#
#                                 차명      제작사명 자동차형식 엔진형식    연식
# 500187         푸조 407SW HDi FAP A6  한불모터스(주)    6E  RHR  2006
# 500195  Nouvelle Peugeot 308SW HDi  한불모터스(주)    4H  RHR  2009
# 500197              푸조 NEW 307 HDi  한불모터스(주)    3C  RHR  2007
# 500199            푸조 NEW 307SW HDi  한불모터스(주)    3H  RHR  2007
# 500200  Nouvelle Peugeot 308CC HDi  한불모터스(주)    4B  RHR  2011
# 500201           푸조 407 HDi FAP A6  한불모터스(주)    6D  RHR  2008
# 500202              푸조 NEW 307 HDi  한불모터스(주)    3C  RHR  2008
# 500203           푸조 407 HDi FAP A6  한불모터스(주)    6D  RHR  2007
# 500204    Nouvelle Peugeot 407 HDi  한불모터스(주)    6D  RHR  2009
# 500205           푸조 NEW 307SW HDi7  한불모터스(주)   3H7  RHR  2007
# 500208  Nouvelle Peugeot 308CC HDi  한불모터스(주)    4B  RHR  2010
# 500211            푸조 NEW 307SW HDi  한불모터스(주)    3H  RHR  2008
# 500217           푸조 NEW 307SW HDi7  한불모터스(주)   3H7  RHR  2008
# 500222            푸조 NEW 307SW HDi  한불모터스(주)    3H  RHR  2009
# 500225    Nouvelle Peugeot 308 HDi  한불모터스(주)    4C  RHR  2009
# 500229  Nouvelle Peugeot 308SW HDi  한불모터스(주)    4H  RHR  2011
# 500239         푸조 407SW HDi FAP A6  한불모터스(주)    6E  RHR  2007
# 500251           푸조 NEW 307SW HDi7  한불모터스(주)   3H7  RHR  2009
# 500255  Nouvelle Peugeot 407SW HDi  한불모터스(주)    6E  RHR  2009
# 500315  Nouvelle Peugeot 308SW HDi  한불모터스(주)    4H  RHR  2010
# 500459         푸조 407SW HDi FAP A6  한불모터스(주)    6E  RHR  2008
# 500674           푸조 407 HDi FAP A6  한불모터스(주)    6D  RHR  2006
# 501391  Nouvelle Peugeot 308CC HDi  한불모터스(주)    4B  RHR  2009
# 501690  Nouvelle Peugeot 308CC HDi  한불모터스(주)    4B  RHR  2012
# 501862                푸조 307SW HDi  자기인증면제차량   3H7  RHR  2008
# 501863                       307SW  자기인증면제차량    3H  9HZ  2008

# %%
# 한불모터스

# %% [markdown]
# ## [🔺] 푸조407 607모델 혼제 DPF 장착 확인
# - 한불모터스에 확인 요청 예정

# %%
text = '푸조407 607모델 혼제 DPF 장착 확인'
func(text)
# Out:
# (127, 10)
#                      차대번호            제원관리번호      배인번호_수정  등급_수정 DPF유무_수정  \
# 501864  VF39UUHZJ7S007926  620000000000000   5MY-HB-14-4      4     확인불가
# 501865  VF36JUHZJ8L000538  620001000000000   5MY-HB-14-4      4     확인불가
# 501866  KL9OA3ADD6H006248  620000000000000   5MY-HB-14-4      4     확인불가
# 501870  VF39UUHZJ8S011450  620000000000000   5MY-HB-14-4      4     확인불가
# 501894  VF36JUHZJ7L005546  620001000000000   5MY-HB-14-4      4     확인불가
# 501901  VF36DUHZJ8L003553  620001000000000   5MY-HB-14-4      4     확인불가
# 501940  KL90A3ADD6H006006  620000000000000   5MY-HB-14-4      4     확인불가
#
#                           차명      제작사명 자동차형식 엔진형식    연식
# 501864    푸조 607 2.7 HDi FAP  한불모터스(주)    9U  UHZ  2007
# 501865  푸조 407 Coupe 2.7 HDi  한불모터스(주)    6J  UHZ  2008
# 501866      푸조607 2.7HDi FAP  한불모터스(주)    9U  UHZ  2006
# 501870    푸조 607 2.7 HDi FAP  한불모터스(주)    9U  UHZ  2008
# 501894  푸조 407 Coupe 2.7 HDi  한불모터스(주)    6J  UHZ  2007
# 501901        푸조 407 2.7 HDi  한불모터스(주)    6D  UHZ  2008
# 501940    푸조 607 2.7 HDi FAP  한불모터스(주)    9U  UHZ  2006

# %%
# 한불모터스

# %% [markdown]
# ## [🔺] DPF장착 확인 필요
# - '유' 로 변경 예정

# %%
text = 'DPF장착 확인 필요'
func(text)
# Out:
# (1, 10)
#                      차대번호           제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 501998  KNEGE226385218649  31105000000000   5MY-KM-24-57      4        무
#
#               차명      제작사명 자동차형식  엔진형식    연식
# 501998  MAGENTIS  자기인증면제차량  GE22  D4EA  2008

# %%
df.loc[df['배인번호_수정'] == '5MY-KM-24-57', 'DPF유무_수정'].value_counts()
# Out:
# 유    350
# 무      1
# Name: DPF유무_수정, dtype: int64

# %%
df.loc[(df['배인번호_수정'] == '5MY-KM-24-57') & (df['DPF유무_수정'] == '유'), col]
# Out:
#                     차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 37254  KNEGE226365052026    31116000000000   5MY-KM-24-57      4        유
# 37255  KNEGE226365067727    31116000000000   5MY-KM-24-57      4        유
# 37256  KNAGE22637A133549  A0110003700441206  5MY-KM-24-57      4        유
# 37257  KNAGE22636A066832  A0110003700191205  5MY-KM-24-57      4        유
# 37258  KNAGE22636A066888  A0110003700191205  5MY-KM-24-57      4        유
# ...                  ...                ...           ...    ...      ...
# 37599  KNAGE22636A066703  A0110003700191205  5MY-KM-24-57      4        유
# 37600  KNAGE22636A073150  A0110003700211205  5MY-KM-24-57      4        유
# 37601  KNAGE22636A052671  A0110003700191205  5MY-KM-24-57      4        유
# 37602  KNAGE22636A074755  A0110003700191205  5MY-KM-24-57      4        유
# 37603  KNAGE22637A133327  A0110003700441206  5MY-KM-24-57      4        유
#
#              차명      제작사명      자동차형식  엔진형식    연식
# 37254  MAGENTIS  자기인증면제차량       GE22  D4EA  2006
# 37255  MAGENTIS  자기인증면제차량       GE22  D4EA  2006
# 37256        로체  기아자동차(주)     GEN63C  D4EA  2007
# 37257        로체  기아자동차(주)     GEN63A  D4EA  2006
# 37258        로체  기아자동차(주)     GEN63A  D4EA  2006
# ...         ...       ...        ...   ...   ...
# 37599        로체  기아자동차(주)     GEN63A  D4EA  2006
# 37600        로체  기아자동차(주)  GEN63A-HG  D4EA  2006
# 37601        로체  기아자동차(주)     GEN63A  D4EA  2006
# 37602        로체  기아자동차(주)     GEN63A  D4EA  2006
# 37603        로체  기아자동차(주)     GEN63C  D4EA  2007
#
# [350 rows x 10 columns]

# %%
# 동일 배인번호 차량의 DFP유무 : 유

# %% [markdown]
# ## [🔺] DPF 장착 확인(미장착) 검토 필요
# - '유' 확인

# %%
text = 'DPF 장착 확인(미장착) 검토 필요'
func(text)
# Out:
# (2, 9)
#                  제원관리번호       배인번호_수정  등급_수정 DPF유무_수정   차명      제작사명  자동차형식  \
# 738520  31113000000000   5MY-SY-23-58      4        유  렉스턴  자기인증면제차량  RX270
# 780651  31124000000000   5MY-SY-23-58      4        유  렉스턴  자기인증면제차량  G0B1F
#
#           엔진형식    연식
# 738520  665925  2006
# 780651  665925  2006

# %%
df.loc[df['배인번호_수정'] == '5MY-SY-23-58', 'DPF유무_수정'].value_counts()
# Out:
# 유    132
# Name: DPF유무_수정, dtype: int64

# %%
# 제작사확인 파일의 DPF유무 : 유 -> 자기인증면제차량은 동일차명, 동일 엔진형식으로 따라감

# %% [markdown]
# ## [🔺] 동일인정번호 차량 중 17대 보조금 지급으로 DPF장착. 실제 출고시 DPF장착 유무 확인 필요
# - '유' 확인

# %%
text = '동일인정번호 차량 중 17대 보조금 지급으로 DPF장착. 실제 출고시 DPF장착 유무 확인 필요'
check = func(text)
check
# Out:
# (24415, 10)
#                      차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 738521  KMFGA17HP9C118382  A0810005007923208  7MY-HD-24-28      4        유
# 738522  KMFGA17HPAC137963  A0810005008603209  7MY-HD-24-28      4        유
# 738523  KMFGA17HP9C116492  A0810005007863208  7MY-HD-24-28      4        유
# 738524  KN90J5MFDBKZ00078  A0810005009343210  7MY-HD-24-28      4        유
# 738525  KMJHD17HP8C000173  A0810005602312207  7MY-HD-24-28      4        유
# ...                   ...                ...           ...    ...      ...
# 762113  KMJHD17HP8C000304  A0810005602172207  7MY-HD-24-28      4        유
# 762162  KMCGK17HP8C091992  A0810005007324207  7MY-HD-24-28      4        유
# 762933  KMCGK17HP9C112030  A0810005008143209  7MY-HD-24-28      4        유
# 762934  KMJHD17HP8C000483    32826000000000   7MY-HD-24-28      4        유
# 999951  KMJHD17PP7C038495    31107000000000   7MY-HD-24-28      4     확인불가
#
#                        차명      제작사명              자동차형식  엔진형식    연식
# 738521              이-마이티  현대자동차(주)     HD2.5CS-9LLFbF  D4GA  2009
# 738522              이-마이티  현대자동차(주)   HD3.5CS2-10LHFbT  D4GA  2010
# 738523              이-마이티  현대자동차(주)     HD2.5CP-9LHFbF  D4GA  2009
# 738524              이-마이티  현대자동차(주)  HD2.5CP-E11LHFbT5  D4GA  2011
# 738525              이-카운티  현대자동차(주)      HCS25-8LFb-TB  D4GA  2008
# ...                   ...       ...                ...   ...   ...
# 762113              이-카운티  현대자동차(주)      HCS14-8SFb-RB  D4GA  2008
# 762162          마이티슈퍼렉커트럭  현대자동차(주)   HD25S-8WR0-LHFbF  D4GA  2008
# 762933         마이티군물자수송트럭  현대자동차(주)    HD25-9MT0-LHFbF  D4GA  2009
# 762934  HYUNDAI LIMOUSINE  자기인증면제차량     HCS15-G8LFB-RB  D4GA  2008
# 999951              이-카운티  자기인증면제차량      HCS16-7LW-TB1  D4DD  2007
#
# [269 rows x 10 columns]

# %%
check['DPF유무_수정'].value_counts()
# Out:
# 유       268
# 확인불가      1
# Name: DPF유무_수정, dtype: int64

# %%
df.loc[df['배출가스인증번호'] == '7MY-HD-24-28', 'DPF유무_수정'].value_counts()
# Out:
# 유       24414
# 확인불가      617
# Name: DPF유무_수정, dtype: int64

# %%
df.loc[df['배출가스인증번호'] == '7MY-HD-24-28', ['배출가스인증번호', '배인번호_수정', '제원관리번호', '제작사명', '차명', '자동차형식', '엔진형식', '연식']]
# Out:
#              배출가스인증번호       배인번호_수정             제원관리번호                제작사명  \
# 738521   7MY-HD-24-28  7MY-HD-24-28  A0810005007923208            현대자동차(주)
# 738522   7MY-HD-24-28  7MY-HD-24-28  A0810005008603209            현대자동차(주)
# 738523   7MY-HD-24-28  7MY-HD-24-28  A0810005007863208            현대자동차(주)
# 738524   7MY-HD-24-28  7MY-HD-24-28  A0810005009343210            현대자동차(주)
# 738525   7MY-HD-24-28  7MY-HD-24-28  A0810005602312207            현대자동차(주)
# ...               ...           ...                ...                 ...
# 1151874  7MY-HD-24-28          확인불가  B1T10001300003208           주식회사 한서정공
# 1151875  7MY-HD-24-28          확인불가  B0B10003300003207         (주) 삼오특장자동차
# 1151876  7MY-HD-24-28          확인불가  A0610004400003210              (주) 오텍
# 1151877  7MY-HD-24-28          확인불가  B1T10001000003208           주식회사 한서정공
# 1151878  7MY-HD-24-28          확인불가  B3710005600003208  주식회사 평강비아이엠(B.I.M)
#
#                    차명              자동차형식  엔진형식    연식
# 738521          이-마이티     HD2.5CS-9LLFbF  D4GA  2009
# 738522          이-마이티   HD3.5CS2-10LHFbT  D4GA  2010
# 738523          이-마이티     HD2.5CP-9LHFbF  D4GA  2009
# 738524          이-마이티  HD2.5CP-E11LHFbT5  D4GA  2011
# 738525          이-카운티      HCS25-8LFb-TB  D4GA  2008
# ...               ...                ...   ...   ...
# 1151874       한서이동방제차           HF-2000D  D4GA  2008
# 1151875     삼오5KL탱크로리            SAM05KL  D4GA  2008
# 1151876  오텍마이티큐티 냉장탑차   D4GA-3P34WL-SRT1  D4GA  2010
# 1151877       한서이동방제차            HF-2000  D4GA  2008
# 1151878       평강 어브바카        PKS-M08K01S  D4GA  2008
#
# [25031 rows x 8 columns]

# %%
df.loc[(df['배출가스인증번호'] == '7MY-HD-24-28') & (df['DPF유무_수정'] == '확인불가'), '제작사명'].unique()
# Out:
# array(['자기인증면제차량', '현대자동차(주)', '(주)애드터치', '(주) 오텍', '수성특장(주)', '(주)지엠케이',
#        '(주)광림', '(주)성진테크', '원진(주)', '주식회사 평강비아이엠(B.I.M)', '(주)새한에어서스펜션',
#        '(주)수산씨에스엠', '(주)호룡', '엠에스특장공업(주)', '(주)화이어텍', '(주)드림티엔에스',
#        '(주)동해기계항공', '(주)다산중공업', '신제일정공(주)', '(주) 삼오특장자동차', '(주)세인이엔지',
#        '영일특장(주)', '(주)동양특장', '창림모아츠(주)', '주식회사 유아이테크', '주식회사 한서정공',
#        '한빛테크원(주)', '동양자동차공업(주)', '(주)신광테크놀러지', '(주)삼성특장', '한신특장',
#        '(유)삼능기계', '(주)방원테크', '녹산대진특장차', '(주) 에이엠특장', '신성엔지니어링', '반도특장(주)',
#        '(주)진우에스엠씨', '(주)에코카', '(주)태경이엔지', '(주)한국차체', '원천특장공업주식회사',
#        '(주)뉴텍티앤엠', '(주) 골드밴', '주식회사 카셈(KASEM Co.,Ltd)', '주식회사 천하',
#        '이텍산업 주식회사', '정우정공 (주)', '선진정공(주)', '한아에스에스(주)', '(주)노바스코리아',
#        '제일F.R.P산업', '(주)가이젠캠핑카'], dtype=object)

# %%
df.loc[(df['배출가스인증번호'] == '7MY-HD-24-28') & (df['DPF유무_수정'] == '유'), '제작사명'].unique()
# Out:
# array(['현대자동차(주)', '자기인증면제차량'], dtype=object)

# %% [markdown]
# ## [🔺] 동일인증번호 차량 중 배출가스 저감창치 장착된 차량 있음. 확인 필요
# -  p_DPF 장착으로 '유' 확인

# %%
text = '동일인증번호 차량 중 배출가스 저감창치 장착된 차량 있음. 확인 필요'
check = func(text)
check
# Out:
# (10751, 10)
#                      차대번호             제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 769902  KMJNN18KP9C001032  A0810005801672209  7MY-HD-24-30      4        유
# 769903  KMJNN18KP8C000067  A0810005700922207  7MY-HD-24-30      4        유
# 769904  KMFLA18KP9C041990  A0810005211193309  7MY-HD-24-30      4        유
# 769905  KMFLA18KP9C039345  A0810005210053308  7MY-HD-24-30      4        유
# 769906  KMCLK18KPAC050202  A0810005212813309  7MY-HD-24-30      4        유
# ...                   ...                ...           ...    ...      ...
# 779935  KMJNN18KP9C000779  A0810005801622309  7MY-HD-24-30      4        유
# 780255  KMCLK18KP8C029778  A0810005209223308  7MY-HD-24-30      4        유
# 780340  KMFLA18KP9C041884  A0810005211683209  7MY-HD-24-30      4        유
# 780591  KMFLA18KP9C041027  A0810005211583209  7MY-HD-24-30      4        유
# 780653  KMCLK18KP8C035195  A0810005209353308  7MY-HD-24-30      4        유
#
#                차명      제작사명               자동차형식  엔진형식    연식
# 769902    이-에어로타운  현대자동차(주)       HSU34-9Gb-TB1  D6GA  2009
# 769903    이-에어로타운  현대자동차(주)        HDB34-8Ga-BF  D6GA  2008
# 769904       메가트럭  현대자동차(주)       HD5CT-9EGd-TE  D6GA  2009
# 769905       메가트럭  현대자동차(주)    HD4.5CT-9EPGd-ZE  D6GA  2009
# 769906     메가트럭암롤  현대자동차(주)   HD050-10AR0-SGd-Z  D6GA  2010
# ...           ...       ...                 ...   ...   ...
# 779935    이-에어로타운  현대자동차(주)        HSU36-9Gb-BS  D6GA  2009
# 780255  메가트럭크레인카고  현대자동차(주)  HD050-8CN1-EUGd-Z2  D6GA  2008
# 780340       메가트럭  현대자동차(주)   HD4.5CT-9NEGdd-AM  D6GA  2009
# 780591       메가트럭  현대자동차(주)    HD4.5CT-9LGdd-AM  D6GA  2009
# 780653  메가트럭군물자수송  현대자동차(주)    HD050-8MT2-LGc-A  D6GA  2008
#
# [293 rows x 10 columns]

# %%
df.loc[df['배인번호_수정'] == '7MY-HD-24-30', 'DPF유무_수정'].value_counts()
# Out:
# 유    10751
# Name: DPF유무_수정, dtype: int64

# %% [markdown]
# ## [🔺] DPF 장착 확인(무, 확인불가)
# - '확인불가' 수정 예정

# %%
text = 'DPF 장착 확인(무, 확인불가)'
func(text)
# Out:
# (1, 9)
#                  제원관리번호       배인번호_수정  등급_수정 DPF유무_수정        차명      제작사명  \
# 780704  32701000000000   7MY-PA-13-11      4        무  랜드로버프리랜더  자기인증면제차량
#
#         자동차형식   엔진형식    연식
# 780704  FA24B  224DT  2008

# %%
df.loc[df['배인번호_수정'] == '7MY-PA-13-11', 'DPF유무_수정'].value_counts()
# Out:
# 확인불가    677
# 무         1
# Name: DPF유무_수정, dtype: int64

# %% [markdown]
# ## [🔺] PDF 확인불가
# - '확인불가' 수정 예정

# %%
text = 'PDF 확인불가'
func(text)
# Out:
# (1, 9)
#                  제원관리번호      배인번호_수정  등급_수정 DPF유무_수정           차명      제작사명  \
# 780705  34106000000000   7MY-PA-14-1      4        무  디스커버리3 TDV6  자기인증면제차량
#
#         자동차형식  엔진형식    연식
# 780705  0F4AD  4R80  2005

# %%
df.loc[df['차명'] == '디스커버리3 TDV6', 'DPF유무_수정'].value_counts()
# Out:
# 확인불가    428
# 무         1
# Name: DPF유무_수정, dtype: int64

# %%
df.loc[df['차명'] == '디스커버리3 TDV6', '배인번호_수정'].value_counts()
# Out:
# 7MY-PA-14-1    429
# Name: 배인번호_수정, dtype: int64

# %% [markdown]
# ## [⭕] TDV6 DPF장착 확인 무, 확인불가
# - 확인불가

# %%
text = 'TDV6 DPF장착 확인 무, 확인불가'
func(text)
# Out:
# (162, 10)
#                      차대번호             제원관리번호      배인번호_수정  등급_수정 DPF유무_수정  \
# 780706  SALLSAA149A193850  4220000000000000   7MY-PA-14-2      4        무
# 780709  SALLSAA149A190723   920002000000000   7MY-PA-14-2      4        무
# 780718  SALLSAA648A165266   920002000000000   7MY-PA-14-2      4        무
# 942884  SALLSAA147A112700   920002000000000   7MY-PA-14-2      4     확인불가
# 942886  SALLSAA148A132982   920002000000000   7MY-PA-14-2      4     확인불가
# 942989  SALLSAA147A108300    32826000000000   7MY-PA-14-2      4     확인불가
#
#                     차명           제작사명 자동차형식   엔진형식    연식
# 780706  레인지로버 스포츠 TDV6  (주)재규어랜드로버코리아    LS  276DT  2009
# 780709  레인지로버 스포츠 TDV6    (주)볼보자동차코리아    LS  276DT  2009
# 780718  레인지로버 스포츠 TDV6    (주)볼보자동차코리아    LS  276DT  2008
# 942884  레인지로버 스포츠 TDV6    (주)볼보자동차코리아    LS  276DT  2007
# 942886  레인지로버 스포츠 TDV6    (주)볼보자동차코리아    LS  276DT  2008
# 942989    레인지로버스포츠TDV6    (주)볼보자동차코리아    LS  276DT  2007

# %%
df.loc[df['비고'] == text, 'DPF유무_수정'].value_counts()
# Out:
# 확인불가    141
# 무        21
# Name: DPF유무_수정, dtype: int64

# %% [markdown]
# ## [❓] 짚 그랜드 체로키 8MY-DK-14-01 배출가스 인증번호 현재 3등급으로 분류 중
# - 동일 배번 3등급 샘플(⭕)

# %%
text = '짚 그랜드 체로키 8MY-DK-14-01 배출가스 인증번호 현재 3등급으로 분류 중'
func(text)
# Out:
# (137, 9)
#                   제원관리번호       배인번호_수정  등급_수정 DPF유무_수정         차명  \
# 782479  220005000000000   8MY-DK-14-01      4     확인불가  짚 그랜드 체로키
# 782480  220005000000000   8MY-DK-14-01      4     확인불가  짚 그랜드 체로키
#
#                제작사명 자동차형식    엔진형식    연식
# 782479  에프씨에이코리아(주)    WH  642980  2009
# 782480  에프씨에이코리아(주)    WH  642980  2008

# %%
g3.loc[g3['차명'] == '짚 그랜드 체로키', check_col]
# Out:
#                     제원관리번호 배출가스인증번호 배출가스등급         차명         제작사명 자동차형식  \
# 868312   00220001000021303      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WJ
# 901920   00220001000021303      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WJ
# 910884   00220001000021303      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WJ
# 912208   00220001000021303      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WJ
# 914141   00220001000021303      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WJ
# ...                    ...      ...    ...        ...          ...   ...
# 2413382  00220004500051309      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WH
# 2414297  00220004500051309      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WH
# 2427827  00220004500051309      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WH
# 2428906  00220004500051309      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WH
# 2437088  00220004500051309      NaN      3  짚 그랜드 체로키  에프씨에이코리아(주)    WH
#
#            엔진형식  차량연식
# 868312      661  2004
# 901920      661  2004
# 910884      661  2004
# 912208      661  2004
# 914141      661  2004
# ...         ...   ...
# 2413382  642980  2010
# 2414297  642980  2010
# 2427827  642980  2010
# 2428906  642980  2010
# 2437088  642980  2010
#
# [131 rows x 8 columns]

# %%
g3.loc[g3['차명'] == '짚 그랜드 체로키', '배출가스인증번호'].unique()
# Out:
# array([nan], dtype=object)

# %% [markdown]
# ## [❓] 짚 그랜드 체로키 동일 제원관리번호 차량 4,5등급 혼재, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중
# - 동일 배번 3등급 샘플(⭕)
# - 동일 제번 5등급 샘플(❌)

# %%
text = '짚 그랜드 체로키 동일 제원관리번호 차량 4,5등급 혼재, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중'
func(text)
# Out:
# (107, 10)
#                      차대번호            제원관리번호       배인번호_수정  등급_수정 DPF유무_수정  \
# 782483  1J8HCE8M17Y557695  220005000000000   8MY-DK-14-01      4     확인불가
#
#                차명         제작사명 자동차형식    엔진형식    연식
# 782483  짚 그랜드 체로키  에프씨에이코리아(주)    WH  642980  2007

# %%
df.loc[df['비고'] == text, '제원관리번호'].unique()
# Out:
# array(['220005000000000 '], dtype=object)

# %%
df.loc[df['제원관리번호'] == '220005000000000 '].shape
# Out:
# (1512, 36)

# %%
df.loc[df['제원관리번호'] == '220005000000000 ', '등급_수정'].unique()
# Out:
# array([4], dtype=int64)

# %%
g5.loc[g5['제원관리번호'] == '220005000000000' , check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g5.loc[g5['제원관리번호'] == '220005000000000 ' , check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g3.loc[g3['제원관리번호'] == '220005000000000' , check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g3.loc[g3['제원관리번호'] == '220005000000000 ' , check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
df.loc[df['비고'] == text, '제원관리번호'].unique()
# Out:
# array(['220005000000000 '], dtype=object)

# %%
g3.loc[g3['배출가스인증번호'] == '8MY-DK-14-01'].shape
# Out:
# (18, 49)

# %%
g3.loc[g3['배출가스인증번호'] == '8MY-DK-14-01', check_col]
# Out:
#                     제원관리번호      배출가스인증번호 배출가스등급       차명         제작사명 자동차형식  \
# 8378882  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8384897  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8386089  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8397586  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8406770  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8409284  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8409285  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8410388  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8410389  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8410604  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8439673  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8455810  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8455811  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8456408  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8461382  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8467641  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8470373  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
# 8470512  00220008900011319  8MY-DK-14-01      3  짚그랜드체로키  에프씨에이코리아(주)    WK
#
#         엔진형식  차량연식
# 8378882    M  2019
# 8384897    M  2019
# 8386089    M  2019
# 8397586    M  2019
# 8406770    M  2019
# 8409284    M  2019
# 8409285    M  2019
# 8410388    M  2019
# 8410389    M  2019
# 8410604    M  2019
# 8439673    M  2019
# 8455810    M  2019
# 8455811    M  2019
# 8456408    M  2019
# 8461382    M  2019
# 8467641    M  2019
# 8470373    M  2019
# 8470512    M  2019

# %% [markdown]
# ## [❓] 짚 그랜드 체로키 동일 제원관리번호 차량 5등급, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중
# - 동일 배번 3등급 샘플(⭕)
# - 동일 제번 5등급 샘플(❌)

# %%
text = '짚 그랜드 체로키 동일 제원관리번호 차량 5등급, 8MY-DK-14-01 배출가스 인증번호 3등급 분류중'
func(text)
# Out:
# (4, 9)
#                   제원관리번호       배인번호_수정  등급_수정 DPF유무_수정       차명         제작사명  \
# 782492  220005000000000   8MY-DK-14-01      4     확인불가  짚그랜드체로키  에프씨에이코리아(주)
#
#        자동차형식     엔진형식    연식
# 782492    WH  642 980  2007

# %%
g5.loc[g5['제원관리번호'] == '220005000000000 ', check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g5.loc[g5['제원관리번호'] == '220005000000000', check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g5.loc[g5['제원관리번호'] == 220005000000000, check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %% [markdown]
# ## [❓] 짚 그랜드 체로키 동일 배출가스인증번호, 동일제원관리번호 3등급으로 분류 되어있음.
# - 동일 배번 3등급 샘플(⭕)
# - 동일 제번 3등급 샘플(❌)

# %%
text = '짚 그랜드 체로키 동일 배출가스인증번로, 동일제원관리번호 3등급으로 분류 되어있음.'
func(text)
# Out:
# (1, 9)
#                   제원관리번호       배인번호_수정  등급_수정 DPF유무_수정       차명         제작사명  \
# 849572  220007000000000   8MY-DK-14-01      4     확인불가  짚그랜드체로키  에프씨에이코리아(주)
#
#        자동차형식   엔진형식    연식
# 849572    WK  VM23D  2012

# %%
df.loc[df['제원관리번호'] == '220007000000000 ', '등급_수정'].unique()
# Out:
# array([4], dtype=int64)

# %%
g3.loc[g3['제원관리번호'] == '220007000000000 ', check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g3.loc[g3['제원관리번호'] == '220007000000000', check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g3.loc[g3['제원관리번호'] == 220007000000000, check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g3.loc[g3['제원관리번호'] == '00220007000000000 ', check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %%
g3.loc[g3['제원관리번호'] == '00220007000000000', check_col]
# Out:
# Empty DataFrame
# Columns: [제원관리번호, 배출가스인증번호, 배출가스등급, 차명, 제작사명, 자동차형식, 엔진형식, 차량연식]
# Index: []

# %% [markdown]
# ### [샘플] 3등급 동일 배번

# %%
g3.loc[g3['배출가스인증번호'] == '8MY-DK-14-01'].shape
# Out:
# (18, 49)

# %%
g3.loc[g3['배출가스인증번호'] == '8MY-DK-14-01'].to_csv(os.path.join(sample_fold, '샘플 3등급 등록&제원 8MY-DK-14-01.csv'), encoding='cp949', index=False)

# %% [markdown]
# ### [샘플] 5등급 동일 배번(❌)

# %%
g5.loc[g5['배출가스인증번호'] == '8MY-DK-14-01'].shape
# Out:
# (0, 49)

# %% [markdown]
# ## [⭕] 제원관리번호 확인 04220000400031308
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '제원관리번호 확인 04220000400031308'
func(text)
# Out:
# (34, 9)
#                    제원관리번호       배인번호_수정  등급_수정 DPF유무_수정               차명  \
# 999652  4220000000000000   8MY-PA-14-04      4     확인불가  재규어 X-TYPE 2.2D
#
#                  제작사명        자동차형식 엔진형식    연식
# 999652  (주)재규어랜드로버코리아  X-TYPE 2.2D   BG  2009

# %% [markdown]
# ## [⭕] 제원관리번호 확인 04220000400041309
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '제원관리번호 확인 04220000400041309'
func(text)
# Out:
# (15, 9)
#                    제원관리번호       배인번호_수정  등급_수정 DPF유무_수정               차명  \
# 999655  4220000000000000   8MY-PA-14-04      4     확인불가  재규어 X-TYPE 2.2D
#
#                  제작사명        자동차형식 엔진형식    연식
# 999655  (주)재규어랜드로버코리아  X-TYPE 2.2D   BG  2010

# %% [markdown]
# ## [⭕] 제원관리번호 확인 04220000800021308
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '제원관리번호 확인 04220000800021308'
func(text)
# Out:
# (120, 9)
#                    제원관리번호       배인번호_수정  등급_수정 DPF유무_수정           차명  \
# 999731  4220000000000000   8MY-PA-14-05      4     확인불가  재규어 XF 2.7D
#
#                  제작사명    자동차형식 엔진형식    연식
# 999731  (주)재규어랜드로버코리아  XF 2.7D   7G  2009

# %% [markdown]
# ## [⭕] 제원관리번호 확인 04220000800031308
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '제원관리번호 확인 04220000800031308'
func(text)
# Out:
# (17, 9)
#                    제원관리번호       배인번호_수정  등급_수정 DPF유무_수정           차명  \
# 999767  4220000000000000   8MY-PA-14-05      4     확인불가  재규어 XF 2.7D
#
#                  제작사명    자동차형식 엔진형식    연식
# 999767  (주)재규어랜드로버코리아  XF 2.7D   7G  2009

# %% [markdown]
# ## [❓] 봉고3 8MY-KM-13-19 동일 배출가스 인증번호 3, 4등급 혼재 위 차량은 4등급 DPF장착 차량이며 저공해 인증차량 09,10년식 등급제 반영되어있음
# - 동일 배번 3등급 샘플

# %%
text = '봉고3 8MY-KM-13-19 동일 배출가스 인증번호 3, 4등급 혼재 위 차량은 4등급 DPF장착 차량이며 저공해 인증차량 09,10년식 등급제 반영되어있음'
func(text)
# Out:
# (934, 9)
#                     제원관리번호       배인번호_수정  등급_수정 DPF유무_수정      차명      제작사명  \
# 1000444  A0110003116593108  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1000446  A0110003116633108  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1000451  A0110003116673108  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1000458  A0110003117293109  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1000459  A0110003116613108  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1000473  A0110003117313109  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1000579  A0110003117303109  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1000762  A0110003117323109  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1001006  A0110003116693108  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
# 1001177  A0110003116663108  8MY-KM-13-19      4        유  봉고Ⅲ 1톤  기아자동차(주)
#
#                   자동차형식 엔진형식    연식
# 1000444   SEL42K-L-A-EM   J3  2009
# 1000446     SEL42K-A-EM   J3  2009
# 1000451    SEL42K-AF-EM   J3  2009
# 1000458     PUL4AA-L-EM   J3  2010
# 1000459  SEL42K-L-AF-EM   J3  2009
# 1000473       PUL4AA-EM   J3  2010
# 1000579   PUL4AA-L-F-EM   J3  2010
# 1000762     PUL4AA-F-EM   J3  2010
# 1001006   SEL42K-ABF-EM   J3  2009
# 1001177    SEL42K-AB-EM   J3  2009

# %%
df.loc[df['배인번호_수정'] == '8MY-KM-13-19', '등급_수정'].value_counts()
# Out:
# 4    934
# Name: 등급_수정, dtype: int64

# %% [markdown]
# ### [샘플] 동일 배번 3등급

# %%
g3.loc[g3['배출가스인증번호'] == '8MY-KM-13-19'].shape
# Out:
# (5116, 49)

# %%
g3.loc[g3['배출가스인증번호'] == '8MY-KM-13-19'].to_csv(os.path.join(sample_fold, '샘플 3등급 8MY-KM-13-19.csv'), encoding='cp949', index=False)

# %% [markdown]
# ## [⭕] (23.2.15)볼보차량 2,003대 4등급 -> 3등급 조정
# - 공단에서 수정된 사실 확인을 표시함.

# %%
text = '(23.2.15)볼보차량 2,003대 4등급 -> 3등급 조정'
func(text)
# Out:
# (2005, 9)
#                     제원관리번호        배인번호_수정  등급_수정 DPF유무_수정             차명  \
# 1145708  BRX20001900003314  CMY-VTK-14-01      3        유  FM 10x4 윙바디트럭
# 1145709  BRX20001400003313  CMY-VTK-14-01      3        유    FM10x4윙바디트럭
# 1145710  1120000000000000   CMY-VTK-14-02      3        유  Quon 6x4 카고트럭
# 1145712  BRX20000600003312  CMY-VTK-14-02      3        유   Quon6X4윙바디트럭
# 1145715  1120000000000000   CMY-VTK-14-02      3        유  Quon 6x4 카고트럭
# 1145734  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1145735  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1145736  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1145740  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1145744  1120000000000000    FMY-VTK-14-1      3        유          FH 카고
# 1145746  1120000000000000    FMY-VTK-14-1      3        유          FM 카고
# 1145760  BRX20004600003317   FMY-VTK-14-1      3        유          FM 카고
# 1145769  BRX20004200013316   FMY-VTK-14-1      3        유          FM 카고
# 1145774  BRX20004600013317   FMY-VTK-14-1      3        유          FM 카고
# 1145802  1120000000000000    FMY-VTK-14-1      3        유          FH 카고
# 1145821  BRX20004200003316   FMY-VTK-14-1      3        유          FM 카고
# 1145837  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1145852  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1145873  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1145960  BRX20003900003315   FMY-VTK-14-1      3        유          FH 카고
# 1146018  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1146033  1120000000000000    FMY-VTK-14-1      3        유          FH 카고
# 1146043  1120000000000000    FMY-VTK-14-1      3        유          FM 카고
# 1146129  1120000000000000    FMY-VTK-14-1      3        유          FM 카고
# 1146498  1120000000000000    FMY-VTK-14-1      3        유         FH 트랙터
# 1146623  1120000000000000    FMY-VTK-14-1      3        유          FH 카고
# 1146662  1120000000000000    FMY-VTK-14-1      3        유          FM 카고
# 1147515  1120000000000000    FMY-VTK-14-2      3        유          FM 카고
# 1147516  1120000000000000    FMY-VTK-14-2      3        유          FM 카고
# 1147517  1120000000000000    FMY-VTK-14-2      3        유          FM 카고
# 1147518  1120000000000000    FMY-VTK-14-2      3        유          FM 카고
# 1147520  1120000000000000    FMY-VTK-14-2      3        유          FM 카고
# 1147521  1120000000000000    FMY-VTK-14-2      3        유          FM 카고
# 1147552  BRX20004000003315   FMY-VTK-14-2      3        유          FM 카고
# 1147571  1120000000000000    FMY-VTK-14-2      3        유          FM 카고
# 1147602  1120000000000000    FMY-VTK-14-3      3        유          FL 카고
# 1147603  1120000000000000    FMY-VTK-14-3      3        유          FL 카고
# 1147604  1120000000000000    FMY-VTK-14-3      3        유          FL 카고
# 1147605  1120000000000000    FMY-VTK-14-3      3        유          FL 카고
# 1147606  BRX20003400013315   FMY-VTK-14-3      3        유      FL4X2카고트럭
# 1147613  BRX20003300013315   FMY-VTK-14-3      3        유      FL4X2카고트럭
# 1147617  BRX20004500003316   FMY-VTK-14-3      3        유          FL 카고
# 1147620  BRX20004500013316   FMY-VTK-14-3      3        유          FL 카고
# 1147623  BRX20004800003317   FMY-VTK-14-3      3        유         FE 윙바디
# 1147626  1120000000000000    FMY-VTK-14-3      3        유          FL 카고
# 1147638  BRX20003400003315   FMY-VTK-14-3      3        유      FL4X2카고트럭
# 1147651  BRX20004400003316   FMY-VTK-14-3      3        유          FL 카고
# 1147669  BRX20004700003317   FMY-VTK-14-3      3        유          FE 카고
# 1147678  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147679  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147680  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147681  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147683  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147684  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147685  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147686  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147689  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147695  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147700  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
# 1147722  1120000000000000    FMY-VTK-14-4      3        유         FH 트랙터
#
#                제작사명        자동차형식  엔진형식    연식
# 1145708  볼보트럭코리아(주)   N0TSWC452I   D11  2014
# 1145709  볼보트럭코리아(주)   N0TSWC451I   D11  2013
# 1145710  볼보트럭코리아(주)   CWB5ELZHLS  GH11  2014
# 1145712  볼보트럭코리아(주)   CWB5ELWHLS  GH11  2013
# 1145715  볼보트럭코리아(주)   CWB5ELWHLS  GH11  2013
# 1145734  볼보트럭코리아(주)    FH62TT3HA   D13  2016
# 1145735  볼보트럭코리아(주)    FH62TT3HA   D13  2017
# 1145736  볼보트럭코리아(주)    FH62TT3HA   D13  2018
# 1145740  볼보트럭코리아(주)    FH62TT3HA   D13  2015
# 1145744  볼보트럭코리아(주)  FH104FTR3HA   D13  2017
# 1145746  볼보트럭코리아(주)  FM104FTR3HA   D13  2017
# 1145760  볼보트럭코리아(주)  FM104FTR3HA   D13  2017
# 1145769  볼보트럭코리아(주)  FM104FTR3HA   D13  2017
# 1145774  볼보트럭코리아(주)  FM104FTR3HA   D13  2018
# 1145802  볼보트럭코리아(주)    FH84TR3HA   D13  2016
# 1145821  볼보트럭코리아(주)  FM104FTR3HA   D13  2016
# 1145837  볼보트럭코리아(주)     FH64T3HA   D13  2017
# 1145852  볼보트럭코리아(주)     FH64T3HA   D13  2016
# 1145873  볼보트럭코리아(주)     FH64T3HA   D13  2018
# 1145960  볼보트럭코리아(주)  FH104FTR3HA   D13  2016
# 1146018  볼보트럭코리아(주)     FH64T3HA   D13  2015
# 1146033  볼보트럭코리아(주)  FH104FTR3HA   D13  2016
# 1146043  볼보트럭코리아(주)  FM104FTR3HA   D13  2016
# 1146129  볼보트럭코리아(주)  FM104FTR3HA   D13  2018
# 1146498  볼보트럭코리아(주)     FH42T3HA   D13  2017
# 1146623  볼보트럭코리아(주)     FH64R3HA   D13  2017
# 1146662  볼보트럭코리아(주)    FM84TR3HA   D13  2016
# 1147515  볼보트럭코리아(주)     FM64R1HB   D11  2015
# 1147516  볼보트럭코리아(주)     FM64R1HB   D11  2016
# 1147517  볼보트럭코리아(주)     FM64R1HA   D11  2017
# 1147518  볼보트럭코리아(주)     FM64R1HA   D11  2015
# 1147520  볼보트럭코리아(주)     FM64R1HA   D11  2016
# 1147521  볼보트럭코리아(주)     FM64R1HB   D11  2017
# 1147552  볼보트럭코리아(주)  FM104FTR1HA   D11  2016
# 1147571  볼보트럭코리아(주)     FM64R1HA   D11  2018
# 1147602  볼보트럭코리아(주)    FL42R814L    D8  2016
# 1147603  볼보트럭코리아(주)    FL42R814L    D8  2015
# 1147604  볼보트럭코리아(주)    FL42R814L    D8  2017
# 1147605  볼보트럭코리아(주)    FL42R818L    D8  2017
# 1147606  볼보트럭코리아(주)    FL42R814L    D8  2016
# 1147613  볼보트럭코리아(주)    FL42R814L    D8  2016
# 1147617  볼보트럭코리아(주)    FL42R814L    D8  2016
# 1147620  볼보트럭코리아(주)    FL42R814L    D8  2017
# 1147623  볼보트럭코리아(주)       FE64RB    D8  2017
# 1147626  볼보트럭코리아(주)    FL42R818L    D8  2016
# 1147638  볼보트럭코리아(주)    FL42R814L    D8  2015
# 1147651  볼보트럭코리아(주)    FL42R814L    D8  2016
# 1147669  볼보트럭코리아(주)       FE64RB    D8  2017
# 1147678  볼보트럭코리아(주)    FH62TT6HA   D16  2016
# 1147679  볼보트럭코리아(주)     FH64T6HT   D16  2016
# 1147680  볼보트럭코리아(주)     FH64T6HT   D16  2017
# 1147681  볼보트럭코리아(주)     FH64T6HA   D16  2018
# 1147683  볼보트럭코리아(주)    FH62TT6HA   D16  2017
# 1147684  볼보트럭코리아(주)     FH64T6HT   D16  2018
# 1147685  볼보트럭코리아(주)     FH64T6HA   D16  2017
# 1147686  볼보트럭코리아(주)    FH62TT6HA   D16  2015
# 1147689  볼보트럭코리아(주)     FH64T6HA   D16  2016
# 1147695  볼보트럭코리아(주)    FH62TT6HA   D16  2018
# 1147700  볼보트럭코리아(주)     FH64T6HT   D16  2015
# 1147722  볼보트럭코리아(주)     FH64T6HA   D16  2015

# %% [markdown]
# # 출력

# %%
total = pd.DataFrame()
for one in df['비고'].unique():
    total = pd.concat([total, df.loc[df['비고'] == one]], ignore_index=True)
total.shape
# Out:
# (46458, 36)

# %%
total.to_csv(os.path.join(raw_fold, '샘플_result_비고.csv'), index=False, encoding='cp949')

# %% [markdown]
# # 한불모터스 샘플

# %%
df['제작사명'].unique()
# Out:
# array(['아우디폭스바겐코리아(주)', '타타대우상용차(주)', '(주)볼보자동차코리아', '자기인증면제차량',
#        '비엠더블유코리아(주)', '한불모터스(주)', '현대자동차(주)', '기아자동차(주)', '스카니아코리아그룹(주)',
#        '쌍용자동차(주)', '볼보트럭코리아(주)', '자일대우상용차 주식회사', '한국지엠주식회사',
#        '지엠아시아퍼시픽지역본부 주식회사', '메르세데스벤츠코리아(주)', '다임러트럭코리아(주)', '에프씨에이코리아(주)',
#        '(주) 맥써버모터스', '로쏘엠', '(주)재규어랜드로버코리아', '르노삼성자동차(주)', '만트럭버스코리아(주)',
#        '포드세일즈서비스코리아(유)', '(주) 골드밴', '(주)한국쓰리축', '한국특장기술(주)', '(주)포멕특장',
#        '(주)함코', '한국쓰리축공업(주)', '고려특장(주)', '(주)우양', '제일F.R.P산업', '(주)한국토미',
#        '(주) 에이엠특장', '해광산업사', '(주)광림', '(주)한국메리트특장', '코리아특장', '한국상용트럭(주)',
#        '한빛테크원(주)', '(주)새한에어서스펜션', '탱크코리아(주)', '정부쓰리축', '(주) 삼오특장자동차',
#        '(주)신광테크놀러지', '(주)한성특장', '(주)화인특장', '부커셰링코리아 (주)', '신정개발특장차 주식회사',
#        '(주)나노메딕스', '(주)한국차체', '(주)미동이엔씨', '(주)태경이엔지', '(주)화이어텍',
#        '디앨 주식회사', '남영코리아화이어트럭(주)', '(주)에이엔디오토모빌', '신제일정공(주)', '(주)우리특장',
#        '(주)뉴테크특장', '반도특장(주)', '정우정공 (주)', '주식회사 유아이테크', '수성특장(주)',
#        '(주)동해기계항공', '(주) 오텍', '주식회사 평강비아이엠(B.I.M)', '(주)호룡', '(주)지엠케이',
#        '(주)사자후', '(주)무빙애드', '한아에스에스(주)', '주식회사 천하', '창림모아츠(주)', '대구시소방본부',
#        '(주)에버다임', '건민특장 주식회사', '(주)승신', '세화자동차', '(주)애드터치', '(주)에이엠티코리아',
#        '드림특장(주)', '제이에스이엔지', '(주)용진특장', '(주)엠뱅크', '(주)드림티엔에스', '라헬(주)',
#        '동아특장공업사', '녹산대진특장차', '(주) 고호산업', '에스알(주)',
#        '주식회사 카셈(KASEM Co.,Ltd)', '(주)다산중공업', '(주)에코카', '(주)비오에프인베스트먼트',
#        '로버코리아(주)', '(주)팔도', '영일특장(주)', '(주)방원테크', '원천특장공업주식회사', '(주)동양특장',
#        '(유)삼능기계', '(주)부성특장', '(주)수산중공업', '(주) 두성하-드텍', '한신특장', '(주)대양특장',
#        '(주) 강남기공', '(주) 진화이앤씨', '한국특장 (주)', '대지정공(주)', '삼우중공업(주)',
#        '한국후3축', '베스텍특장', '(주)우성특장', '주식회사 씨엔에스티', '일성산업', '(주)서보테크',
#        '대경특장(주)', '(주)노바스코리아', '동양자동차공업(주)', '선진정공(주)', '동아탑정비공업사',
#        '카고텍코리아(주)', '광림특장차 주식회사', '(주)수산씨에스엠', '(주)세인이엔지', '씨제이대한통운(주)',
#        '형제특장 주식회사', '대흥특장정공 (주)', '유비통상(주)', '계백자동차(주)', '대한특장', '카써스(주)',
#        '(유)대원오토', '(주)세정모터스', '해양산업', '씨엔라인', '(주)삼부', '(주) 메인모터스',
#        '흥국정공 (주)', '한국텍(주)', '진우기계', '우림특장산업', '(주)화성특장', '(주)한성티앤아이',
#        '(주)한국특장기술', '신영특장엠엔씨(주)', '(주)디투에스', nan, '(주) 두성특장차', '한특사료차',
#        '디와이(주) 익산공장', '동일석유(주)', '(주)성원테크', '태극자동차공업사', '(주)위더스지',
#        '나인특장자동차정비(주)', '(주)알텍', '(주)밴텍캠핑카', '이텍산업 주식회사', '주식회사 한서정공',
#        '고려에스티엠(주)', '(주)성진테크', '원진(주)', '엠에스특장공업(주)', '(주)삼성특장',
#        '신성엔지니어링', '(주)진우에스엠씨', '(주)뉴텍티앤엠', '(주)가이젠캠핑카', '(주)케이지비고려골든박스',
#        '(주)대진정공', '도원자동차공업 (주)', '동진특장', '(주)마노', '카올넷', '(주)엘위포투',
#        '(주)맥스리무진', '한국상용차(주)', '더유니코오토(주)', '동우인더스(주)', '(주) 대진에스티씨',
#        '(주)크린텍', '라인호(주)', '한국오토모빌얼라이언스(주)', '(주)중평', '대덕',
#        'SK에너지(주)울산COMPLEX', '디에스아이코리아피티와이엘티디', '씨엔에스코퍼레이션(주)', '영원과학(주)',
#        '네오플란오토모빌코리아(주)', '한국도로공사', '대동안전(주)', '(주)한일', '(주)동진특수',
#        '한국공항공사', '지에스칼텍스(주)', '에스티에이컴퍼니(주)', '주식회사 우레아텍', '한국아이비금융(주)',
#        '(주)세기통운', '강원도청', '한성자동차(주)', '서울특별시소방재난본부', '충청남도청', '전라남도소방본부',
#        '비스너코리아 주식회사', '성진지오텍(주)', '서울시보건환경연구원', '신아특장', '(주)프로덕션툴즈',
#        '(주)동방', '대한예수교장로회평강제일교회', '길우상사(주)', '서울시티투어버스(주)'], dtype=object)

# %%
sample_fold
# Out:
# 'D:/data/big2/result/sample'

# %%
df[df['제작사명'] == '한불모터스(주)'].shape
# Out:
# (2668, 36)

# %%
df[df['제작사명'] == '한불모터스(주)'].to_csv(os.path.join(sample_fold, '샘플 한불모터스(주).csv'), index=False, encoding='cp949')

# %% [markdown]
# # 코드 마지막
