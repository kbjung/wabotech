# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os

# %%
grade = 1
ods_folder = 'D:\과업\[한국환경공단]자동차_환경_빅데이터_구축_2차\data\ODS'
file_name = f'[ODS][G{grade}]등록정보&제원정보(말소적용)(한글컬럼)(2022.12.29).csv'
ods_path = os.path.join(ods_folder, file_name)

# %% [markdown]
# # 로드

# %%
# about 2m
df = pd.read_csv(ods_path, encoding='cp949')
df.info()
# Out:
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_9992\958948311.py:2: DtypeWarning: Columns (14,15,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(ods_path, encoding='cp949')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11207727 entries, 0 to 11207726
# Data columns (total 49 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   차량관리번호        object
#  1   차량등록번호        object
#  2   본거지법정동코드      int64
#  3   소유자구분         object
#  4   차종_등록정보       object
#  5   용도            object
#  6   현재회원번호        object
#  7   차대번호          object
#  8   최초등록일자        int64
#  9   차량연식          int64
#  10  차량제작일자        float64
#  11  배출가스검사유효일자    float64
#  12  제원관리번호        object
#  13  배출가스인증번호      object
#  14  배출가스등급        object
#  15  저공해조치YN(미사용)  object
#  16  저공해조치종류       float64
#  17  저공해조치구조변경YN   object
#  18  차량등록번호숫자정보    int64
#  19  차량말소YN        object
#  20  최초회원번호        object
#  21  취득일자          float64
#  22  취득금액          float64
#  23  생성일시_등록정보     object
#  24  수정일시_등록정보     object
#  25  차명            object
#  26  차종_제원정보       object
#  27  차종분류          object
#  28  차종유형(소분류)     object
#  29  자동차형식         object
#  30  제작사명          object
#  31  연료            object
#  32  엔진형식          object
#  33  공차중량          float64
#  34  총중량           float64
#  35  적재중량          float64
#  36  엔진출력          float64
#  37  배기량           float64
#  38  승차인원          float64
#  39  차량길이          float64
#  40  차량너비          float64
#  41  차량높이          float64
#  42  원산지명          object
#  43  삭제YN          object
#  44  승인일자          float64
#  45  구동형식          float64
#  46  변속기종류         object
#  47  생성일시_제원정보     object
#  48  수정일시_제원정보     object
# dtypes: float64(16), int64(4), object(29)
# memory usage: 4.1+ GB

# %% [markdown]
# # 전처리
# - 전기차 제외

# %%
df.columns
# Out:
# Index(['차량관리번호', '차량등록번호', '본거지법정동코드', '소유자구분', '차종_등록정보', '용도', '현재회원번호',
#        '차대번호', '최초등록일자', '차량연식', '차량제작일자', '배출가스검사유효일자', '제원관리번호', '배출가스인증번호',
#        '배출가스등급', '저공해조치YN(미사용)', '저공해조치종류', '저공해조치구조변경YN', '차량등록번호숫자정보',
#        '차량말소YN', '최초회원번호', '취득일자', '취득금액', '생성일시_등록정보', '수정일시_등록정보', '차명',
#        '차종_제원정보', '차종분류', '차종유형(소분류)', '자동차형식', '제작사명', '연료', '엔진형식', '공차중량',
#        '총중량', '적재중량', '엔진출력', '배기량', '승차인원', '차량길이', '차량너비', '차량높이', '원산지명',
#        '삭제YN', '승인일자', '구동형식', '변속기종류', '생성일시_제원정보', '수정일시_제원정보'],
#       dtype='object')

# %%
df['차종_등록정보'].unique()
# Out:
# array(['화물', '승용', '승합', '특수'], dtype=object)

# %% [markdown]
# # 기초 분석

# %% [markdown]
# ## [로드] 영문, 한글 컬럼명

# %%
# 등록정보
ex1 = pd.read_excel('analysis/ODSvsSTD/[정제]CEG_CAR_MIG.xlsx')
# 제원정보
ex2 = pd.read_excel('analysis/ODSvsSTD/[정제]CEG_CAR_SRC_MIG.xlsx')

# %%
ex1
# Out:
#                    컬럼             내용
# 0             UPDT_DT          수정 일시
# 1             OWNR_SE         소유자 구분
# 2               VHRNO         차량등록번호
# 3        BSPL_LEDO_CD     본거지 법정동 코드
# 4             CRTN_DT          생성 일시
# 5               PURPS             용도
# 6   EMIS_INSP_EFCT_DE     배출가스검사유효일자
# 7         EMIS_CRTCNO      배출가스 인증번호
# 8          NOW_MBERNO        현재 회원번호
# 9             ACQS_DE          취득 일자
# 10           ACQS_AMT          취득 금액
# 11         FST_MBERNO        최초 회원번호
# 12         FST_REG_DE       최초 등록 일자
# 13              VHCTY             차종
# 14     VHRNO_NUM_INFO   차량등록번호 숫자 정보
# 15              VHMNO         차량관리번호
# 16      VHCL_MNFCT_DE       차량 제작 일자
# 17        VHCL_YRIDNW          차량 연식
# 18       VHCL_ERSR_YN       차량 말소 YN
# 19                VIN           차대번호
# 20            SRCMNNO         제원관리번호
# 21           EMIS_GRD        배출가스 등급
# 22            LEM_KND       저공해조치 종류
# 23      LEM_STRCHG_YN  저공해조치 구조변경 YN
# 24             LEM_YN  저공해조치 YN(미사용)
# 25        NOW_OWNR_NM             미정
# 26          BSPL_ADRS             미정
# 27          OWNR_ADRS             미정
# 28           BSPL_ZIP             미정
# 29        FST_OWNR_NM             미정
# 30                RMK             미정
# 31            USER_ID             미정

# %%
ex1['내용'].to_list()
# Out:
# ['수정 일시',
#  '소유자 구분',
#  '차량등록번호',
#  '본거지 법정동 코드',
#  '생성 일시',
#  '용도',
#  '배출가스검사유효일자',
#  '배출가스 인증번호',
#  '현재 회원번호',
#  '취득 일자',
#  '취득 금액',
#  '최초 회원번호',
#  '최초 등록 일자',
#  '차종',
#  '차량등록번호 숫자 정보',
#  '차량관리번호',
#  '차량 제작 일자',
#  '차량 연식',
#  '차량 말소 YN',
#  '차대번호',
#  '제원관리번호',
#  '배출가스 등급',
#  '저공해조치 종류',
#  '저공해조치 구조변경 YN',
#  '저공해조치 YN(미사용)',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정']

# %%
ex1['내용'] = [
    '수정일시_등록정보',
    '소유자구분',
    '차량등록번호',
    '본거지법정동코드',
    '생성일시_등록정보',
    '용도',
    '배출가스검사유효일자',
    '배출가스인증번호',
    '현재회원번호',
    '취득일자',
    '취득금액',
    '최초회원번호',
    '최초등록일자',
    '차종_등록정보',
    '차량등록번호숫자정보',
    '차량관리번호',
    '차량제작일자',
    '차량연식',
    '차량말소YN',
    '차대번호',
    '제원관리번호',
    '배출가스등급',
    '저공해조치종류',
    '저공해조치구조변경YN',
    '저공해조치YN(미사용)',
    '미정',
    '미정',
    '미정',
    '미정',
    '미정',
    '미정',
    '미정',
 ]

# %%
ex1
# Out:
#                    컬럼            내용
# 0             UPDT_DT     수정일시_등록정보
# 1             OWNR_SE         소유자구분
# 2               VHRNO        차량등록번호
# 3        BSPL_LEDO_CD      본거지법정동코드
# 4             CRTN_DT     생성일시_등록정보
# 5               PURPS            용도
# 6   EMIS_INSP_EFCT_DE    배출가스검사유효일자
# 7         EMIS_CRTCNO      배출가스인증번호
# 8          NOW_MBERNO        현재회원번호
# 9             ACQS_DE          취득일자
# 10           ACQS_AMT          취득금액
# 11         FST_MBERNO        최초회원번호
# 12         FST_REG_DE        최초등록일자
# 13              VHCTY       차종_등록정보
# 14     VHRNO_NUM_INFO    차량등록번호숫자정보
# 15              VHMNO        차량관리번호
# 16      VHCL_MNFCT_DE        차량제작일자
# 17        VHCL_YRIDNW          차량연식
# 18       VHCL_ERSR_YN        차량말소YN
# 19                VIN          차대번호
# 20            SRCMNNO        제원관리번호
# 21           EMIS_GRD        배출가스등급
# 22            LEM_KND       저공해조치종류
# 23      LEM_STRCHG_YN   저공해조치구조변경YN
# 24             LEM_YN  저공해조치YN(미사용)
# 25        NOW_OWNR_NM            미정
# 26          BSPL_ADRS            미정
# 27          OWNR_ADRS            미정
# 28           BSPL_ZIP            미정
# 29        FST_OWNR_NM            미정
# 30                RMK            미정
# 31            USER_ID            미정

# %%
ex2
# Out:
#              컬럼           내용
# 0       UPDT_DT        수정 일시
# 1      CNFRM_DE        승인 일자
# 2       DELE_YN        삭제 YN
# 3       CRTN_DT        생성 일시
# 4      TOT_WGHT         총 중량
# 5      VHCTY_TY  차종 유형 (소분류)
# 6      VHCTY_CL        차종 분류
# 7         VHCTY           차종
# 8         VHCNM           차명
# 9       VHCL_HG        차량 높이
# 10      VHCL_WH        차량 너비
# 11      VHCL_LT        차량 길이
# 12      DRV_FRM        구동 형식
# 13       MKR_NM        제작사 명
# 14      SRCMNNO       제원관리번호
# 15   CRYNG_WGHT        적재 중량
# 16      CAR_FRM       자동차 형식
# 17    EMPV_WGHT         공차중량
# 18      PLOR_NM        원산지 명
# 19         FUEL           연료
# 20       EGINTY         엔진형식
# 21      EGINPWR         엔진출력
# 22   TKCAR_NMPR        승차 인원
# 23       DSPLVL          배기량
# 24  GEARBOX_KND       변속기 종류
# 25    REPCAR_NM           미정
# 26          RMK           미정
# 27      USER_ID           미정

# %%
ex2['내용'].to_list()
# Out:
# ['수정 일시',
#  '승인 일자',
#  '삭제 YN',
#  '생성 일시',
#  '총 중량',
#  '차종 유형 (소분류)',
#  '차종 분류',
#  '차종',
#  '차명',
#  '차량 높이',
#  '차량 너비',
#  '차량 길이',
#  '구동 형식',
#  '제작사 명',
#  '제원관리번호',
#  '적재 중량',
#  '자동차 형식',
#  '공차중량',
#  '원산지 명',
#  '연료',
#  '엔진형식',
#  '엔진출력',
#  '승차 인원',
#  '배기량',
#  '변속기 종류',
#  '미정',
#  '미정',
#  '미정']

# %%
ex2['내용'] = [
    '수정일시_제원정보',
    '승인일자',
    '삭제YN',
    '생성일시_제원정보',
    '총중량',
    '차종유형(소분류)',
    '차종분류',
    '차종_제원정보',
    '차명',
    '차량높이',
    '차량너비',
    '차량길이',
    '구동형식',
    '제작사명',
    '제원관리번호',
    '적재중량',
    '자동차형식',
    '공차중량',
    '원산지명',
    '연료',
    '엔진형식',
    '엔진출력',
    '승차인원',
    '배기량',
    '변속기종류',
    '미정',
    '미정',
    '미정'
]

# %%
ex2
# Out:
#              컬럼         내용
# 0       UPDT_DT  수정일시_제원정보
# 1      CNFRM_DE       승인일자
# 2       DELE_YN       삭제YN
# 3       CRTN_DT  생성일시_제원정보
# 4      TOT_WGHT        총중량
# 5      VHCTY_TY  차종유형(소분류)
# 6      VHCTY_CL       차종분류
# 7         VHCTY    차종_제원정보
# 8         VHCNM         차명
# 9       VHCL_HG       차량높이
# 10      VHCL_WH       차량너비
# 11      VHCL_LT       차량길이
# 12      DRV_FRM       구동형식
# 13       MKR_NM       제작사명
# 14      SRCMNNO     제원관리번호
# 15   CRYNG_WGHT       적재중량
# 16      CAR_FRM      자동차형식
# 17    EMPV_WGHT       공차중량
# 18      PLOR_NM       원산지명
# 19         FUEL         연료
# 20       EGINTY       엔진형식
# 21      EGINPWR       엔진출력
# 22   TKCAR_NMPR       승차인원
# 23       DSPLVL        배기량
# 24  GEARBOX_KND      변속기종류
# 25    REPCAR_NM         미정
# 26          RMK         미정
# 27      USER_ID         미정

# %%
ex = pd.concat([ex1, ex2], ignore_index=True)
ex
# Out:
#                    컬럼            내용
# 0             UPDT_DT     수정일시_등록정보
# 1             OWNR_SE         소유자구분
# 2               VHRNO        차량등록번호
# 3        BSPL_LEDO_CD      본거지법정동코드
# 4             CRTN_DT     생성일시_등록정보
# 5               PURPS            용도
# 6   EMIS_INSP_EFCT_DE    배출가스검사유효일자
# 7         EMIS_CRTCNO      배출가스인증번호
# 8          NOW_MBERNO        현재회원번호
# 9             ACQS_DE          취득일자
# 10           ACQS_AMT          취득금액
# 11         FST_MBERNO        최초회원번호
# 12         FST_REG_DE        최초등록일자
# 13              VHCTY       차종_등록정보
# 14     VHRNO_NUM_INFO    차량등록번호숫자정보
# 15              VHMNO        차량관리번호
# 16      VHCL_MNFCT_DE        차량제작일자
# 17        VHCL_YRIDNW          차량연식
# 18       VHCL_ERSR_YN        차량말소YN
# 19                VIN          차대번호
# 20            SRCMNNO        제원관리번호
# 21           EMIS_GRD        배출가스등급
# 22            LEM_KND       저공해조치종류
# 23      LEM_STRCHG_YN   저공해조치구조변경YN
# 24             LEM_YN  저공해조치YN(미사용)
# 25        NOW_OWNR_NM            미정
# 26          BSPL_ADRS            미정
# 27          OWNR_ADRS            미정
# 28           BSPL_ZIP            미정
# 29        FST_OWNR_NM            미정
# 30                RMK            미정
# 31            USER_ID            미정
# 32            UPDT_DT     수정일시_제원정보
# 33           CNFRM_DE          승인일자
# 34            DELE_YN          삭제YN
# 35            CRTN_DT     생성일시_제원정보
# 36           TOT_WGHT           총중량
# 37           VHCTY_TY     차종유형(소분류)
# 38           VHCTY_CL          차종분류
# 39              VHCTY       차종_제원정보
# 40              VHCNM            차명
# 41            VHCL_HG          차량높이
# 42            VHCL_WH          차량너비
# 43            VHCL_LT          차량길이
# 44            DRV_FRM          구동형식
# 45             MKR_NM          제작사명
# 46            SRCMNNO        제원관리번호
# 47         CRYNG_WGHT          적재중량
# 48            CAR_FRM         자동차형식
# 49          EMPV_WGHT          공차중량
# 50            PLOR_NM          원산지명
# 51               FUEL            연료
# 52             EGINTY          엔진형식
# 53            EGINPWR          엔진출력
# 54         TKCAR_NMPR          승차인원
# 55             DSPLVL           배기량
# 56        GEARBOX_KND         변속기종류
# 57          REPCAR_NM            미정
# 58                RMK            미정
# 59            USER_ID            미정

# %%
col_dict = {a:b for b, a in zip(ex['컬럼'], ex['내용'])}
col_dict
# Out:
# {'수정일시_등록정보': 'UPDT_DT',
#  '소유자구분': 'OWNR_SE',
#  '차량등록번호': 'VHRNO',
#  '본거지법정동코드': 'BSPL_LEDO_CD',
#  '생성일시_등록정보': 'CRTN_DT',
#  '용도': 'PURPS',
#  '배출가스검사유효일자': 'EMIS_INSP_EFCT_DE',
#  '배출가스인증번호': 'EMIS_CRTCNO',
#  '현재회원번호': 'NOW_MBERNO',
#  '취득일자': 'ACQS_DE',
#  '취득금액': 'ACQS_AMT',
#  '최초회원번호': 'FST_MBERNO',
#  '최초등록일자': 'FST_REG_DE',
#  '차종_등록정보': 'VHCTY',
#  '차량등록번호숫자정보': 'VHRNO_NUM_INFO',
#  '차량관리번호': 'VHMNO',
#  '차량제작일자': 'VHCL_MNFCT_DE',
#  '차량연식': 'VHCL_YRIDNW',
#  '차량말소YN': 'VHCL_ERSR_YN',
#  '차대번호': 'VIN',
#  '제원관리번호': 'SRCMNNO',
#  '배출가스등급': 'EMIS_GRD',
#  '저공해조치종류': 'LEM_KND',
#  '저공해조치구조변경YN': 'LEM_STRCHG_YN',
#  '저공해조치YN(미사용)': 'LEM_YN',
#  '미정': 'USER_ID',
#  '수정일시_제원정보': 'UPDT_DT',
#  '승인일자': 'CNFRM_DE',
#  '삭제YN': 'DELE_YN',
#  '생성일시_제원정보': 'CRTN_DT',
#  '총중량': 'TOT_WGHT',
#  '차종유형(소분류)': 'VHCTY_TY',
#  '차종분류': 'VHCTY_CL',
#  '차종_제원정보': 'VHCTY',
#  '차명': 'VHCNM',
#  '차량높이': 'VHCL_HG',
#  '차량너비': 'VHCL_WH',
#  '차량길이': 'VHCL_LT',
#  '구동형식': 'DRV_FRM',
#  '제작사명': 'MKR_NM',
#  '적재중량': 'CRYNG_WGHT',
#  '자동차형식': 'CAR_FRM',
#  '공차중량': 'EMPV_WGHT',
#  '원산지명': 'PLOR_NM',
#  '연료': 'FUEL',
#  '엔진형식': 'EGINTY',
#  '엔진출력': 'EGINPWR',
#  '승차인원': 'TKCAR_NMPR',
#  '배기량': 'DSPLVL',
#  '변속기종류': 'GEARBOX_KND'}

# %%
df.columns
# Out:
# Index(['차량관리번호', '차량등록번호', '본거지법정동코드', '소유자구분', '차종_등록정보', '용도', '현재회원번호',
#        '차대번호', '최초등록일자', '차량연식', '차량제작일자', '배출가스검사유효일자', '제원관리번호', '배출가스인증번호',
#        '배출가스등급', '저공해조치YN(미사용)', '저공해조치종류', '저공해조치구조변경YN', '차량등록번호숫자정보',
#        '차량말소YN', '최초회원번호', '취득일자', '취득금액', '생성일시_등록정보', '수정일시_등록정보', '차명',
#        '차종_제원정보', '차종분류', '차종유형(소분류)', '자동차형식', '제작사명', '연료', '엔진형식', '공차중량',
#        '총중량', '적재중량', '엔진출력', '배기량', '승차인원', '차량길이', '차량너비', '차량높이', '원산지명',
#        '삭제YN', '승인일자', '구동형식', '변속기종류', '생성일시_제원정보', '수정일시_제원정보'],
#       dtype='object')

# %%
an = df.isnull().sum().reset_index()
an
# Out:
#            index         0
# 0         차량관리번호         0
# 1         차량등록번호         0
# 2       본거지법정동코드         0
# 3          소유자구분         0
# 4        차종_등록정보         0
# 5             용도         0
# 6         현재회원번호         0
# 7           차대번호         0
# 8         최초등록일자         0
# 9           차량연식         0
# 10        차량제작일자      2905
# 11    배출가스검사유효일자         5
# 12        제원관리번호         0
# 13      배출가스인증번호    567419
# 14        배출가스등급         0
# 15  저공해조치YN(미사용)    582683
# 16       저공해조치종류  11207718
# 17   저공해조치구조변경YN         0
# 18    차량등록번호숫자정보         0
# 19        차량말소YN         0
# 20        최초회원번호         0
# 21          취득일자     34599
# 22          취득금액     34337
# 23     생성일시_등록정보         0
# 24     수정일시_등록정보   3000846
# 25            차명         0
# 26       차종_제원정보         0
# 27          차종분류         0
# 28     차종유형(소분류)         0
# 29         자동차형식      1131
# 30          제작사명        83
# 31            연료        26
# 32          엔진형식      1421
# 33          공차중량  11207727
# 34           총중량        99
# 35          적재중량   4832649
# 36          엔진출력      1713
# 37           배기량         7
# 38          승차인원         0
# 39          차량길이      1694
# 40          차량너비      1699
# 41          차량높이      1710
# 42          원산지명         0
# 43          삭제YN         0
# 44          승인일자         3
# 45          구동형식   7804962
# 46         변속기종류      2777
# 47     생성일시_제원정보         0
# 48     수정일시_제원정보  10765926

# %%
an.columns = ['한글컬럼', '결측치']
an
# Out:
#             한글컬럼       결측치
# 0         차량관리번호         0
# 1         차량등록번호         0
# 2       본거지법정동코드         0
# 3          소유자구분         0
# 4        차종_등록정보         0
# 5             용도         0
# 6         현재회원번호         0
# 7           차대번호         0
# 8         최초등록일자         0
# 9           차량연식         0
# 10        차량제작일자      2905
# 11    배출가스검사유효일자         5
# 12        제원관리번호         0
# 13      배출가스인증번호    567419
# 14        배출가스등급         0
# 15  저공해조치YN(미사용)    582683
# 16       저공해조치종류  11207718
# 17   저공해조치구조변경YN         0
# 18    차량등록번호숫자정보         0
# 19        차량말소YN         0
# 20        최초회원번호         0
# 21          취득일자     34599
# 22          취득금액     34337
# 23     생성일시_등록정보         0
# 24     수정일시_등록정보   3000846
# 25            차명         0
# 26       차종_제원정보         0
# 27          차종분류         0
# 28     차종유형(소분류)         0
# 29         자동차형식      1131
# 30          제작사명        83
# 31            연료        26
# 32          엔진형식      1421
# 33          공차중량  11207727
# 34           총중량        99
# 35          적재중량   4832649
# 36          엔진출력      1713
# 37           배기량         7
# 38          승차인원         0
# 39          차량길이      1694
# 40          차량너비      1699
# 41          차량높이      1710
# 42          원산지명         0
# 43          삭제YN         0
# 44          승인일자         3
# 45          구동형식   7804962
# 46         변속기종류      2777
# 47     생성일시_제원정보         0
# 48     수정일시_제원정보  10765926

# %%
an['컬럼'] = [col_dict[x] for x in an['한글컬럼']]
an
# Out:
#             한글컬럼       결측치                 컬럼
# 0         차량관리번호         0              VHMNO
# 1         차량등록번호         0              VHRNO
# 2       본거지법정동코드         0       BSPL_LEDO_CD
# 3          소유자구분         0            OWNR_SE
# 4        차종_등록정보         0              VHCTY
# 5             용도         0              PURPS
# 6         현재회원번호         0         NOW_MBERNO
# 7           차대번호         0                VIN
# 8         최초등록일자         0         FST_REG_DE
# 9           차량연식         0        VHCL_YRIDNW
# 10        차량제작일자      2905      VHCL_MNFCT_DE
# 11    배출가스검사유효일자         5  EMIS_INSP_EFCT_DE
# 12        제원관리번호         0            SRCMNNO
# 13      배출가스인증번호    567419        EMIS_CRTCNO
# 14        배출가스등급         0           EMIS_GRD
# 15  저공해조치YN(미사용)    582683             LEM_YN
# 16       저공해조치종류  11207718            LEM_KND
# 17   저공해조치구조변경YN         0      LEM_STRCHG_YN
# 18    차량등록번호숫자정보         0     VHRNO_NUM_INFO
# 19        차량말소YN         0       VHCL_ERSR_YN
# 20        최초회원번호         0         FST_MBERNO
# 21          취득일자     34599            ACQS_DE
# 22          취득금액     34337           ACQS_AMT
# 23     생성일시_등록정보         0            CRTN_DT
# 24     수정일시_등록정보   3000846            UPDT_DT
# 25            차명         0              VHCNM
# 26       차종_제원정보         0              VHCTY
# 27          차종분류         0           VHCTY_CL
# 28     차종유형(소분류)         0           VHCTY_TY
# 29         자동차형식      1131            CAR_FRM
# 30          제작사명        83             MKR_NM
# 31            연료        26               FUEL
# 32          엔진형식      1421             EGINTY
# 33          공차중량  11207727          EMPV_WGHT
# 34           총중량        99           TOT_WGHT
# 35          적재중량   4832649         CRYNG_WGHT
# 36          엔진출력      1713            EGINPWR
# 37           배기량         7             DSPLVL
# 38          승차인원         0         TKCAR_NMPR
# 39          차량길이      1694            VHCL_LT
# 40          차량너비      1699            VHCL_WH
# 41          차량높이      1710            VHCL_HG
# 42          원산지명         0            PLOR_NM
# 43          삭제YN         0            DELE_YN
# 44          승인일자         3           CNFRM_DE
# 45          구동형식   7804962            DRV_FRM
# 46         변속기종류      2777        GEARBOX_KND
# 47     생성일시_제원정보         0            CRTN_DT
# 48     수정일시_제원정보  10765926            UPDT_DT

# %%
an = an[['컬럼', '한글컬럼', '결측치']]
an
# Out:
#                    컬럼          한글컬럼       결측치
# 0               VHMNO        차량관리번호         0
# 1               VHRNO        차량등록번호         0
# 2        BSPL_LEDO_CD      본거지법정동코드         0
# 3             OWNR_SE         소유자구분         0
# 4               VHCTY       차종_등록정보         0
# 5               PURPS            용도         0
# 6          NOW_MBERNO        현재회원번호         0
# 7                 VIN          차대번호         0
# 8          FST_REG_DE        최초등록일자         0
# 9         VHCL_YRIDNW          차량연식         0
# 10      VHCL_MNFCT_DE        차량제작일자      2905
# 11  EMIS_INSP_EFCT_DE    배출가스검사유효일자         5
# 12            SRCMNNO        제원관리번호         0
# 13        EMIS_CRTCNO      배출가스인증번호    567419
# 14           EMIS_GRD        배출가스등급         0
# 15             LEM_YN  저공해조치YN(미사용)    582683
# 16            LEM_KND       저공해조치종류  11207718
# 17      LEM_STRCHG_YN   저공해조치구조변경YN         0
# 18     VHRNO_NUM_INFO    차량등록번호숫자정보         0
# 19       VHCL_ERSR_YN        차량말소YN         0
# 20         FST_MBERNO        최초회원번호         0
# 21            ACQS_DE          취득일자     34599
# 22           ACQS_AMT          취득금액     34337
# 23            CRTN_DT     생성일시_등록정보         0
# 24            UPDT_DT     수정일시_등록정보   3000846
# 25              VHCNM            차명         0
# 26              VHCTY       차종_제원정보         0
# 27           VHCTY_CL          차종분류         0
# 28           VHCTY_TY     차종유형(소분류)         0
# 29            CAR_FRM         자동차형식      1131
# 30             MKR_NM          제작사명        83
# 31               FUEL            연료        26
# 32             EGINTY          엔진형식      1421
# 33          EMPV_WGHT          공차중량  11207727
# 34           TOT_WGHT           총중량        99
# 35         CRYNG_WGHT          적재중량   4832649
# 36            EGINPWR          엔진출력      1713
# 37             DSPLVL           배기량         7
# 38         TKCAR_NMPR          승차인원         0
# 39            VHCL_LT          차량길이      1694
# 40            VHCL_WH          차량너비      1699
# 41            VHCL_HG          차량높이      1710
# 42            PLOR_NM          원산지명         0
# 43            DELE_YN          삭제YN         0
# 44           CNFRM_DE          승인일자         3
# 45            DRV_FRM          구동형식   7804962
# 46        GEARBOX_KND         변속기종류      2777
# 47            CRTN_DT     생성일시_제원정보         0
# 48            UPDT_DT     수정일시_제원정보  10765926

# %% [markdown]
# ## [출력] 등록정보&제원정보 결측치 통계

# %%
an.to_excel(f'analysis2/[BD3][G{grade}][통계]등록정보&제원정보_결측치.xlsx', index=False)

# %% [markdown]
# # 코드 마지막
