# %% [markdown]
# # Library
# - 함수 : 특정 작업을 수행하는 코드 단위
# - module(모듈) : 코드 파일
# - package(패키지) : 여러 모듈과 기능을 폴더로 모은 것
# - library(라이브러리) : 여러 패키지와 모듈을 모아놓은 것
# - 모듈 <= 패키지 <= 라이브러리

# %%
# 도와주는 라이브러리
import os
from tqdm import tqdm

# %%
# 핵심 라이브러리
import pandas as pd
import numpy as np

# %% [markdown]
# ## 시각화 라이브러리

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## plt 한글 폰트 지정

# %%
import platform
from matplotlib import font_manager, rc

# 한글 폰트 지정
path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system()=="Darwin":
    rc('font', family='AppleGothic')
else:
    print("Unknown System")

# %%
# 음수 표현
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # path

# %%
# data_fold = 'C:/Users/kbjung/Documents/GitHub/wabotech/class/data'
# export_fold = 'C:/Users/kbjung/Documents/GitHub/wabotech/class/export'

# %% [markdown]
# # 1\. 파일 로드&출력

# %% [markdown]
# ## 파일 로드

# %%
# os.path.join(data_fold, 'train.csv')

# %%
# csv
df = pd.read_csv('C:/Users/kbjung/Documents/GitHub/wabotech/class/data/train.csv')

# %%
# xlsx
df = pd.read_excel('C:/Users/kbjung/Documents/GitHub/wabotech/class/data/train.xlsx')

# %%
# txt
df = pd.read_table('C:/Users/kbjung/Documents/GitHub/wabotech/class/data/train.txt')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# ## 파일 출력

# %%
# csv
df.to_csv('C:/Users/kbjung/Documents/GitHub/wabotech/class/export/to_csv_train.csv', index=False)
df.to_csv(os.path.join(), index=False)

# %%
# xlsx
df.to_excel('C:/Users/kbjung/Documents/GitHub/wabotech/class/export/to_csv_train.xlsx', index=False)

# %%
# txt
df.to_csv('C:/Users/kbjung/Documents/GitHub/wabotech/class/export/to_csv_train.txt', index=False)

# %% [markdown]
# # 2\. 데이터프레임 탐색 및 수정

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %% [markdown]
# ## 조건 탐색

# %%
df.loc[df['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %%
df.loc[(df['Sex'] == 'female') & (df['Embarked'] == 'C')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 31            32         1       1
# 39            40         1       3
# ..           ...       ...     ...
# 858          859         1       3
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch         Ticket      Fare Cabin Embarked
# 1        0       PC 17599   71.2833   C85        C
# 9        0         237736   30.0708   NaN        C
# 19       0           2649    7.2250   NaN        C
# 31       0       PC 17569  146.5208   B78        C
# 39       0           2651   11.2417   NaN        C
# ..     ...            ...       ...   ...      ...
# 858      3           2666   19.2583   NaN        C
# 866      0  SC/PARIS 2149   13.8583   NaN        C
# 874      0      P/PP 3381   24.0000   NaN        C
# 875      0           2667    7.2250   NaN        C
# 879      1          11767   83.1583   C50        C
#
# [73 rows x 12 columns]

# %%
# <, >, ==
df.loc[(df['Sex'] == 'female') & (df['Embarked'] == 'C') & (df['Age'] < 40) & (df['Age'] >= 30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 215          216         1       1
# 218          219         1       1
# 258          259         1       1
# 309          310         1       1
# 325          326         1       1
# 537          538         1       1
# 581          582         1       1
# 716          717         1       1
# 835          836         1       1
# 842          843         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 215                            Newell, Miss. Madeleine  female  31.0      1
# 218                              Bazzani, Miss. Albina  female  32.0      0
# 258                                   Ward, Miss. Anna  female  35.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 325                           Young, Miss. Marie Grice  female  36.0      0
# 537                                LeRoy, Miss. Bertha  female  30.0      0
# 581  Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.0      1
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 842                            Serepeca, Miss. Augusta  female  30.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 215      0     35273  113.2750   D36        C
# 218      0     11813   76.2917   D15        C
# 258      0  PC 17755  512.3292   NaN        C
# 309      0  PC 17485   56.9292   E36        C
# 325      0  PC 17760  135.6333   C32        C
# 537      0  PC 17761  106.4250   NaN        C
# 581      1     17421  110.8833   C68        C
# 716      0  PC 17757  227.5250   C45        C
# 835      1  PC 17756   83.1583   E49        C
# 842      0    113798   31.0000   NaN        C

# %%
temp = df.loc[(df['Sex'] == 'female') & ( (df['Embarked'] == 'C') | (df['Embarked'] == 'Q') ) & (df['Age'] <= 39) & (df['Age'] >= 30)]
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 215          216         1       1
# 218          219         1       1
# 258          259         1       1
# 309          310         1       1
# 322          323         1       2
# 325          326         1       1
# 412          413         1       1
# 537          538         1       1
# 581          582         1       1
# 657          658         0       3
# 716          717         1       1
# 767          768         0       3
# 835          836         1       1
# 842          843         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 215                            Newell, Miss. Madeleine  female  31.0      1
# 218                              Bazzani, Miss. Albina  female  32.0      0
# 258                                   Ward, Miss. Anna  female  35.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 322                          Slayter, Miss. Hilda Mary  female  30.0      0
# 325                           Young, Miss. Marie Grice  female  36.0      0
# 412                             Minahan, Miss. Daisy E  female  33.0      1
# 537                                LeRoy, Miss. Bertha  female  30.0      0
# 581  Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.0      1
# 657                      Bourke, Mrs. John (Catherine)  female  32.0      1
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
# 767                                 Mangan, Miss. Mary  female  30.5      0
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 842                            Serepeca, Miss. Augusta  female  30.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 215      0     35273  113.2750   D36        C
# 218      0     11813   76.2917   D15        C
# 258      0  PC 17755  512.3292   NaN        C
# 309      0  PC 17485   56.9292   E36        C
# 322      0    234818   12.3500   NaN        Q
# 325      0  PC 17760  135.6333   C32        C
# 412      0     19928   90.0000   C78        Q
# 537      0  PC 17761  106.4250   NaN        C
# 581      1     17421  110.8833   C68        C
# 657      1    364849   15.5000   NaN        Q
# 716      0  PC 17757  227.5250   C45        C
# 767      0    364850    7.7500   NaN        Q
# 835      1  PC 17756   83.1583   E49        C
# 842      0    113798   31.0000   NaN        C
# 885      5    382652   29.1250   NaN        Q

# %%
# excel
temp.to_excel('C:/Users/kbjung/Documents/GitHub/wabotech/class/export/female_30s_C_Q.xlsx', index=False)

# %%
nan_df = df.loc[df['Embarked'].isnull() == True]
nan_df
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
total = pd.concat([temp, nan_df], ignore_index=True)
total
# Out:
#     PassengerId  Survived  Pclass  \
# 0             2         1       1
# 1           216         1       1
# 2           219         1       1
# 3           259         1       1
# 4           310         1       1
# 5           323         1       2
# 6           326         1       1
# 7           413         1       1
# 8           538         1       1
# 9           582         1       1
# 10          658         0       3
# 11          717         1       1
# 12          768         0       3
# 13          836         1       1
# 14          843         1       1
# 15          886         0       3
# 16           62         1       1
# 17          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                             Newell, Miss. Madeleine  female  31.0      1
# 2                               Bazzani, Miss. Albina  female  32.0      0
# 3                                    Ward, Miss. Anna  female  35.0      0
# 4                      Francatelli, Miss. Laura Mabel  female  30.0      0
# 5                           Slayter, Miss. Hilda Mary  female  30.0      0
# 6                            Young, Miss. Marie Grice  female  36.0      0
# 7                              Minahan, Miss. Daisy E  female  33.0      1
# 8                                 LeRoy, Miss. Bertha  female  30.0      0
# 9   Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.0      1
# 10                      Bourke, Mrs. John (Catherine)  female  32.0      1
# 11                      Endres, Miss. Caroline Louise  female  38.0      0
# 12                                 Mangan, Miss. Mary  female  30.5      0
# 13                        Compton, Miss. Sara Rebecca  female  39.0      1
# 14                            Serepeca, Miss. Augusta  female  30.0      0
# 15               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 16                                Icard, Miss. Amelie  female  38.0      0
# 17          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#     Parch    Ticket      Fare Cabin Embarked
# 0       0  PC 17599   71.2833   C85        C
# 1       0     35273  113.2750   D36        C
# 2       0     11813   76.2917   D15        C
# 3       0  PC 17755  512.3292   NaN        C
# 4       0  PC 17485   56.9292   E36        C
# 5       0    234818   12.3500   NaN        Q
# 6       0  PC 17760  135.6333   C32        C
# 7       0     19928   90.0000   C78        Q
# 8       0  PC 17761  106.4250   NaN        C
# 9       1     17421  110.8833   C68        C
# 10      1    364849   15.5000   NaN        Q
# 11      0  PC 17757  227.5250   C45        C
# 12      0    364850    7.7500   NaN        Q
# 13      1  PC 17756   83.1583   E49        C
# 14      0    113798   31.0000   NaN        C
# 15      5    382652   29.1250   NaN        Q
# 16      0    113572   80.0000   B28      NaN
# 17      0    113572   80.0000   B28      NaN

# %%
total.Embarked.value_counts()
# Out:
# C    11
# Q     5
# Name: Embarked, dtype: int64

# %%
test = pd.DataFrame({'테스트':['S', 'Q', 'C'], '값':[1, 2, 3]})
test
# Out:
#   테스트  값
# 0   S  1
# 1   Q  2
# 2   C  3

# %%
total.merge(test, left_on='Embarked', right_on='테스트', how='left')
# Out:
#     PassengerId  Survived  Pclass  \
# 0             2         1       1
# 1           216         1       1
# 2           219         1       1
# 3           259         1       1
# 4           310         1       1
# 5           323         1       2
# 6           326         1       1
# 7           413         1       1
# 8           538         1       1
# 9           582         1       1
# 10          658         0       3
# 11          717         1       1
# 12          768         0       3
# 13          836         1       1
# 14          843         1       1
# 15          886         0       3
# 16           62         1       1
# 17          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                             Newell, Miss. Madeleine  female  31.0      1
# 2                               Bazzani, Miss. Albina  female  32.0      0
# 3                                    Ward, Miss. Anna  female  35.0      0
# 4                      Francatelli, Miss. Laura Mabel  female  30.0      0
# 5                           Slayter, Miss. Hilda Mary  female  30.0      0
# 6                            Young, Miss. Marie Grice  female  36.0      0
# 7                              Minahan, Miss. Daisy E  female  33.0      1
# 8                                 LeRoy, Miss. Bertha  female  30.0      0
# 9   Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.0      1
# 10                      Bourke, Mrs. John (Catherine)  female  32.0      1
# 11                      Endres, Miss. Caroline Louise  female  38.0      0
# 12                                 Mangan, Miss. Mary  female  30.5      0
# 13                        Compton, Miss. Sara Rebecca  female  39.0      1
# 14                            Serepeca, Miss. Augusta  female  30.0      0
# 15               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 16                                Icard, Miss. Amelie  female  38.0      0
# 17          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#     Parch    Ticket      Fare Cabin Embarked  테스트    값
# 0       0  PC 17599   71.2833   C85        C    C  3.0
# 1       0     35273  113.2750   D36        C    C  3.0
# 2       0     11813   76.2917   D15        C    C  3.0
# 3       0  PC 17755  512.3292   NaN        C    C  3.0
# 4       0  PC 17485   56.9292   E36        C    C  3.0
# 5       0    234818   12.3500   NaN        Q    Q  2.0
# 6       0  PC 17760  135.6333   C32        C    C  3.0
# 7       0     19928   90.0000   C78        Q    Q  2.0
# 8       0  PC 17761  106.4250   NaN        C    C  3.0
# 9       1     17421  110.8833   C68        C    C  3.0
# 10      1    364849   15.5000   NaN        Q    Q  2.0
# 11      0  PC 17757  227.5250   C45        C    C  3.0
# 12      0    364850    7.7500   NaN        Q    Q  2.0
# 13      1  PC 17756   83.1583   E49        C    C  3.0
# 14      0    113798   31.0000   NaN        C    C  3.0
# 15      5    382652   29.1250   NaN        Q    Q  2.0
# 16      0    113572   80.0000   B28      NaN  NaN  NaN
# 17      0    113572   80.0000   B28      NaN  NaN  NaN

# %% [markdown]
# # 3\. 시각화

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.title('성별 샘플 수')
plt.bar(df.Sex.unique(), df.Sex.value_counts(), width=0.2);

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
temp = df.Embarked.value_counts().reset_index()
temp
# Out:
#   index  Embarked
# 0     S       644
# 1     C       168
# 2     Q        77

# %%
plt.figure(figsize=(6, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('승선 항구별 샘플 수', fontdict={'fontsize':'20'})
plt.bar('index', 'Embarked', width=0.2, data=temp, color='skyblue');
# aqua, orange, tomato,

# %%
plt.figure(figsize=(6, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('승선 항구별 샘플 수', fontdict={'fontsize':'20'})
plt.plot('index', 'Embarked', data=temp, color='skyblue');

# %%
plt.figure(figsize=(10,7)) # cmpa : summer도 해보기
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap="GnBu");

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(10, 8))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df.corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 14});
# Out:
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_22240\983214868.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 14});

# %%
x = np.linspace(0, 9, 100)
y1 = [np.sin(x) for x in x]
x = np.linspace(0, 9, 100)
y2 = [np.cos(x) for x in x]

# %%
plt.figure(figsize=(6, 5))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.plot(x, y1, '-',color='red', label='sin')
plt.plot(x, y2, '--', color='blue', label='cos')
plt.grid(linestyle='--')
plt.legend(frameon=True, shadow=True, fontsize=20, labelcolor='orange', facecolor='palegreen', edgecolor='gold')
plt.show();

# %% [markdown]
# # 코드 마지막
