# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rcParams # 한글 환경 설정을 위한 rcParams 임포트
rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 기호가 깨지는 현상 방지

# %%
import warnings
# 경고창 무시
warnings.filterwarnings('ignore')

# %% [markdown]
# # seaborn setting

# %% [markdown]
# ## 전체 스타일링
# - context
#     - notebook: 기본 설정
#     - paper: 논문, 보고서
#     - talk: 프리젠테이션
#     - poster: 포스터
# - style
#     - darkgrid: 회색 배경색 + 그리드
#     - whitegrid: 흰색 배경색 + 그리드
#     - dark: 회색 배경색
#     - white: 흰색 배경색
#     - ticks: 흰색 배경색 + 눈금
# - palette
#     - deep
#     - muted
#     - pastel
#     - bright
#     - dark
#     - colorblind

# %%
for one in ['deep', 'muted', 'pastel', 'bright', 'dark', 'colorblind']:
    sns.palplot(sns.color_palette(one))

# %%
sequential_colors = sns.color_palette("RdPu", 10)
sns.palplot(sequential_colors)

# %%
diverging_colors = sns.color_palette("RdBu", 10)
sns.palplot(diverging_colors)

# %%
sns.set_theme(
    context='notebook',   # 매체: paper, talk, poster
    style='darkgrid',     # 기본 내장 테마
    palette='deep',       # 그래프 색
    font='D2Coding', # 글꼴 종류 
    # font='Malgun Gothic', # 글꼴 종류 
    font_scale=1,         # 글꼴 크기
    # rc=custom_params # 그래프 세부 사항
    )

# %%
sns.plotting_context()
# Out:
# {'font.size': 12.0,
#  'axes.labelsize': 12.0,
#  'axes.titlesize': 12.0,
#  'xtick.labelsize': 11.0,
#  'ytick.labelsize': 11.0,
#  'legend.fontsize': 11.0,
#  'legend.title_fontsize': 12.0,
#  'axes.linewidth': 1.25,
#  'grid.linewidth': 1.0,
#  'lines.linewidth': 1.5,
#  'lines.markersize': 6.0,
#  'patch.linewidth': 1.0,
#  'xtick.major.width': 1.25,
#  'ytick.major.width': 1.25,
#  'xtick.minor.width': 1.0,
#  'ytick.minor.width': 1.0,
#  'xtick.major.size': 6.0,
#  'ytick.major.size': 6.0,
#  'xtick.minor.size': 4.0,
#  'ytick.minor.size': 4.0}

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## [load] flights

# %%
fg = sns.load_dataset('flights')
fg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
fg.shape
# Out:
# (144, 3)

# %%
fg.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fg.year.unique(), len(fg.year.unique())
# Out:
# (array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#         1960], dtype=int64),
#  12)

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data=fg, x='year', y='passengers');

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(fg, x='year', y='passengers');

# %%
plt.figure(figsize=(12, 5))
# sns.set_palette('bright')
sns.swarmplot(data=fg, x='year', y='passengers');

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(data=fg, x='year', y='passengers');

# %%
sns.violinplot(fg, x='year', y='passengers');

# %%
plt.figure(figsize=(12, 5))
# sns.set_palette('bright')
sns.swarmplot(data=fg, x='year', y='passengers')
sns.violinplot(fg, x='year', y='passengers', facecolor=(0, 0, 0, 0));

# %%
plt.figure(figsize=(20, 5))
# sns.set(rc={'figure.figsize':(15,5)})
sns.catplot(data=fg, x='year', y='passengers', kind='violin', color='.9', inner=None)
plt.show()

# %%
# 그래프 크기 조정 적용 안됨
fig, ax = plt.subplots(figsize=(15,5))
# plt.figure(figsize=(20, 5))
# sns.set(rc={'figure.figsize':(15,5)})

sns.catplot(data=fg, x='year', y='passengers', kind='violin', color='.9', inner=None)
sns.swarmplot(data=fg, x='year', y='passengers', size=3)

plt.show();

# %%
# 그래프 크기 조정 적용 안됨
fig1 = sns.catplot(data=fg, x='year', y='passengers', kind='violin', color='.9', inner=None)
sns.swarmplot(data=fg, x='year', y='passengers', size=3)
fig1.fig.set_size_inches(12,5)

plt.show();

# %%
sns.__version__
# Out:
# '0.12.2'

# %% [markdown]
# ### distplot(displot)

# %%
sns.distplot(fg.passengers);

# %%
sns.displot(fg.passengers);

# %% [markdown]
# ### histplot

# %%
sns.set(rc={'figure.figsize':(12, 5)})
sns.histplot(fg.passengers);

# %% [markdown]
# ### subplots

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))
plt.suptitle('flights')
sns.barplot(data=fg, x='year', y='passengers', ax=axes[0, 0])
axes[0, 0].set_title('mean')
sns.barplot(data=fg, x='year', y='passengers', estimator=np.median, ax=axes[0, 1])
axes[0, 1].set_title('median')
sns.boxplot(fg, x='year', y='passengers', ax=axes[1, 0])
axes[1, 0].set_title('box')
sns.lineplot(data=fg, x='year', y='passengers', ax=axes[1, 1])
axes[1, 1].set_title('line');

# %% [markdown]
# ### lmplot

# %%
sns.set_style('darkgrid')
sns.lmplot(x='year', y='passengers', data=fg, height=7);

# %%
sns.set_style('darkgrid')
sns.lmplot(x='year', y='passengers', hue='month', data=fg, height=7);

# %% [markdown]
# ### pivot
# - df.pivot('rows', 'cols', 'values')

# %%
fgpivot = fg.pivot('month', 'year', 'passengers')
fgpivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# ### hitmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(fgpivot, annot=True, fmt='d');

# %% [markdown]
# ## [load] titanic

# %%
df = sns.load_dataset('titanic')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### countplot

# %%
sns.set(rc={'figure.figsize':(8, 5)})
sns.countplot(df, x='class', color='skyblue');

# %%
sns.countplot(df, x='class', palette='Set3');

# %%
sns.countplot(df, x='class', facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette('dark', 3));

# %%
sns.countplot(df, y='class', palette='Set3');

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(8, 5)})
sns.countplot(df, x='class', hue='survived');

# %%
sns.set(rc={'figure.figsize':(8, 5)})
sns.countplot(df, x='sex', hue='survived');

# %% [markdown]
# ### catplot

# %%
sns.catplot(df, x='class', y='fare');

# %%
sns.catplot(df, x='class', kind='count');

# %%
sns.catplot(df, x='class', y='fare', kind='bar');

# %%
sns.catplot(df, x='class', y='fare', kind='bar', estimator=np.median);

# %%
sns.catplot(df, x='class', y='fare', kind='bar', estimator=len);

# %%
# catplot은 subplots 안먹힘.
fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1, 2, 1)
sns.catplot(df, x='class', y='fare', kind='bar')
ax1.set_title('mean')
ax2 = fig.add_subplot(1, 2, 2)
sns.catplot(df, x='class', y='fare', kind='bar', estimator=np.median)
ax2.set_title('median')
# Out:
# Text(0.5, 1.0, 'median')

# %%
# catplot은 subplots 안먹힘.
fig, axes = plt.subplots(ncols=2)
sns.catplot(data=df, x='class', y='fare', kind='bar', ax=axes[0])
axes[0].set_title('mean')
sns.catplot(data=df, x='class', y='fare', kind='bar', estimator=np.median, ax=axes[1])
axes[1].set_title('median')
# Out:
# Text(0.5, 1.0, 'median')

# %%
df.survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### plot 겹치기(boxplot, stripplot)

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(data=df, x='survived', y='age', palette='Set3')
sns.stripplot(data=df, x='survived', y='age');

# %%
pal = sns.color_palette('YlOrRd')
sns.palplot(pal)

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(data=df, x='survived', y='age', palette='hls')
sns.stripplot(data=df, x='survived', y='age', color=pal[2], alpha=0.5, size=3);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### violinplot

# %%
sns.violinplot(df, x='age', y='embark_town');

# %%
sns.violinplot(df, x='age', y='embark_town', inner='box');

# %%
sns.violinplot(df, x='age', y='embark_town', inner='stick');

# %%
sns.violinplot(df, x='age', y='embark_town', inner='quartile');

# %%
sns.violinplot(df, x='age', y='embark_town', inner='point');

# %%
sns.violinplot(df, x='age', y='embark_town', inner=None);

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(df, x='embark_town', hue='sex');

# %%
sns.histplot(df, y='sex', hue='survived');

# %%
sns.histplot(df, x='sex', hue='survived', multiple='stack');

# %%
sns.countplot(df, y='sex', hue='survived');

# %%
sns.displot(df, x='sex', hue='survived', multiple='stack');

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## [load] penguins

# %%
penguins = sns.load_dataset('penguins')
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins = sns.load_dataset("penguins")
sns.displot(data=penguins, x="flipper_length_mm");

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="kde");

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="ecdf");

# %%
sns.displot(data=penguins, x="flipper_length_mm", kde=True);

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm");

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", kind="kde");

# %%
g = sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", kind="kde", rug=True);

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", kind="kde");

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack");

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="sex", kind="kde");

# %%
sns.displot(
    data=penguins, y="flipper_length_mm", hue="sex", col="species",
    kind="ecdf", height=4, aspect=.7,
);

# %%
g = sns.displot(
    data=penguins, y="flipper_length_mm", hue="sex", col="species",
    kind="kde", height=4, aspect=.7,
)
g.set_axis_labels("Density (a.u.)", "Flipper length (mm)")
g.set_titles("{col_name} penguins");

# %%
g?
# Out:
# Type:           FacetGrid
# String form:    <seaborn.axisgrid.FacetGrid object at 0x000002B554F6DB90>
# File:           c:\users\kbjung\anaconda3\lib\site-packages\seaborn\axisgrid.py
# Docstring:      Multi-plot grid for plotting conditional relationships.
# Init docstring:
# Initialize the matplotlib figure and FacetGrid object.
#
# This class maps a dataset onto multiple axes arrayed in a grid of rows
# and columns that correspond to *levels* of variables in the dataset.
# The plots it produces are often called "lattice", "trellis", or
# "small-multiple" graphics.
#
# It can also represent levels of a third variable with the ``hue``
# parameter, which plots different subsets of data in different colors.
# This uses color to resolve elements on a third dimension, but only
# draws subsets on top of each other and will not tailor the ``hue``
# parameter for the specific visualization the way that axes-level
# functions that accept ``hue`` will.
#
# ...

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
g.col_names
# Out:
# ['Adelie', 'Chinstrap', 'Gentoo']

# %% [markdown]
# ## [load] tips

# %%
tips = sns.load_dataset('tips')
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ### FacetGrid

# %%
sns.FacetGrid(tips);

# %%
sns.FacetGrid(tips, col="time", row="sex");

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
tips.sex.unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
tips.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
tips.tip.describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip");

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map_dataframe(sns.histplot, x="total_bill");

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map_dataframe(sns.histplot, x="total_bill");

# %%
g = sns.FacetGrid(tips, col="time", row="sex")
g.map_dataframe(sns.histplot, x="total_bill", binwidth=2, binrange=(0, 60));

# %%
g = sns.FacetGrid(tips, col="time", hue="sex")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.add_legend();

# %%
g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip", hue="sex")
g.add_legend();

# %%
g = sns.FacetGrid(tips, col="day", height=3.5, aspect=.65)
g.map(sns.histplot, "total_bill");

# %%
g = sns.FacetGrid(tips, col="size", height=2.5, col_wrap=3)
g.map(sns.histplot, "total_bill");

# %%
g = sns.FacetGrid(tips, col="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.refline(y=tips["tip"].median());

# %%
import matplotlib.pyplot as plt
def annotate(data, **kws):
    n = len(data)
    ax = plt.gca()
    ax.text(.1, .6, f"N = {n}", transform=ax.transAxes)

g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.map_dataframe(annotate);

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.set_axis_labels("Total bill ($)", "Tip ($)")
g.set_titles(col_template="{col_name} patrons", row_template="{row_name}")
g.set(xlim=(0, 60), ylim=(0, 12), xticks=[10, 30, 50], yticks=[2, 6, 10])
g.tight_layout();

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True, despine=False)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.figure.subplots_adjust(wspace=0, hspace=0)
for (row_val, col_val), ax in g.axes_dict.items():
    if row_val == "Lunch" and col_val == "Female":
        ax.set_facecolor(".95")
    else:
        ax.set_facecolor((0, 0, 0, 0));

# %%
# Apply the default theme
sns.set_theme()

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
);

# %% [markdown]
# # 코드마지막
