# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %% [markdown]
# # fold path

# %%
ods_fold = 'D:/data/big2/ODS'
g4_data_check_fold = 'D:/data/big2/BD1_4등급_데이터_점검1'

# %% [markdown]
# # Load

# %% [markdown]
# ## 4등급 등록&제원정보

# %%
# about 22s
file_name = '[ODS][G4]등록정보&제원정보(말소제거)(2022.12.28).csv'
df = pd.read_csv(os.path.join(ods_fold, file_name), encoding='cp949')
df.info()
# Out:
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\1303083448.py:3: DtypeWarning: Columns (12,14,21,44,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(ods_fold, file_name), encoding='cp949')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511251 entries, 0 to 1511250
# Data columns (total 49 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   차량관리번호        1511251 non-null  object
#  1   차량등록번호        1511251 non-null  object
#  2   본거지법정동코드      1511251 non-null  int64
#  3   소유자구분         1511251 non-null  object
#  4   차종_등록정보       1511249 non-null  object
#  5   용도            1511251 non-null  object
#  6   현재회원번호        1510412 non-null  object
#  7   차대번호          1511251 non-null  object
#  8   최초등록일자        1511251 non-null  int64
#  9   차량연식          1511251 non-null  int64
#  10  차량제작일자        1342461 non-null  float64
#  11  배출가스검사유효일자    1511239 non-null  float64
#  12  제원관리번호        1511251 non-null  object
#  13  배출가스인증번호      1387530 non-null  object
#  14  배출가스등급        1511251 non-null  object
#  15  저공해조치YN(미사용)  1511096 non-null  object
#  16  저공해조치종류       189 non-null      float64
#  17  저공해조치구조변경YN   1511251 non-null  object
#  18  차량등록번호숫자정보    1511251 non-null  int64
#  19  차량말소YN        1511251 non-null  object
#  20  최초회원번호        1506595 non-null  object
#  21  취득일자          1418010 non-null  object
#  22  취득금액          1436843 non-null  float64
#  23  생성일시_등록정보     1511251 non-null  object
#  24  수정일시_등록정보     915041 non-null   object
#  25  차명            1511251 non-null  object
#  26  차종_제원정보       1511251 non-null  object
#  27  차종분류          1511251 non-null  object
#  28  차종유형(소분류)     1511251 non-null  object
#  29  자동차형식         1510723 non-null  object
#  30  제작사명          1501221 non-null  object
#  31  연료            1511180 non-null  object
#  32  엔진형식          1509249 non-null  object
#  33  공차중량          0 non-null        float64
#  34  총중량           1511226 non-null  float64
#  35  적재중량          1510714 non-null  float64
#  36  엔진출력          1510623 non-null  float64
#  37  배기량           1511240 non-null  float64
#  38  승차인원          1511251 non-null  float64
#  39  차량길이          1511176 non-null  float64
#  40  차량너비          1511176 non-null  float64
#  41  차량높이          1511174 non-null  float64
#  42  원산지명          1492122 non-null  object
#  43  삭제YN          1511251 non-null  object
#  44  승인일자          1510704 non-null  object
#  45  구동형식          47 non-null       float64
#  46  변속기종류         1511091 non-null  object
#  47  생성일시_제원정보     1511251 non-null  object
#  48  수정일시_제원정보     497 non-null      object
# dtypes: float64(14), int64(4), object(31)
# memory usage: 565.0+ MB

# %%
df.columns
# Out:
# Index(['차량관리번호', '차량등록번호', '본거지법정동코드', '소유자구분', '차종_등록정보', '용도', '현재회원번호',
#        '차대번호', '최초등록일자', '차량연식', '차량제작일자', '배출가스검사유효일자', '제원관리번호', '배출가스인증번호',
#        '배출가스등급', '저공해조치YN(미사용)', '저공해조치종류', '저공해조치구조변경YN', '차량등록번호숫자정보',
#        '차량말소YN', '최초회원번호', '취득일자', '취득금액', '생성일시_등록정보', '수정일시_등록정보', '차명',
#        '차종_제원정보', '차종분류', '차종유형(소분류)', '자동차형식', '제작사명', '연료', '엔진형식', '공차중량',
#        '총중량', '적재중량', '엔진출력', '배기량', '승차인원', '차량길이', '차량너비', '차량높이', '원산지명',
#        '삭제YN', '승인일자', '구동형식', '변속기종류', '생성일시_제원정보', '수정일시_제원정보'],
#       dtype='object')

# %%
df['연료'].value_counts(dropna=False)
# Out:
# 경유             1152698
# 휘발유             332351
# LPG(액화석유가스)      26090
# NaN                 71
# 기타연료                39
# 알코올                  1
# CNG(압축천연가스)          1
# Name: 연료, dtype: int64

# %%
df['차량말소YN'].value_counts(dropna=False)
# Out:
# N    1511251
# Name: 차량말소YN, dtype: int64

# %% [markdown]
# ## 정기검사

# %%
# about 2m 56s
file_name = '[ODS]정기검사(2022.12.28).csv'
ins = pd.read_csv(os.path.join(ods_fold, file_name))
ins.info()
# Out:
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\1947711141.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   ins = pd.read_csv(os.path.join(ods_fold, file_name))
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22006426 entries, 0 to 22006425
# Data columns (total 39 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   사용연료       object
#  1   주행거리       object
#  2   차명         object
#  3   차량번호       object
#  4   차대번호       object
#  5   차종         object
#  6   차량연식       int64
#  7   엔진형식       object
#  8   검사방법       object
#  9   검사일자       int64
#  10  검사종류       object
#  11  검사판정시각     object
#  12  검사판정       object
#  13  산소값        float64
#  14  이산화탄소값     float64
#  15  무부하매연판정1   object
#  16  무부하매연판정2   object
#  17  무부하매연판정3   object
#  18  무부하매연판정4   object
#  19  무부하매연판정5   object
#  20  무부하매연판정6   object
#  21  무부하매연허용치1  float64
#  22  무부하매연허용치2  float64
#  23  무부하매연허용치3  float64
#  24  무부하매연허용치4  float64
#  25  무부하매연허용치5  float64
#  26  무부하매연허용치6  float64
#  27  무부하매연측정치1  float64
#  28  무부하매연측정치2  float64
#  29  무부하매연측정치3  float64
#  30  무부하매연측정치4  float64
#  31  무부하매연측정치5  float64
#  32  무부하매연측정치6  float64
#  33  차량용도       object
#  34  최대출력허용치    float64
#  35  최대출력측정값    float64
#  36  검사접수번호     object
#  37  검사소명       object
#  38  재검사기간      object
# dtypes: float64(16), int64(2), object(21)
# memory usage: 6.4+ GB

# %% [markdown]
# ## 정밀검사

# %%
# about 
file_name = '[ODS]정밀검사(2022.12.28).csv'
dins = pd.read_csv(os.path.join(ods_fold, file_name))
dins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28682228 entries, 0 to 28682227
# Data columns (total 41 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   사용연료       object
#  1   주행거리       float64
#  2   차명         object
#  3   차량번호       object
#  4   차대번호       object
#  5   차종         object
#  6   차량연식       int64
#  7   엔진형식       object
#  8   검사방법       object
#  9   검사일자       int64
#  10  검사종류       object
#  11  검사판정시각     object
#  12  검사판정       object
#  13  산소값        float64
#  14  이산화탄소값     float64
#  15  무부하매연판정1   object
#  16  무부하매연판정2   object
#  17  무부하매연판정3   object
#  18  무부하매연판정4   object
#  19  무부하매연판정5   object
#  20  무부하매연판정6   object
#  21  무부하매연허용치1  float64
#  22  무부하매연허용치2  float64
#  23  무부하매연허용치3  float64
#  24  무부하매연허용치4  float64
#  25  무부하매연허용치5  float64
#  26  무부하매연허용치6  float64
#  27  무부하매연측정치1  float64
#  28  무부하매연측정치2  float64
#  29  무부하매연측정치3  float64
#  30  무부하매연측정치4  float64
#  31  무부하매연측정치5  float64
#  32  무부하매연측정치6  float64
#  33  차량용도       object
#  34  최대출력허용치    float64
#  35  최대출력측정값    float64
#  36  검사접수번호     object
#  37  검사소명       object
#  38  재검사기간      object
#  39  검사 검사소코드   object
#  40  검사유효기간     float64
# dtypes: float64(18), int64(2), object(21)
# memory usage: 8.8+ GB

# %% [markdown]
# ## 4등급차 회신내역 정리(23.02.14.)(정리)

# %%
# about 
file_name = '4등급차 회신내역 정리(23.02.14.)(정리).xlsx'
check_df = pd.read_excel(os.path.join(g4_data_check_fold, file_name))
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   배출가스인증번호  133 non-null    object
#  1   차량 대수(대)  133 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# # 전처리
#     - 등록&제원정보
#         - 경유차만 추출
#         - 차대번호 중복 제거
#     - 정기, 정밀 검사
#         - 정기/정밀 검사 표기 컬럼 추가
#         - 병합
#         - 최신 검사만 추출
#     - 등록&제원, 정기&정밀 병합(차대번호 기준)

# %% [markdown]
# ## 등록&제원정보

# %% [markdown]
# ### 말소 제거

# %%
df.shape
# Out:
# (1511251, 49)

# %%
df = df[df['차량말소YN'] == 'N']
df.shape
# Out:
# (1511251, 49)

# %% [markdown]
# ### 경유차만 추출

# %%
df.shape
# Out:
# (1511251, 49)

# %%
df1 = df[df['연료'] == '경유'].reset_index(drop=True)
df1.shape
# Out:
# (1152698, 49)

# %% [markdown]
# ### 차대번호 중복 제거
# - '최초등록일자', '배출가스검사유효일자' 최신 순

# %%
df2 = df1.sort_values(['최초등록일자', '배출가스검사유효일자'], ascending=[False, False]).drop_duplicates('차대번호').reset_index(drop=True)
df2.shape
# Out:
# (1152698, 49)

# %% [markdown]
# ## 정기, 정밀 검사

# %% [markdown]
# ### 정기, 정밀 검사 표기 컬럼 추가

# %%
ins['정기정밀'] = '정기'
dins['정기정밀'] = '정밀'
ins.shape, dins.shape
# Out:
# ((22006426, 40), (28682228, 42))

# %% [markdown]
# ### 병합

# %%
# about 17s
tin = pd.concat([ins, dins], ignore_index=True)
tin.shape
# Out:
# (50688654, 42)

# %% [markdown]
# ### 최신 검사만 추출

# %%
# about 6m 26s
tin1 = tin.sort_values('검사일자', ascending=False).drop_duplicates('차대번호').reset_index(drop=True)
tin1.shape
# Out:
# (22044208, 42)

# %% [markdown]
# #### [출력] 정기&정밀검사

# %%
# about 16m 44s
tin.to_csv(os.path.join(ods_fold, '[ODS]정기&정밀검사(2022.12.28).csv'), index=False)

# %% [markdown]
# #### [출력] 정기&정밀검사(최신검사만)

# %%
# about 7m 17s
tin1.to_csv(os.path.join(ods_fold, '[ODS]정기&정밀검사(최신검사만)(2022.12.28).csv'), index=False)

# %% [markdown]
# ## 등록&제원 과 정기&정밀 데이터 병합

# %%
df2.shape
# Out:
# (1152698, 49)

# %%
# about 
total = df2.merge(tin1, on='차대번호', how='left')
total.shape
# Out:
# (1152698, 90)

# %% [markdown]
# ## 차량연식과 차대번호10자리 연식 다른 데이터 제거

# %%
total['vin10'] = total['차대번호'].str[9]
total[['차대번호', 'vin10']].head()
# Out:
#                 차대번호 vin10
# 0  KMFLA18KP8C028585     8
# 1  KMCLK18KP8C035195     8
# 2  KMFLA18KP8C031274     8
# 3  KMCGK17HP9C112030     9
# 4  KLACA26RD8B226753     8

# %%
vin10_dict = {'J':1988, 'K':1989, 'L':1990, 'M':1991, 'N':1992, 'P':1993, 'R':1994, 'S':1995, 'T':1996, 'V':1997, 'W':1998, 'X':1999, 'Y':2000, '1':2001, '2':2002, '3':2003, '4':2004, '5':2005, '6':2006, '7':2007, '8':2008, '9':2009, 'A':2010, 'B':2011, 'C':2012, 'D':2013, 'E':2014, 'F':2015, 'G':2016, 'H':2017}

# %%
total['vin10_year'] = total['vin10'].map(vin10_dict, na_action='ignore')

# %%
total.shape
# Out:
# (1152698, 92)

# %% [markdown]
# ## [출력] 배인번호별 파일 출력

# %%
total['배출가스인증번호'].isnull().sum()
# Out:
# 7621

# %%
total['배출가스인증번호'] = total['배출가스인증번호'].astype('str')

# %%
# about 1m 15s
# csv
for one in tqdm(total['배출가스인증번호'].unique()):
    total[total['배출가스인증번호'] == one].reset_index(drop=True).to_csv(f'D:/data/big2/BD1_4등급_데이터_점검1/과제1/{one}.csv', index=False)
# Out:
# 100%|██████████| 207/207 [01:14<00:00,  2.79it/s]

# %%
# # about 27m 48s
# # excel
# for one in tqdm(total['배출가스인증번호'].unique()):
#     total[total['배출가스인증번호'] == one].reset_index(drop=True).to_excel(f'D:/data/big2/BD1_4등급_데이터_점검1/과제1/{one}.xlsx', index=False)
# Out:
# 100%|██████████| 207/207 [27:47<00:00,  8.06s/it]

# %%
total.loc[total['제작사명'] == 'SOFA차량', ['제작사명' ,'검사판정', '무부하매연판정1', '무부하매연측정치1']].isnull().sum()
# Out:
# 제작사명           0
# 검사판정         145
# 무부하매연판정1     145
# 무부하매연측정치1    145
# dtype: int64

# %%
total.loc[total['제작사명'] == 'SOFA차량', ['제작사명' ,'검사판정', '무부하매연판정1', '무부하매연측정치1']].shape
# Out:
# (159, 4)

# %% [markdown]
# # 배출가스 인증번호별 분석

# %%
# check_df['배출가스인증번호'].to_list()

# %% [markdown]
# ## [로드] 배인번호 파일

# %%
gas_nm_fold = 'D:/data/big2/BD1_4등급_데이터_점검1/과제1'

# %%
gas_nm = '5MY-HD-24-59'
file_name = f'{gas_nm}.xlsx'
gas_df = pd.read_excel(os.path.join(gas_nm_fold, file_name))
gas_df.shape
# Out:
# (29250, 92)

# %%
# gas_df.columns

# %% [markdown]
# ## 전처리
# - 제거
#     - 차대번호 17자리 아닌 샘플
#     - 차대번호 10자리와 차량연식이 다른 샘플

# %% [markdown]
# ### [출력] 차대번호17자리 아닌 샘플

# %%
gas_df_vin17_y = gas_df[(gas_df['차대번호'].str.len() == 17)].reset_index(drop=True)
gas_df_vin17_n = gas_df[(gas_df['차대번호'].str.len() != 17)].reset_index(drop=True)
gas_df_vin17_y.shape, gas_df_vin17_n.shape
# Out:
# ((29250, 92), (0, 92))

# %%
gas_df_vin17_n.to_excel(os.path.join(gas_nm_fold, f'샘플_차대번호17자리아닌_{gas_nm}.xlsx'), index=False)

# %% [markdown]
# ### [출력] 차대번호10자리 연도와 차량연식 다른 샘플

# %%
gas_df_vin17_y_vin10_year_y = gas_df_vin17_y[gas_df_vin17_y['vin10_year'] == gas_df_vin17_y['차량연식_y']].reset_index(drop=True)
gas_df_vin17_y_vin10_year_n = gas_df_vin17_y[gas_df_vin17_y['vin10_year'] != gas_df_vin17_y['차량연식_y']].reset_index(drop=True)
gas_df_vin17_y_vin10_year_y.shape, gas_df_vin17_y_vin10_year_n.shape
# Out:
# ((28848, 92), (402, 92))

# %%
gas_df_vin17_y_vin10_year_n.to_excel(os.path.join(gas_nm_fold, f'샘플_차대번호17자리_차량연식다른_{gas_nm}.xlsx'), index=False)

# %% [markdown]
# ### [출력] 배인번호 해당 제작사가 아닌 샘플

# %%
gas_df_vin17_y_vin10_year_y['제작사명'].unique()
# Out:
# array(['SOFA차량', '자기인증면제차량', '현대자동차(주)', '준성모터스', '한불모터스(주)'],
#       dtype=object)

# %%
productor_name = gas_df_vin17_y_vin10_year_y['제작사명'].unique()[2]
productor_name
# Out:
# '현대자동차(주)'

# %%
gas_df_vin17_y_vin10_year_y_product_y = gas_df_vin17_y_vin10_year_y[(gas_df_vin17_y_vin10_year_y['제작사명'] == productor_name) | (gas_df_vin17_y_vin10_year_y['제작사명'] == '자가인증면제차량') | (gas_df_vin17_y_vin10_year_y['제작사명'] == 'SOFA차량')].reset_index(drop=True)
gas_df_vin17_y_vin10_year_y_product_n = gas_df_vin17_y_vin10_year_y[(gas_df_vin17_y_vin10_year_y['제작사명'] != productor_name) & (gas_df_vin17_y_vin10_year_y['제작사명'] != '자가인증면제차량') & (gas_df_vin17_y_vin10_year_y['제작사명'] != 'SOFA차량')].reset_index(drop=True)
gas_df_vin17_y_vin10_year_y_product_y.shape, gas_df_vin17_y_vin10_year_y_product_n.shape
# Out:
# ((28835, 92), (13, 92))

# %%
gas_df_vin17_y_vin10_year_y_product_n.to_excel(os.path.join(gas_nm_fold, f'샘플_차대번호17자리_차량연식다른_해당제작사아닌_{gas_nm}.xlsx'), index=False)

# %%
gas_df_vin17_y_vin10_year_y_product_y.loc[gas_df_vin17_y_vin10_year_y_product_y['제작사명'] == 'SOFA차량', ['제작사명', '검사판정', '무부하매연판정1', '무부하매연측정치1']]
# Out:
#      제작사명 검사판정 무부하매연판정1  무부하매연측정치1
# 0  SOFA차량    Y        Y        0.0
# 1  SOFA차량    Y        Y        5.0

# %% [markdown]
# ## 분석
# - 제원관리번호별, 자동차형식별, 엔진형식별, 검사판정별 무부하매연측정치1 통계

# %%
g1 = gas_df_vin17_y_vin10_year_y_product_y.groupby(['배출가스인증번호', '제작사명', '제원관리번호', '자동차형식', '엔진형식_y', '검사판정'], dropna=False, as_index=False)['차대번호'].agg(['count'])
g1
# Out:
#                                                                         count
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y         1
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y         1
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y         1
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y         1
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N         7
#                                                                   Y       121
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N        48
#                                                                   Y      1250
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N         5
#                                                                   Y        73
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N       114
#                                                                   Y      3033
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N         1
#                                                                   Y        41
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N       165
#                                                                   Y      5102
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N        30
#                                                                   Y       773
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N         1
#                                                                   Y        65
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N         1
#                                                                   Y        15
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N         2
#                                                                   Y        27
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y        16
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y         7
#                       A0810006301161206 JM-4VNF7-1         D4EA   N         9
#                                                                   Y       153
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y         1
#                       A0810006301181206 JM-4VAF7-1         D4EA   N        66
#                                                                   Y      2098
#                       A0810006301191206 JM-3VNF7-1         D4EA   N         9
#                                                                   Y        94
#                       A0810006301201206 JM-3VAF7-1         D4EA   N       221
#                                                                   Y      6543
#                       A0810006301211206 JM-2VNF7-1         D4EA   N         2
#                                                                   Y        51
#                       A0810006301221206 JM-2VAF7-1         D4EA   N       255
#                                                                   Y      7040
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y         1
#                       A0810006301241206 JM-1VAF7-1         D4EA   N        31
#                                                                   Y      1017
#                       A0810006301261206 JM-0VAF7-1         D4EA   N         6
#                                                                   Y        63
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y        20
#                       A0810006301291206 JM-3VNA7-1         D4EA   N         2
#                                                                   Y        55
#                       A0810006301301206 JM-2VNA7-1         D4EA   N         1
#                                                                   Y        13
#                       A0810006301311206 JM-1VNA7-1         D4EA   N         2
#                                                                   Y        17
#                       A0810009300091314 NC6XBB-T           D4HB   N         1
#                                                                   Y       163

# %%
g2 = gas_df_vin17_y_vin10_year_y_product_y.groupby(['배출가스인증번호', '제작사명', '제원관리번호', '자동차형식', '엔진형식_y', '검사판정'], dropna=False, as_index=False)['무부하매연측정치1'].agg(['count', 'mean', 'min', 'max'])
g2
# Out:
#                                                                         count  \
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y         1
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y         1
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y         1
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y         1
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N         7
#                                                                   Y       121
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N        37
#                                                                   Y      1250
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N         5
#                                                                   Y        73
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N        87
#                                                                   Y      3033
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N         0
#                                                                   Y        41
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N       102
#                                                                   Y      5102
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N        28
#                                                                   Y       773
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N         0
#                                                                   Y        65
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N         1
#                                                                   Y        15
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N         1
#                                                                   Y        27
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y        16
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y         7
#                       A0810006301161206 JM-4VNF7-1         D4EA   N         6
#                                                                   Y       153
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y         1
#                       A0810006301181206 JM-4VAF7-1         D4EA   N        46
#                                                                   Y      2098
#                       A0810006301191206 JM-3VNF7-1         D4EA   N         7
#                                                                   Y        94
#                       A0810006301201206 JM-3VAF7-1         D4EA   N       161
#                                                                   Y      6543
#                       A0810006301211206 JM-2VNF7-1         D4EA   N         2
#                                                                   Y        51
#                       A0810006301221206 JM-2VAF7-1         D4EA   N       183
#                                                                   Y      7040
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y         1
#                       A0810006301241206 JM-1VAF7-1         D4EA   N        22
#                                                                   Y      1017
#                       A0810006301261206 JM-0VAF7-1         D4EA   N         4
#                                                                   Y        63
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y        20
#                       A0810006301291206 JM-3VNA7-1         D4EA   N         2
#                                                                   Y        55
#                       A0810006301301206 JM-2VNA7-1         D4EA   N         1
#                                                                   Y        13
#                       A0810006301311206 JM-1VNA7-1         D4EA   N         2
#                                                                   Y        17
#                       A0810009300091314 NC6XBB-T           D4HB   N         0
#                                                                   Y       163
#
#                                                                              mean  \
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y      5.000000
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y      0.000000
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y     37.000000
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y      0.000000
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N     16.428571
#                                                                   Y      6.090909
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N     10.270270
#                                                                   Y      3.236000
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N      2.800000
#                                                                   Y      5.095890
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N     10.701149
#                                                                   Y      2.987141
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N           NaN
#                                                                   Y      6.951220
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N     12.323529
#                                                                   Y      3.150529
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N     16.285714
#                                                                   Y      3.329884
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N           NaN
#                                                                   Y      3.446154
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N     12.000000
#                                                                   Y      1.733333
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N      1.000000
#                                                                   Y      5.629630
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y      4.875000
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y      2.285714
#                       A0810006301161206 JM-4VNF7-1         D4EA   N     15.166667
#                                                                   Y      6.575163
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y     11.000000
#                       A0810006301181206 JM-4VAF7-1         D4EA   N     18.456522
#                                                                   Y      3.750715
#                       A0810006301191206 JM-3VNF7-1         D4EA   N     31.857143
#                                                                   Y      8.393617
#                       A0810006301201206 JM-3VAF7-1         D4EA   N     22.204348
#                                                                   Y      3.702583
#                       A0810006301211206 JM-2VNF7-1         D4EA   N     12.500000
#                                                                   Y      6.294118
#                       A0810006301221206 JM-2VAF7-1         D4EA   N     21.048634
#                                                                   Y      3.720597
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y      0.000000
#                       A0810006301241206 JM-1VAF7-1         D4EA   N     20.090909
#                                                                   Y      3.604720
#                       A0810006301261206 JM-0VAF7-1         D4EA   N     15.750000
#                                                                   Y      3.285714
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y      8.050000
#                       A0810006301291206 JM-3VNA7-1         D4EA   N      4.000000
#                                                                   Y      8.400000
#                       A0810006301301206 JM-2VNA7-1         D4EA   N     82.000000
#                                                                   Y      3.692308
#                       A0810006301311206 JM-1VNA7-1         D4EA   N      3.000000
#                                                                   Y     10.000000
#                       A0810009300091314 NC6XBB-T           D4HB   N           NaN
#                                                                   Y      0.503067
#
#                                                                          min  \
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y      5.0
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y      0.0
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y     37.0
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y      0.0
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N      NaN
#                                                                   Y      0.0
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N      NaN
#                                                                   Y      0.0
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N     12.0
#                                                                   Y      0.0
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N      1.0
#                                                                   Y      0.0
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y      0.0
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y      0.0
#                       A0810006301161206 JM-4VNF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y     11.0
#                       A0810006301181206 JM-4VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301191206 JM-3VNF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301201206 JM-3VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301211206 JM-2VNF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301221206 JM-2VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y      0.0
#                       A0810006301241206 JM-1VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301261206 JM-0VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y      0.0
#                       A0810006301291206 JM-3VNA7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301301206 JM-2VNA7-1         D4EA   N     82.0
#                                                                   Y      0.0
#                       A0810006301311206 JM-1VNA7-1         D4EA   N      2.0
#                                                                   Y      0.0
#                       A0810009300091314 NC6XBB-T           D4HB   N      NaN
#                                                                   Y      0.0
#
#                                                                           max
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y       5.0
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y       0.0
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y      37.0
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y       0.0
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N      70.0
#                                                                   Y      33.0
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N      67.0
#                                                                   Y      45.0
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N      12.0
#                                                                   Y      37.0
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N      71.0
#                                                                   Y      50.0
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N       NaN
#                                                                   Y      29.0
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N      87.0
#                                                                   Y      43.0
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N      86.0
#                                                                   Y      40.0
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N       NaN
#                                                                   Y      29.0
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N      12.0
#                                                                   Y      14.0
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N       1.0
#                                                                   Y      39.0
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y      22.0
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y      12.0
#                       A0810006301161206 JM-4VNF7-1         D4EA   N      42.0
#                                                                   Y      45.0
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y      11.0
#                       A0810006301181206 JM-4VAF7-1         D4EA   N      64.0
#                                                                   Y      45.0
#                       A0810006301191206 JM-3VNF7-1         D4EA   N      69.0
#                                                                   Y      39.0
#                       A0810006301201206 JM-3VAF7-1         D4EA   N     999.9
#                                                                   Y      45.0
#                       A0810006301211206 JM-2VNF7-1         D4EA   N      25.0
#                                                                   Y      28.0
#                       A0810006301221206 JM-2VAF7-1         D4EA   N     999.9
#                                                                   Y      42.0
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y       0.0
#                       A0810006301241206 JM-1VAF7-1         D4EA   N      95.0
#                                                                   Y      35.0
#                       A0810006301261206 JM-0VAF7-1         D4EA   N      34.0
#                                                                   Y      22.0
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y      44.0
#                       A0810006301291206 JM-3VNA7-1         D4EA   N       8.0
#                                                                   Y      41.0
#                       A0810006301301206 JM-2VNA7-1         D4EA   N      82.0
#                                                                   Y      17.0
#                       A0810006301311206 JM-1VNA7-1         D4EA   N       4.0
#                                                                   Y      44.0
#                       A0810009300091314 NC6XBB-T           D4HB   N       NaN
#                                                                   Y       8.0

# %%
g = pd.concat([g1, g2], axis=1)
g
# Out:
#                                                                         count  \
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y         1
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y         1
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y         1
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y         1
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N         7
#                                                                   Y       121
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N        48
#                                                                   Y      1250
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N         5
#                                                                   Y        73
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N       114
#                                                                   Y      3033
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N         1
#                                                                   Y        41
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N       165
#                                                                   Y      5102
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N        30
#                                                                   Y       773
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N         1
#                                                                   Y        65
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N         1
#                                                                   Y        15
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N         2
#                                                                   Y        27
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y        16
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y         7
#                       A0810006301161206 JM-4VNF7-1         D4EA   N         9
#                                                                   Y       153
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y         1
#                       A0810006301181206 JM-4VAF7-1         D4EA   N        66
#                                                                   Y      2098
#                       A0810006301191206 JM-3VNF7-1         D4EA   N         9
#                                                                   Y        94
#                       A0810006301201206 JM-3VAF7-1         D4EA   N       221
#                                                                   Y      6543
#                       A0810006301211206 JM-2VNF7-1         D4EA   N         2
#                                                                   Y        51
#                       A0810006301221206 JM-2VAF7-1         D4EA   N       255
#                                                                   Y      7040
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y         1
#                       A0810006301241206 JM-1VAF7-1         D4EA   N        31
#                                                                   Y      1017
#                       A0810006301261206 JM-0VAF7-1         D4EA   N         6
#                                                                   Y        63
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y        20
#                       A0810006301291206 JM-3VNA7-1         D4EA   N         2
#                                                                   Y        55
#                       A0810006301301206 JM-2VNA7-1         D4EA   N         1
#                                                                   Y        13
#                       A0810006301311206 JM-1VNA7-1         D4EA   N         2
#                                                                   Y        17
#                       A0810009300091314 NC6XBB-T           D4HB   N         1
#                                                                   Y       163
#
#                                                                         count  \
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y         1
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y         1
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y         1
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y         1
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N         7
#                                                                   Y       121
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N        37
#                                                                   Y      1250
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N         5
#                                                                   Y        73
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N        87
#                                                                   Y      3033
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N         0
#                                                                   Y        41
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N       102
#                                                                   Y      5102
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N        28
#                                                                   Y       773
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N         0
#                                                                   Y        65
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N         1
#                                                                   Y        15
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N         1
#                                                                   Y        27
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y        16
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y         7
#                       A0810006301161206 JM-4VNF7-1         D4EA   N         6
#                                                                   Y       153
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y         1
#                       A0810006301181206 JM-4VAF7-1         D4EA   N        46
#                                                                   Y      2098
#                       A0810006301191206 JM-3VNF7-1         D4EA   N         7
#                                                                   Y        94
#                       A0810006301201206 JM-3VAF7-1         D4EA   N       161
#                                                                   Y      6543
#                       A0810006301211206 JM-2VNF7-1         D4EA   N         2
#                                                                   Y        51
#                       A0810006301221206 JM-2VAF7-1         D4EA   N       183
#                                                                   Y      7040
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y         1
#                       A0810006301241206 JM-1VAF7-1         D4EA   N        22
#                                                                   Y      1017
#                       A0810006301261206 JM-0VAF7-1         D4EA   N         4
#                                                                   Y        63
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y        20
#                       A0810006301291206 JM-3VNA7-1         D4EA   N         2
#                                                                   Y        55
#                       A0810006301301206 JM-2VNA7-1         D4EA   N         1
#                                                                   Y        13
#                       A0810006301311206 JM-1VNA7-1         D4EA   N         2
#                                                                   Y        17
#                       A0810009300091314 NC6XBB-T           D4HB   N         0
#                                                                   Y       163
#
#                                                                              mean  \
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y      5.000000
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y      0.000000
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y     37.000000
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y      0.000000
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N     16.428571
#                                                                   Y      6.090909
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N     10.270270
#                                                                   Y      3.236000
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N      2.800000
#                                                                   Y      5.095890
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N     10.701149
#                                                                   Y      2.987141
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N           NaN
#                                                                   Y      6.951220
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N     12.323529
#                                                                   Y      3.150529
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N     16.285714
#                                                                   Y      3.329884
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N           NaN
#                                                                   Y      3.446154
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N     12.000000
#                                                                   Y      1.733333
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N      1.000000
#                                                                   Y      5.629630
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y      4.875000
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y      2.285714
#                       A0810006301161206 JM-4VNF7-1         D4EA   N     15.166667
#                                                                   Y      6.575163
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y     11.000000
#                       A0810006301181206 JM-4VAF7-1         D4EA   N     18.456522
#                                                                   Y      3.750715
#                       A0810006301191206 JM-3VNF7-1         D4EA   N     31.857143
#                                                                   Y      8.393617
#                       A0810006301201206 JM-3VAF7-1         D4EA   N     22.204348
#                                                                   Y      3.702583
#                       A0810006301211206 JM-2VNF7-1         D4EA   N     12.500000
#                                                                   Y      6.294118
#                       A0810006301221206 JM-2VAF7-1         D4EA   N     21.048634
#                                                                   Y      3.720597
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y      0.000000
#                       A0810006301241206 JM-1VAF7-1         D4EA   N     20.090909
#                                                                   Y      3.604720
#                       A0810006301261206 JM-0VAF7-1         D4EA   N     15.750000
#                                                                   Y      3.285714
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y      8.050000
#                       A0810006301291206 JM-3VNA7-1         D4EA   N      4.000000
#                                                                   Y      8.400000
#                       A0810006301301206 JM-2VNA7-1         D4EA   N     82.000000
#                                                                   Y      3.692308
#                       A0810006301311206 JM-1VNA7-1         D4EA   N      3.000000
#                                                                   Y     10.000000
#                       A0810009300091314 NC6XBB-T           D4HB   N           NaN
#                                                                   Y      0.503067
#
#                                                                          min  \
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y      5.0
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y      0.0
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y     37.0
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y      0.0
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N      NaN
#                                                                   Y      0.0
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N      NaN
#                                                                   Y      0.0
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N     12.0
#                                                                   Y      0.0
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N      1.0
#                                                                   Y      0.0
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y      0.0
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y      0.0
#                       A0810006301161206 JM-4VNF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y     11.0
#                       A0810006301181206 JM-4VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301191206 JM-3VNF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301201206 JM-3VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301211206 JM-2VNF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301221206 JM-2VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y      0.0
#                       A0810006301241206 JM-1VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301261206 JM-0VAF7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y      0.0
#                       A0810006301291206 JM-3VNA7-1         D4EA   N      0.0
#                                                                   Y      0.0
#                       A0810006301301206 JM-2VNA7-1         D4EA   N     82.0
#                                                                   Y      0.0
#                       A0810006301311206 JM-1VNA7-1         D4EA   N      2.0
#                                                                   Y      0.0
#                       A0810009300091314 NC6XBB-T           D4HB   N      NaN
#                                                                   Y      0.0
#
#                                                                           max
# 배출가스인증번호     제작사명     제원관리번호            자동차형식              엔진형식_y 검사판정
# 5MY-HD-24-59 SOFA차량   99934125199341219 JM-3VAF7-1         D4EA   Y       5.0
#                       99934515023041219 JM-BB5MSFR4FVAF6-3 D4EA   Y       0.0
#              현대자동차(주) A0810006300691205 JM-BB5MSFR0FJAF6-1 D4EA   Y      37.0
#                       A0810006300911205 JM-BB5MSFS5FJMF6-5 D4EA   Y       0.0
#                       A0810006300931205 JM-BB5MSFR4FVNF6-3 D4EA   N      70.0
#                                                                   Y      33.0
#                       A0810006300941205 JM-BB5MSFR4FVAF6-3 D4EA   N      67.0
#                                                                   Y      45.0
#                       A0810006300951205 JM-BB5MSFR3FVNF6-3 D4EA   N      12.0
#                                                                   Y      37.0
#                       A0810006300961205 JM-BB5MSFR3FVAF6-3 D4EA   N      71.0
#                                                                   Y      50.0
#                       A0810006300971205 JM-BB5MSFR2FVNF6-3 D4EA   N       NaN
#                                                                   Y      29.0
#                       A0810006300981205 JM-BB5MSFR2FVAF6-3 D4EA   N      87.0
#                                                                   Y      43.0
#                       A0810006301001205 JM-BB5MSFR1FVAF6-3 D4EA   N      86.0
#                                                                   Y      40.0
#                       A0810006301021205 JM-BB5MSFR0FVAF6-3 D4EA   N       NaN
#                                                                   Y      29.0
#                       A0810006301111205 JM-BB5MSFR4FVNA6-3 D4EA   N      12.0
#                                                                   Y      14.0
#                       A0810006301121205 JM-BB5MSFR3FVNA6-3 D4EA   N       1.0
#                                                                   Y      39.0
#                       A0810006301131205 JM-BB5MSFR2FVNA6-3 D4EA   Y      22.0
#                       A0810006301141205 JM-BB5MSFR1FVNA6-3 D4EA   Y      12.0
#                       A0810006301161206 JM-4VNF7-1         D4EA   N      42.0
#                                                                   Y      45.0
#                       A0810006301171206 JM-5VAF7-5         D4EA   Y      11.0
#                       A0810006301181206 JM-4VAF7-1         D4EA   N      64.0
#                                                                   Y      45.0
#                       A0810006301191206 JM-3VNF7-1         D4EA   N      69.0
#                                                                   Y      39.0
#                       A0810006301201206 JM-3VAF7-1         D4EA   N     999.9
#                                                                   Y      45.0
#                       A0810006301211206 JM-2VNF7-1         D4EA   N      25.0
#                                                                   Y      28.0
#                       A0810006301221206 JM-2VAF7-1         D4EA   N     999.9
#                                                                   Y      42.0
#                       A0810006301231206 JM-1VNF7-1         D4EA   Y       0.0
#                       A0810006301241206 JM-1VAF7-1         D4EA   N      95.0
#                                                                   Y      35.0
#                       A0810006301261206 JM-0VAF7-1         D4EA   N      34.0
#                                                                   Y      22.0
#                       A0810006301271206 JM-4VNA7-1         D4EA   Y      44.0
#                       A0810006301291206 JM-3VNA7-1         D4EA   N       8.0
#                                                                   Y      41.0
#                       A0810006301301206 JM-2VNA7-1         D4EA   N      82.0
#                                                                   Y      17.0
#                       A0810006301311206 JM-1VNA7-1         D4EA   N       4.0
#                                                                   Y      44.0
#                       A0810009300091314 NC6XBB-T           D4HB   N       NaN
#                                                                   Y       8.0

# %%
g.columns
# Out:
# Index(['count', 'count', 'mean', 'min', 'max'], dtype='object')

# %% [markdown]
# ### [출력] 제번별, 자동차형식별, 엔진형식별 검사판정별 무부하매연측정치1 통계

# %%
analysis_fold = 'D:/data/big2/BD1_4등급_데이터_점검1/과제1/통계'

# %%
g.to_excel(os.path.join(analysis_fold, f'통계_제번별_차형식별_엔진형식별_검사판정별_무부하매연측정치1_{gas_nm}.xlsx'))

# %% [markdown]
# ### 데이터 확인

# %%
# gas_df_vin17_y_vin10_year_y_product_y.loc[gas_df_vin17_y_vin10_year_y_product_y['무부하매연판정1'].isnull() == True, ['검사판정']]

# %%
# gas_df_vin17_y_vin10_year_y_product_y.loc[(gas_df_vin17_y_vin10_year_y_product_y['검사판정'] == 'N') & (gas_df_vin17_y_vin10_year_y_product_y['제원관리번호'] == '120001600051307'), ['무부하매연측정치1']]

# %% [markdown]
# ## 코드 병합

# %%
gas_nm_list = check_df['배출가스인증번호'].unique()
len(gas_nm_list)
# Out:
# 133

# %%
gas_nm_fold = 'D:/data/big2/BD1_4등급_데이터_점검1/과제1'
analysis_fold = 'D:/data/big2/BD1_4등급_데이터_점검1/과제1/통계'
productor_dict = {
    'HD':'현대자동차(주)', 'KM':'기아자동차(주)', 'JL':'(주)재규어랜드로버코리아', 'AD':'아우디폭스바겐코리아(주)', 'PP':'아우디폭스바겐코리아(주)', 'PA':'(주)볼보자동차코리아', 'BK':'비엠더블유코리아(주)',
    'DC':'타타대우상용차(주)', 'DB':'자일대우상용차 주식회사', 'DW':'한국지엠주식회사', 'DK':'다임러트럭코리아(주)', 'HB':'한불모터스(주)', 'SK':'스카니아코리아그룹(주)', 'SY':'쌍용자동차(주)', 
    'VTK':'볼보트럭코리아(주)', 'GK':'지엠아시아퍼시픽지역본부 주식회사', 'MK':'메르세데스벤츠코리아(주)', 'MT':'만트럭버스코리아(주)', 'SM':'르노삼성자동차(주)',  }
for one in gas_nm_list:
    try:
        # 파일 로드
        file_name = f'{one}.csv'
        gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name), low_memory=False)

        # [출력] 차대번호 17자리 아닌 샘플
        gas_df_vin17_y = gas_df[(gas_df['차대번호'].str.len() == 17)].reset_index(drop=True)
        gas_df_vin17_n = gas_df[(gas_df['차대번호'].str.len() != 17)].reset_index(drop=True)
        gas_df_vin17_n.to_excel(os.path.join(gas_nm_fold, f'샘플_차대번호17자리아닌_{one}.xlsx'), index=False)

        # [출력] 차대번호 연식과 차량연식 다른 샘플
        gas_df_vin17_y_vin10_year_y = gas_df_vin17_y[gas_df_vin17_y['vin10_year'] == gas_df_vin17_y['차량연식_y']].reset_index(drop=True)
        gas_df_vin17_y_vin10_year_n = gas_df_vin17_y[gas_df_vin17_y['vin10_year'] != gas_df_vin17_y['차량연식_y']].reset_index(drop=True)
        gas_df_vin17_y_vin10_year_n.to_excel(os.path.join(gas_nm_fold, f'샘플_차대번호17자리_차량연식다른_{one}.xlsx'), index=False)

        # [출력] 배인번호 해당 제작사가 아닌 샘플
        productors = gas_df_vin17_y_vin10_year_y['제작사명'].unique()
        # 제작사명 조건에 따라 진행
        if len(productors) == 1:
            productor_name = gas_df_vin17_y_vin10_year_y['제작사명'].unique()[0]
            num = 0
            productor_name = gas_df_vin17_y_vin10_year_y['제작사명'].unique()[num]
            gas_df_vin17_y_vin10_year_y_product_y = gas_df_vin17_y_vin10_year_y[(gas_df_vin17_y_vin10_year_y['제작사명'] == productor_name) | (gas_df_vin17_y_vin10_year_y['제작사명'] == '자기인증면제차량')].reset_index(drop=True)
            gas_df_vin17_y_vin10_year_y_product_n = gas_df_vin17_y_vin10_year_y[(gas_df_vin17_y_vin10_year_y['제작사명'] != productor_name) & (gas_df_vin17_y_vin10_year_y['제작사명'] != '자기인증면제차량')].reset_index(drop=True)
            gas_df_vin17_y_vin10_year_y_product_n.to_excel(os.path.join(gas_nm_fold, f'샘플_차대번호17자리_차량연식다른_해당제작사아닌_{one}.xlsx'), index=False)    
        else:
            temp = one.split('-')
            if len(temp) == 1:
                productor_name = one
            else:
                productor_name = productor_dict[temp[1]]
            # print(one)
            # print(gas_df_vin17_y_vin10_year_y['제작사명'].unique())
            # productor_name = input('제작사명 : ')
            gas_df_vin17_y_vin10_year_y_product_y = gas_df_vin17_y_vin10_year_y[(gas_df_vin17_y_vin10_year_y['제작사명'] == productor_name) | (gas_df_vin17_y_vin10_year_y['제작사명'] == '자가인증면제차량') | (gas_df_vin17_y_vin10_year_y['제작사명'] == 'SOFA차량')].reset_index(drop=True)
            gas_df_vin17_y_vin10_year_y_product_n = gas_df_vin17_y_vin10_year_y[(gas_df_vin17_y_vin10_year_y['제작사명'] != productor_name) & (gas_df_vin17_y_vin10_year_y['제작사명'] != '자가인증면제차량') & (gas_df_vin17_y_vin10_year_y['제작사명'] != 'SOFA차량')].reset_index(drop=True)
            gas_df_vin17_y_vin10_year_y_product_n.to_excel(os.path.join(gas_nm_fold, f'샘플_차대번호17자리_차량연식다른_해당제작사아닌_{one}.xlsx'), index=False)

        # 제번별, 차형식별, 엔진형식별, 검사판정별 무부하매연측정치1 통계
        g1 = gas_df_vin17_y_vin10_year_y_product_y.groupby(['배출가스인증번호', '제작사명', '제원관리번호', '자동차형식', '엔진형식_y', '검사판정'], dropna=False, as_index=False)['차대번호'].agg(['count'])
        g2 = gas_df_vin17_y_vin10_year_y_product_y.groupby(['배출가스인증번호', '제작사명', '제원관리번호', '자동차형식', '엔진형식_y', '검사판정'], dropna=False, as_index=False)['무부하매연측정치1'].agg(['count', 'mean', 'min', 'max'])
        g = pd.concat([g1, g2], axis=1)
        g.to_excel(os.path.join(analysis_fold, f'통계_제번별_차형식별_엔진형식별_검사판정별_무부하매연측정치1_{one}.xlsx'))
    except:
        print(f'{one} 파일 없음.')
        pass
# Out:
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (65,66,67,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (64,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (68,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (14,48,64,65,66,67,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (64,65,66,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (64,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (14,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# 9MY-KM-14-22 파일 없음.
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (65,66,67,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (32,55,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_17604\2803716882.py:11: DtypeWarning: Columns (14,48,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   gas_df = pd.read_csv(os.path.join(gas_nm_fold, file_name))
