# %%
import numpy as np

# %%
1 + 2
# Out:
# 3

# %%
3 % 2
# Out:
# 1

# %%
5 / 2
# Out:
# 2.5

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
a, b = [1, 2, 3], [3, 5, 1]
plt.bar(a, b)
plt.show()

# %%
plt.boxplot(a, b)
plt.show()

# %%
plt.scatter(a, b);
plt.grid()

# %%
np.random.rand(5)
# Out:
# array([0.03744801, 0.79160602, 0.90955149, 0.1568107 , 0.30027624])

# %%
np.random.choice(5, 2)
# Out:
# array([0, 0])

# %%
np.random.choice(5, 2, replace=False)
# Out:
# array([1, 0])

# %%
np.random.randint(1, 100, 10)
# Out:
# array([71, 25, 66, 29, 30, 80, 18, 80, 48, 84])

# %%
a = list(range(1, 11))
b = np.random.randint(1, 100, 10)
plt.figure(figsize=(6, 6))
plt.scatter(a, b)
plt.show()

# %%
plt.plot(a, b, '.')

# %%
ax = np.random.randint(1, 1000, 100)
ay = np.random.randint(1, 1000, 100)
by = np.random.randint(1, 1000, 100)
cy = np.random.randint(1, 1000, 100)
plt.plot(ax, ay, 'r.', label='a')
plt.plot(ax, by, 'b.', label='b')
plt.plot(ax, cy, 'g.', label='c')
plt.legend(frameon=True, shadow=True, framealpha=0.3, fancybox=True);

# %%
ax = np.random.randint(1, 1000, 100)
ay = np.random.randint(1, 1000, 100)
by = np.random.randint(1, 1000, 100)
cy = np.random.randint(1, 1000, 100)
plt.bar(ax, ay, label='a', width=5, alpha=0.7)
plt.bar(ax, by, label='b', width=5, alpha=0.7)
plt.bar(ax, cy, label='c', width=5, alpha=0.7)
plt.legend(frameon=True, shadow=False, framealpha=0.3, fancybox=True);

# %%
x = np.linspace(0, 14, 100)
y = np.sin(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y);

# %%
y1 = np.cos(x)
plt.plot(x, y1);

# %%
x = np.linspace(1, 14, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.title('Sin(X)')
plt.fill([5, 5, 7, 7], [-0.5, 0.25, 0.25, -0.5], color='gray', alpha=0.5)
plt.plot(x, y1)

plt.subplot(1, 3, 2)
plt.plot(x, y2)
plt.title('Cos(X)')

plt.subplot(1, 3, 3)
plt.title('Tan(X)')
plt.plot(x, y3)
plt.show();

# %%
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]
plt.figure(figsize=(8, 6))
plt.plot(x, y)
plt.fill_between(x[1:3], y[1:3], alpha=0.5);

# %%
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()

ax.plot(x, y)
ax.axvspan(2, 3, facecolor='green', alpha=0.3);

# %%
import pandas as pd
df = pd.read_csv('gas.csv', encoding='EUC-kr')
df.head()
# Out:
#              검사방법  연료     적용법령   차종      제작시작일자      제작종료일자      적용시작일자  \
# 0  부하검사(LUG DOWN)  경유  대기환경보전법  전차종  2008-01-01  9999-12-31  2010-07-01
# 1  부하검사(LUG DOWN)  경유  대기환경보전법  전차종  2001-01-01  2007-12-31  2010-07-01
# 2  부하검사(LUG DOWN)  경유  대기환경보전법  전차종  1996-01-01  2000-12-31  2010-07-01
# 3  부하검사(LUG DOWN)  경유  대기환경보전법  전차종  1901-01-01  1995-12-31  2010-07-01
# 4  부하검사(LUG DOWN)  경유  대기환경보전법  전차종  2008-01-01  9999-12-31  2010-07-01
#
#        적용종료일자  차량최소중량   차량최대중량 일산화탄소-기준치 탄화수소-기준치 질소산화물-기준치 매연-기준치 매연-기준치(촉매)
# 0  9999-12-31       0     5500                                  20
# 1  9999-12-31       0     5500                                  50
# 2  9999-12-31       0     5500                                  60
# 3  9999-12-31       0     5500                                  70
# 4  9999-12-31    5501  9999999                                  15

# %%
df.describe()
# Out:
#             차량최소중량        차량최대중량
# count  4913.000000  4.913000e+03
# mean   1359.252595  3.398468e+06
# std    1106.363764  4.735618e+06
# min       0.000000  9.990000e+02
# 25%       0.000000  1.749000e+03
# 50%    1600.000000  2.499000e+03
# 75%    2250.000000  9.999999e+06
# max    5501.000000  9.999999e+06

# %%
pd.options.display.float_format = '{:.9}'.format
# pd.reset_option('display.float_format')

# %%
df.describe()
# Out:
#           차량최소중량     차량최대중량
# count     4913.0     4913.0
# mean   1359.2526 3398467.96
# std   1106.36376 4735617.54
# min          0.0      999.0
# 25%          0.0     1749.0
# 50%       1600.0     2499.0
# 75%       2250.0  9999999.0
# max       5501.0  9999999.0

# %%
df.columns
# Out:
# Index(['검사방법', '연료', '적용법령', '차종', '제작시작일자', '제작종료일자', '적용시작일자', '적용종료일자',
#        '차량최소중량', '차량최대중량', '일산화탄소-기준치', '탄화수소-기준치', '질소산화물-기준치', '매연-기준치',
#        '매연-기준치(촉매)'],
#       dtype='object')

# %%
df['일산화탄소-기준치'].describe()
# Out:
# count     4913
# unique     120
# top
# freq       322
# Name: 일산화탄소-기준치, dtype: object

# %%
df['일산화탄소-기준치'].unique()
# Out:
# array([' ', '1', '1.2', '4.5', '2.5', '시내', '0.77', '1.22', '1.83',
#        '0.62', '0.81', '0.99', '1.47', '0.52', '0.67', '0.82', '1.21',
#        '0.46', '0.6', '0.73', '1.08', '0.41', '0.53', '0.65', '0.94',
#        '0.38', '0.49', '0.87', '0.35', '0.45', '0.55', '0.79', '2.4',
#        '4.2', '0.48', '0.76', '2.2', '1.84', '2.19', '2.91', '0.43',
#        '0.69', '2.6', '1.64', '1.96', '1.41', '1.68', '2.22', '1.28',
#        '1.52', '2.01', '0.42', '0.51', '1.17', '1.38', '1.39', '1.82',
#        '1.05', '1.24', '1.62', '0.96', '1.13', '1.14', '1.49', '0.34',
#        '0.89', '1.37', '1.89', '2.51', '1.04', '1.36', '1.3', '1.59',
#        '2.38', '1.29', '1.91', '0.68', '1.07', '1.57', '0.78', '1.4',
#        '0.95', '0.85', '0.64', '0.59', '0.72', '1.03', '1.56', '3.12',
#        '5.46', '2.39', '2.85', '2.86', '3.78', '0.56', '0.9', '2.13',
#        '2.55', '3.38', '2.18', '2.89', '1.66', '1.98', '2.61', '0.66',
# ...

# %%
df['일산화탄소-기준치'].isnull().sum()
# Out:
# 0

# %%
df[df['일산화탄소-기준치'] == ' '].count()
# Out:
# 검사방법          322
# 연료            322
# 적용법령          322
# 차종            322
# 제작시작일자        322
# 제작종료일자        322
# 적용시작일자        322
# 적용종료일자        322
# 차량최소중량        322
# 차량최대중량        322
# 일산화탄소-기준치     322
# 탄화수소-기준치      322
# 질소산화물-기준치     322
# 매연-기준치        322
# 매연-기준치(촉매)    322
# dtype: int64
