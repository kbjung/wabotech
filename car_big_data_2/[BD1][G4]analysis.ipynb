# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %% [markdown]
# # 로드
# - 등록정보&제원정보(말소적용)
# - 정기검사(말소적용)
# - 정밀검사(말소적용)

# %%
# about 44s
# 등록&제원 정보(말소적용)
df = pd.read_csv('data/[ODS][G4]등록정보&제원정보(말소적용)(2022.12.29).csv')
# 정기
ins1 = pd.read_csv('data/[ODS][G4]정기검사(말소적용)(2022.12.29).csv')
# 정밀
ins2 = pd.read_csv('data/[ODS][G4]정밀검사(말소적용)(2022.12.29).csv')
# Out:
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_4832\617598753.py:3: DtypeWarning: Columns (11,13,17,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/[ODS][G4]등록정보&제원정보(말소적용)(2022.12.29).csv')
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_4832\617598753.py:5: DtypeWarning: Columns (1,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   ins1 = pd.read_csv('data/[ODS][G4]정기검사(말소적용)(2022.12.29).csv')
# C:\Users\kbjung\AppData\Local\Temp\ipykernel_4832\617598753.py:7: DtypeWarning: Columns (1,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   ins2 = pd.read_csv('data/[ODS][G4]정밀검사(말소적용)(2022.12.29).csv')

# %% [markdown]
# # [분석]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511251 entries, 0 to 1511250
# Data columns (total 40 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   차량관리번호       1511251 non-null  object
#  1   차량등록번호       1511251 non-null  object
#  2   본거지법정동코드     1511251 non-null  int64
#  3   소유자구분        1511251 non-null  object
#  4   차종_등록정보      1511249 non-null  object
#  5   용도           1511251 non-null  object
#  6   차대번호         1511251 non-null  object
#  7   최초등록일자       1511251 non-null  int64
#  8   차량연식         1511251 non-null  int64
#  9   차량제작일자       1342461 non-null  float64
#  10  배출가스검사유효일자   1511239 non-null  float64
#  11  제원관리번호       1511251 non-null  object
#  12  배출가스인증번호     1387542 non-null  object
#  13  배출가스등급       1511251 non-null  object
#  14  저공해조치종류      189 non-null      float64
#  15  저공해조치구조변경YN  1511251 non-null  object
#  16  차량말소YN       1511251 non-null  object
# ...

# %%
df.shape
# Out:
# (1511251, 40)

# %%
ins1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2563368 entries, 0 to 2563367
# Data columns (total 40 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   차대번호       object
#  1   제원관리번호     object
#  2   사용연료       object
#  3   주행거리       float64
#  4   차명         object
#  5   차량번호       object
#  6   차종         object
#  7   차량연식       float64
#  8   검사방법       object
#  9   이산화탄소값     float64
#  10  최대출력허용치    float64
#  11  최대출력측정값    float64
#  12  엔진형식       object
#  13  검사접수번호     object
#  14  정기검사일자     float64
#  15  검사종류       object
#  16  검사소명       object
#  17  검사판정시각     object
#  18  정기검사판정     object
#  19  산소값        float64
#  20  재검사기간      object
#  21  무부하매연판정1   object
#  22  무부하매연판정2   object
#  23  무부하매연판정3   object
#  24  무부하매연판정4   object
#  25  무부하매연판정5   object
#  26  무부하매연판정6   object
#  27  무부하매연허용치1  float64
#  28  무부하매연허용치2  float64
#  29  무부하매연허용치3  float64
#  30  무부하매연허용치4  float64
#  31  무부하매연허용치5  float64
# ...

# %%
ins1.shape
# Out:
# (2563368, 40)

# %%
ins2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3431911 entries, 0 to 3431910
# Data columns (total 42 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   차대번호        object
#  1   제원관리번호      object
#  2   사용연료        object
#  3   주행거리        float64
#  4   차명          object
#  5   차량번호        object
#  6   차종          object
#  7   차량연식        float64
#  8   정밀검사 검사소코드  object
#  9   이산화탄소값      float64
#  10  최대출력허용치     float64
#  11  최대출력측정값     float64
#  12  엔진형식        object
#  13  산소값         float64
#  14  재검사기간       object
#  15  정밀검사일자      float64
#  16  정밀검사판정      object
#  17  정밀검사측정방법    object
#  18  정밀검사소명      object
#  19  정밀검사접수번호    object
#  20  정밀검사종류      object
#  21  정밀검사시각정보    object
#  22  무부하매연판정1    object
#  23  무부하매연판정2    object
#  24  무부하매연판정3    object
#  25  무부하매연판정4    object
#  26  무부하매연판정5    object
#  27  무부하매연판정6    object
#  28  무부하매연허용치1   float64
#  29  무부하매연허용치2   float64
#  30  무부하매연허용치3   float64
# ...

# %%
ins2.shape
# Out:
# (3431911, 42)

# %%
ins2['차량용도'].unique()
# Out:
# array([nan, '자가용', '관용', '영업용', '개인택시'], dtype=object)

# %%
df.columns
# Out:
# Index(['차량관리번호', '차량등록번호', '본거지법정동코드', '소유자구분', '차종_등록정보', '용도', '차대번호',
#        '최초등록일자', '차량연식', '차량제작일자', '배출가스검사유효일자', '제원관리번호', '배출가스인증번호',
#        '배출가스등급', '저공해조치종류', '저공해조치구조변경YN', '차량말소YN', '취득일자', '취득금액', '차명',
#        '차종_제원정보', '차종분류', '차종유형', '자동차형식', '제작사명', '연료', '엔진형식', '총중량', '적재중량',
#        '엔진출력', '배기량', '승차인원', '차량길이', '차량너비', '차량높이', '원산지명', '삭제YN', '승인일자',
#        '구동형식', '변속기종류'],
#       dtype='object')

# %%
ins1.columns
# Out:
# Index(['차대번호', '제원관리번호', '사용연료', '주행거리', '차명', '차량번호', '차종', '차량연식', '검사방법',
#        '이산화탄소값', '최대출력허용치', '최대출력측정값', '엔진형식', '검사접수번호', '정기검사일자', '검사종류',
#        '검사소명', '검사판정시각', '정기검사판정', '산소값', '재검사기간', '무부하매연판정1', '무부하매연판정2',
#        '무부하매연판정3', '무부하매연판정4', '무부하매연판정5', '무부하매연판정6', '무부하매연허용치1',
#        '무부하매연허용치2', '무부하매연허용치3', '무부하매연허용치4', '무부하매연허용치5', '무부하매연허용치6',
#        '무부하매연측정치1', '무부하매연측정치2', '무부하매연측정치3', '무부하매연측정치4', '무부하매연측정치5',
#        '무부하매연측정치6', '차량용도'],
#       dtype='object')

# %%
ins2.columns
# Out:
# Index(['차대번호', '제원관리번호', '사용연료', '주행거리', '차명', '차량번호', '차종', '차량연식',
#        '정밀검사 검사소코드', '이산화탄소값', '최대출력허용치', '최대출력측정값', '엔진형식', '산소값', '재검사기간',
#        '정밀검사일자', '정밀검사판정', '정밀검사측정방법', '정밀검사소명', '정밀검사접수번호', '정밀검사종류',
#        '정밀검사시각정보', '무부하매연판정1', '무부하매연판정2', '무부하매연판정3', '무부하매연판정4', '무부하매연판정5',
#        '무부하매연판정6', '무부하매연허용치1', '무부하매연허용치2', '무부하매연허용치3', '무부하매연허용치4',
#        '무부하매연허용치5', '무부하매연허용치6', '무부하매연측정치1', '무부하매연측정치2', '무부하매연측정치3',
#        '무부하매연측정치4', '무부하매연측정치5', '무부하매연측정치6', '차량용도', '정밀검사유효기간'],
#       dtype='object')

# %%
df['차종_등록정보'].unique()
# Out:
# array(['승용', '화물', '승합', nan, '특수'], dtype=object)

# %%
df['용도'].unique()
# Out:
# array(['자가용', '영업용', '관용'], dtype=object)

# %%
df['차종_제원정보'].unique()
# Out:
# array(['승용', '화물', '승합', '특수'], dtype=object)

# %%
df['차종분류'].unique()
# Out:
# array(['일반', '일반형-픽업', '일반형-카고', '승용겸화물', '특수', '다목적', '특수용도형-특수용도형',
#        '기타', '밴', '덤프', '특수작업형', '견인', '구난', '특수용도형-탱크로리', '특수용도형-피견인'],
#       dtype=object)

# %%
df['차종유형'].unique()
# Out:
# array(['소형', '대형', '중형', '경형'], dtype=object)

# %%
df['구동형식'].unique()
# Out:
# array([nan, 30.,  3., 12.,  4., 14., 31., 19., 11.,  2.,  1.])

# %%
df['연료'].unique()
# Out:
# array(['휘발유', 'LGP(액화석유가스)', '경유', '기타연료', nan, '알코올', 'CNG(압축천연가스)'],
#       dtype=object)

# %%
df.isnull().sum().reset_index()
# Out:
#           index        0
# 0        차량관리번호        0
# 1        차량등록번호        0
# 2      본거지법정동코드        0
# 3         소유자구분        0
# 4       차종_등록정보        2
# 5            용도        0
# 6          차대번호        0
# 7        최초등록일자        0
# 8          차량연식        0
# 9        차량제작일자   168790
# 10   배출가스검사유효일자       12
# 11       제원관리번호        0
# 12     배출가스인증번호   123709
# 13       배출가스등급        0
# 14      저공해조치종류  1511062
# 15  저공해조치구조변경YN        0
# 16       차량말소YN        0
# 17         취득일자    93241
# 18         취득금액    74408
# 19           차명        0
# 20      차종_제원정보        0
# 21         차종분류        0
# 22         차종유형        0
# 23        자동차형식      528
# 24         제작사명    10030
# 25           연료       71
# 26         엔진형식     2002
# 27          총중량       25
# 28         적재중량      537
# 29         엔진출력      628
# 30          배기량       11
# 31         승차인원        0
# 32         차량길이       75
# 33         차량너비       75
# 34         차량높이       77
# 35         원산지명    19129
# ...

# %%
ins1.isnull().sum().reset_index()
# Out:
#         index        0
# 0        차대번호        0
# 1      제원관리번호        0
# 2        사용연료   978904
# 3        주행거리   982658
# 4          차명   978899
# 5        차량번호   978899
# 6          차종   978899
# 7        차량연식   978899
# 8        검사방법   978899
# 9      이산화탄소값  2539951
# 10    최대출력허용치  2563368
# 11    최대출력측정값  2563368
# 12       엔진형식   978926
# 13     검사접수번호   978899
# 14     정기검사일자   978899
# 15       검사종류   978899
# 16       검사소명   978899
# 17     검사판정시각   978899
# 18     정기검사판정   978899
# 19        산소값  2541707
# 20      재검사기간   978899
# 21   무부하매연판정1   981858
# 22   무부하매연판정2  2539645
# 23   무부하매연판정3  2539645
# 24   무부하매연판정4  2542735
# 25   무부하매연판정5  2542735
# 26   무부하매연판정6  2542735
# 27  무부하매연허용치1   981858
# 28  무부하매연허용치2  2539645
# 29  무부하매연허용치3  2539645
# 30  무부하매연허용치4  2542735
# 31  무부하매연허용치5  2542735
# 32  무부하매연허용치6  2542735
# 33  무부하매연측정치1   981858
# 34  무부하매연측정치2  2539645
# 35  무부하매연측정치3  2539645
# 36  무부하매연측정치4  2542735
# 37  무부하매연측정치5  2542735
# 38  무부하매연측정치6  2542735
# ...

# %%
ins2.isnull().sum().reset_index()
# Out:
#          index        0
# 0         차대번호        0
# 1       제원관리번호        0
# 2         사용연료   524092
# 3         주행거리   524092
# 4           차명   524092
# 5         차량번호   524092
# 6           차종   524092
# 7         차량연식   524092
# 8   정밀검사 검사소코드   524092
# 9       이산화탄소값   779350
# 10     최대출력허용치  3243272
# 11     최대출력측정값  3431911
# 12        엔진형식   524191
# 13         산소값   779350
# 14       재검사기간   524092
# 15      정밀검사일자   524092
# 16      정밀검사판정   524092
# 17    정밀검사측정방법   524092
# 18      정밀검사소명   524092
# 19    정밀검사접수번호   524092
# 20      정밀검사종류   524092
# 21    정밀검사시각정보   632287
# 22    무부하매연판정1   632358
# 23    무부하매연판정2  3157830
# 24    무부하매연판정3  3160336
# 25    무부하매연판정4  3160344
# 26    무부하매연판정5  3160344
# 27    무부하매연판정6  3318887
# 28   무부하매연허용치1   632356
# 29   무부하매연허용치2  2339994
# 30   무부하매연허용치3  2339999
# 31   무부하매연허용치4  2340002
# 32   무부하매연허용치5  2340002
# 33   무부하매연허용치6  2462927
# 34   무부하매연측정치1   632287
# 35   무부하매연측정치2  2272669
# 36   무부하매연측정치3  2339980
# ...

# %% [markdown]
# ## [출력] 결측값 통계

# %%
# 등록정보
file_name1 = 'CEG_CAR_MIG'
col_exc1 = pd.read_excel(f'analysis/ODSvsSTD/[정제]{file_name1}.xlsx', sheet_name='ODS_col')
# 제원정보
file_name2 = 'CEG_CAR_SRC_MIG'
col_exc2 = pd.read_excel(f'analysis/ODSvsSTD/[정제]{file_name2}.xlsx', sheet_name='ODS_col')
# 정기검사
file_name3 = 'TB_JGT_HIS'
col_exc3 = pd.read_excel(f'analysis/ODSvsSTD/[정제]{file_name3}.xlsx', sheet_name='ODS_col')
# 정밀검사
file_name4 = 'TB_EET_HIS_ME'
col_exc4 = pd.read_excel(f'analysis/ODSvsSTD/[정제]{file_name4}.xlsx', sheet_name='ODS_col')

# %%
col_exc1
# Out:
#                    컬럼             내용
# 0             UPDT_DT          수정 일시
# 1             OWNR_SE         소유자 구분
# 2               VHRNO         차량등록번호
# 3        BSPL_LEDO_CD     본거지 법정동 코드
# 4             CRTN_DT          생성 일시
# 5               PURPS             용도
# 6   EMIS_INSP_EFCT_DE     배출가스검사유효일자
# 7         EMIS_CRTCNO      배출가스 인증번호
# 8          NOW_MBERNO        현재 회원번호
# 9             ACQS_DE          취득 일자
# 10           ACQS_AMT          취득 금액
# 11         FST_MBERNO        최초 회원번호
# 12         FST_REG_DE       최초 등록 일자
# 13              VHCTY             차종
# 14     VHRNO_NUM_INFO   차량등록번호 숫자 정보
# 15              VHMNO         차량관리번호
# 16      VHCL_MNFCT_DE       차량 제작 일자
# 17        VHCL_YRIDNW          차량 연식
# 18       VHCL_ERSR_YN       차량 말소 YN
# 19                VIN           차대번호
# 20            SRCMNNO         제원관리번호
# 21           EMIS_GRD        배출가스 등급
# 22            LEM_KND       저공해조치 종류
# 23      LEM_STRCHG_YN  저공해조치 구조변경 YN
# ...

# %%
col_exc1 = col_exc1.loc[:24]
col_exc1
# Out:
#                    컬럼             내용
# 0             UPDT_DT          수정 일시
# 1             OWNR_SE         소유자 구분
# 2               VHRNO         차량등록번호
# 3        BSPL_LEDO_CD     본거지 법정동 코드
# 4             CRTN_DT          생성 일시
# 5               PURPS             용도
# 6   EMIS_INSP_EFCT_DE     배출가스검사유효일자
# 7         EMIS_CRTCNO      배출가스 인증번호
# 8          NOW_MBERNO        현재 회원번호
# 9             ACQS_DE          취득 일자
# 10           ACQS_AMT          취득 금액
# 11         FST_MBERNO        최초 회원번호
# 12         FST_REG_DE       최초 등록 일자
# 13              VHCTY             차종
# 14     VHRNO_NUM_INFO   차량등록번호 숫자 정보
# 15              VHMNO         차량관리번호
# 16      VHCL_MNFCT_DE       차량 제작 일자
# 17        VHCL_YRIDNW          차량 연식
# 18       VHCL_ERSR_YN       차량 말소 YN
# 19                VIN           차대번호
# 20            SRCMNNO         제원관리번호
# 21           EMIS_GRD        배출가스 등급
# 22            LEM_KND       저공해조치 종류
# 23      LEM_STRCHG_YN  저공해조치 구조변경 YN
# ...

# %%
col_exc2
# Out:
#              컬럼           내용
# 0       UPDT_DT        수정 일시
# 1      CNFRM_DE        승인 일자
# 2       DELE_YN        삭제 YN
# 3       CRTN_DT        생성 일시
# 4      TOT_WGHT         총 중량
# 5      VHCTY_TY  차종 유형 (소분류)
# 6      VHCTY_CL        차종 분류
# 7         VHCTY           차종
# 8         VHCNM           차명
# 9       VHCL_HG        차량 높이
# 10      VHCL_WH        차량 너비
# 11      VHCL_LT        차량 길이
# 12      DRV_FRM        구동 형식
# 13       MKR_NM        제작사 명
# 14      SRCMNNO       제원관리번호
# 15   CRYNG_WGHT        적재 중량
# 16      CAR_FRM       자동차 형식
# 17    EMPV_WGHT         공차중량
# 18      PLOR_NM        원산지 명
# 19         FUEL           연료
# 20       EGINTY         엔진형식
# 21      EGINPWR         엔진출력
# 22   TKCAR_NMPR        승차 인원
# 23       DSPLVL          배기량
# 24  GEARBOX_KND       변속기 종류
# 25    REPCAR_NM           미정
# 26          RMK           미정
# 27      USER_ID           미정

# %%
col_exc2 = col_exc2.loc[:24]
col_exc2
# Out:
#              컬럼           내용
# 0       UPDT_DT        수정 일시
# 1      CNFRM_DE        승인 일자
# 2       DELE_YN        삭제 YN
# 3       CRTN_DT        생성 일시
# 4      TOT_WGHT         총 중량
# 5      VHCTY_TY  차종 유형 (소분류)
# 6      VHCTY_CL        차종 분류
# 7         VHCTY           차종
# 8         VHCNM           차명
# 9       VHCL_HG        차량 높이
# 10      VHCL_WH        차량 너비
# 11      VHCL_LT        차량 길이
# 12      DRV_FRM        구동 형식
# 13       MKR_NM        제작사 명
# 14      SRCMNNO       제원관리번호
# 15   CRYNG_WGHT        적재 중량
# 16      CAR_FRM       자동차 형식
# 17    EMPV_WGHT         공차중량
# 18      PLOR_NM        원산지 명
# 19         FUEL           연료
# 20       EGINTY         엔진형식
# 21      EGINPWR         엔진출력
# 22   TKCAR_NMPR        승차 인원
# 23       DSPLVL          배기량
# 24  GEARBOX_KND       변속기 종류

# %%
col_exc3
# Out:
#              컬럼    내용
# 0   CAR_FUEL_NM  사용연료
# 1      CAR_MILE  주행거리
# 2        CAR_NM    차명
# 3    CAR_REG_NO  차량번호
# 4    CAR_SER_NO  차대번호
# ..          ...   ...
# 58  FUN_CHKR_NM    미정
# 59  SMO_CHKR_NM    미정
# 60  MNG_CHKR_NM    미정
# 61     DT_GUBUN    미정
# 62      FILE_NM    미정
#
# [63 rows x 2 columns]

# %%
col_exc3['내용'].to_list()
# Out:
# ['사용연료',
#  '주행거리',
#  '차명',
#  '차량번호',
#  '차대번호',
#  '차종',
#  '차량연식',
#  '검사방법',
#  '이산화탄소값',
#  '최대출력허용치',
#  '최대출력측정값',
#  '엔진형식',
#  '검사접수번호',
#  '정기검사일자',
#  '검사종류',
#  '검사소명',
#  '검사판정시각',
#  '정기검사판정',
#  '산소값',
#  '재검사기간',
#  '무부하매연판정1',
#  '무부하매연판정2',
#  '무부하매연판정3',
#  '무부하매연판정4',
#  '무부하매연판정5',
#  '무부하매연판정6',
#  '무부하매연허용치1',
#  '무부하매연허용치2',
#  '무부하매연허용치3',
#  '무부하매연허용치4',
#  '무부하매연허용치5',
#  '무부하매연허용치6',
#  '무부하매연측정치1',
#  '무부하매연측정치2',
#  '무부하매연측정치3',
#  '무부하매연측정치4',
#  '무부하매연측정치5',
#  '무부하매연측정치6',
#  '차량용도',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정',
#  '미정']

# %%
col_exc3 = col_exc3.loc[:38]
col_exc3
# Out:
#                    컬럼         내용
# 0         CAR_FUEL_NM       사용연료
# 1            CAR_MILE       주행거리
# 2              CAR_NM         차명
# 3          CAR_REG_NO       차량번호
# 4          CAR_SER_NO       차대번호
# 5         CAR_TYPE_NM         차종
# 6            CAR_YEAR       차량연식
# 7          CHK_METHOD       검사방법
# 8             CO2_VAL     이산화탄소값
# 9      ENGINE_TOR_LIM    최대출력허용치
# 10     ENGINE_TOR_VAL    최대출력측정값
# 11        ENGINE_TYPE       엔진형식
# 12           JEBSU_NO     검사접수번호
# 13        JG_CHK_DATE     정기검사일자
# 14        JG_CHK_TYPE       검사종류
# 15          JG_ORG_NM       검사소명
# 16         JUDGE_DATE     검사판정시각
# 17           JUDGE_YN     정기검사판정
# 18             O2_VAL        산소값
# 19        RE_CHK_DATE      재검사기간
# 20  UNLOAD_SMO_JUDGE1   무부하매연판정1
# 21  UNLOAD_SMO_JUDGE2   무부하매연판정2
# 22  UNLOAD_SMO_JUDGE3   무부하매연판정3
# 23  UNLOAD_SMO_JUDGE4   무부하매연판정4
# 24  UNLOAD_SMO_JUDGE5   무부하매연판정5
# 25  UNLOAD_SMO_JUDGE6   무부하매연판정6
# 26    UNLOAD_SMO_LIM1  무부하매연허용치1
# ...

# %%
df.isnull().sum().reset_index().to_excel('analysis/[BD1][G4]등록정보&제원정보(말소적용)_결측값_통계.xlsx')

# %%
ins1.isnull().sum().reset_index().to_excel('analysis/[BD1][G4]정기검사(말소적용)_결측값_통계.xlsx')

# %%
ins2.isnull().sum().reset_index().to_excel('analysis/[BD1][G4]정밀검사(말소적용)_결측값_통계.xlsx')

# %% [markdown]
# # 코드 마지막
